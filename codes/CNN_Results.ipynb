# %% [markdown]
# # IMDB

# %% [markdown]
# ## Glove Embedding + No Early Stopping

# %% [markdown]
# ### EPOCH = 5 Learning rate = 5e-4
# - IMDB-PRUNING-CNN-51
# - 충분히 학습될만한 epoch 주지 못함

# %%
reinit_performance = [87.15167197452229, 88.30613057324841, 88.18670382165605, 87.86823248407643, 87.81847133757962, 87.83837579617835, 87.24124203821655, 87.17157643312102, 86.76353503184714, 86.95262738853503, 86.68391719745223, 86.41520700636943, 86.19625796178345, 85.53941082802548, 86.01711783439491, 85.03184713375796, 85.00199044585987, 83.5390127388535, 80.78224522292994, 82.37460191082803, 82.88216560509554]
lt_performance = [86.72372611464968, 86.80334394904459, 86.91281847133759, 86.26592356687898, 85.76831210191082, 85.41998407643312, 84.6437101910828, 83.66839171974523, 82.73288216560509, 81.9765127388535, 80.89171974522293, 80.09554140127389, 78.68232484076432, 77.99562101910828, 76.79140127388536, 75.17914012738854, 74.51234076433121, 73.59673566878982, 73.39769108280255, 70.66082802547771, 70.52149681528662]
lr_f_performance = [87.13176751592357, 87.94785031847134, 87.49004777070064, 87.66918789808918, 87.34076433121018, 86.97253184713377, 86.28582802547771, 85.25079617834395, 84.156050955414, 82.40445859872611, 80.76234076433121, 78.53304140127389, 76.1843152866242, 75.27866242038218, 74.36305732484077, 73.27826433121018, 72.39251592356688, 72.02428343949045, 70.9295382165605, 71.17834394904459, 70.8499203821656]
lr_l_performance = [86.80334394904459, 88.59474522292994, 88.14689490445859, 88.01751592356688, 88.12699044585987, 87.72890127388536, 87.2312898089172, 86.36544585987261, 85.56926751592357, 84.265525477707, 83.0812101910828, 82.26512738853503, 81.29976114649682, 79.10031847133759, 77.11982484076432, 74.83081210191082, 73.63654458598727, 71.984474522293, 71.80533439490446, 71.36743630573248, 71.09872611464968]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'binary CNN Result')
# Out:
# Text(0.5, 1.0, 'binary CNN Result')

# %% [markdown]
# ### EPOCH = 10 Learning rate = 5e-4
# - IMDB-PRUNING-CNN-101

# %%
reinit_performance = [88.51512738853503, 87.67914012738854, 87.02229299363057, 86.67396496815286, 86.19625796178345, 86.09673566878982, 85.96735668789809, 85.63893312101911, 85.45979299363057, 85.08160828025477, 85.09156050955414, 85.24084394904459, 85.14132165605095, 85.02189490445859, 84.43471337579618, 83.57882165605095, 82.11584394904459, 79.4187898089172, 82.45421974522293, 80.0656847133758, 80.13535031847134]
lt_performance = [88.50517515923568, 88.34593949044586, 87.70899681528662, 87.36066878980891, 87.21138535031847, 86.74363057324841, 86.49482484076432, 86.23606687898089, 86.01711783439491, 85.57921974522293, 84.593949044586, 83.51910828025477, 82.60350318471338, 81.84713375796179, 80.4140127388535, 79.20979299363057, 77.73686305732484, 76.80135350318471, 75.77627388535032, 75.13933121019109, 73.25835987261146]
lr_f_performance = [88.62460191082803, 88.80374203821655, 88.45541401273886, 88.13694267515923, 88.07722929936305, 87.94785031847134, 87.83837579617835, 87.33081210191082, 86.6640127388535, 86.41520700636943, 85.61902866242038, 85.00199044585987, 83.52906050955414, 82.60350318471338, 81.28980891719745, 80.05573248407643, 79.51831210191082, 78.33399681528662, 77.23925159235668, 76.55254777070064, 76.12460191082803]
lr_l_performance = [88.57484076433121, 87.63933121019109, 87.83837579617835, 87.55971337579618, 87.37062101910828, 87.75875796178345, 87.56966560509554, 87.69904458598727, 87.61942675159236, 87.48009554140127, 86.80334394904459, 85.718550955414, 84.77308917197452, 84.01671974522293, 83.06130573248409, 82.17555732484077, 79.71735668789809, 76.95063694267516, 76.8312101910828, 75.59713375796179, 73.51711783439491]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'binary CNN Result')
# Out:
# Text(0.5, 1.0, 'binary CNN Result')

# %% [markdown]
# # Custom Embedding + Early Stopping

# %% [markdown]
# pre-trained embedding이 성능이 더 좋지만, 그냥 데이터에서 vocabulary 구축해도 성능에 큰 차이가 없었다. 그래서 그냥 자체 vocalbulary 구축해서 진행하기로 결정

# %% [markdown]
# ### EPOCH = 10 Learning rate = 1e-3
# - IMDB-PRUNING-CNN-EMBEDDING-201
# - EPOCH 충분히 주지 못함

# %%
reinit_performance = [88.2265127388535, 88.25636942675159, 87.66918789808918, 87.609474522293, 87.390525477707, 87.52985668789809, 86.9625796178344, 87.07205414012739, 87.06210191082803, 86.67396496815286, 86.24601910828027, 86.01711783439491, 86.05692675159236, 85.15127388535032, 85.3702229299363, 85.04179936305732, 84.79299363057325, 83.3797770700637, 81.06090764331209, 83.8375796178344, 81.08081210191082]
lt_performance = [88.74402866242038, 87.98765923566879, 88.09713375796179, 87.84832802547771, 87.27109872611464, 87.11186305732484, 86.80334394904459, 86.79339171974523, 86.27587579617835, 85.52945859872611, 85.67874203821655, 84.90246815286623, 84.61385350318471, 84.07643312101911, 83.38972929936305, 82.64331210191082, 81.92675159235668, 80.17515923566879, 79.43869426751591, 79.32921974522293, 77.00039808917197]
lr_f_performance = [88.16679936305732, 87.78861464968153, 87.41042993630573, 87.1218152866242, 86.97253184713377, 87.32085987261146, 86.99243630573248, 87.10191082802548, 86.86305732484077, 86.42515923566879, 86.45501592356688, 85.83797770700637, 85.86783439490446, 85.00199044585987, 83.87738853503186, 82.73288216560509, 81.58837579617835, 80.5234872611465, 79.25955414012739, 78.08519108280255, 76.62221337579618]
lr_l_performance = [88.19665605095541, 87.68909235668791, 88.04737261146497, 87.46019108280255, 87.32085987261146, 86.94267515923568, 87.06210191082803, 86.89291401273886, 86.80334394904459, 86.61425159235668, 85.99721337579618, 86.00716560509554, 84.98208598726114, 84.00676751592357, 82.98168789808918, 82.18550955414013, 81.47890127388536, 79.52826433121018, 78.67237261146497, 76.66202229299363, 72.95979299363057]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'Binary CNN Result')
# Out:
# Text(0.5, 1.0, 'Binary CNN Result')

# %% [markdown]
# ### EPOCH = 10 Learning rate = 5e-4
# - IMDB-PRUNING-CNN-EMBEDDING-301

# %%
reinit_performance = [88.29617834394905, 87.73885350318471, 87.65923566878982, 87.69904458598727, 87.22133757961782, 87.26114649681529, 87.29100318471338, 86.97253184713377, 86.82324840764332, 86.61425159235668, 86.36544585987261, 86.07683121019109, 86.08678343949045, 85.76831210191082, 85.75835987261146, 85.31050955414013, 84.89251592356688, 84.33519108280255, 82.1954617834395, 82.09593949044586, 80.8718152866242]
lt_performance = [88.42555732484077, 88.30613057324841, 87.98765923566879, 87.70899681528662, 87.54976114649682, 87.36066878980891, 87.06210191082803, 86.53463375796179, 86.3156847133758, 85.73845541401273, 84.89251592356688, 83.90724522292994, 82.88216560509554, 82.07603503184714, 80.88176751592357, 79.31926751592357, 78.5031847133758, 77.16958598726114, 76.5625, 74.76114649681529, 74.67157643312102]
lr_f_performance = [87.85828025477707, 87.65923566878982, 87.35071656050955, 87.46019108280255, 87.08200636942675, 87.06210191082803, 87.34076433121018, 86.78343949044586, 86.64410828025477, 86.046974522293, 85.49960191082803, 84.29538216560509, 83.63853503184714, 82.1954617834395, 81.80732484076432, 80.2249203821656, 78.57285031847134, 76.37340764331209, 76.12460191082803, 74.75119426751591, 72.93988853503186]
lr_l_performance = [87.81847133757962, 87.83837579617835, 87.74880573248409, 87.65923566878982, 87.48009554140127, 87.42038216560509, 87.40047770700637, 87.18152866242038, 86.87300955414013, 86.28582802547771, 85.61902866242038, 85.13136942675159, 83.54896496815286, 82.33479299363057, 81.44904458598727, 80.6827229299363, 78.82165605095541, 77.10987261146497, 76.343550955414, 74.88057324840764, 74.92038216560509]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'Binary CNN Result')
# Out:
# Text(0.5, 1.0, 'Binary CNN Result')

# %% [markdown]
# ### EPOCH = 20 Learning rate = 1e-2
# - IMDB-PRUNING-CNN-EMBEDDING-401
# - learning rate가 너무 커서 제대로 학습하지 못함

# %%
reinit_performance = [84.25557324840764, 83.85748407643312, 83.9968152866242, 83.50915605095541, 85.30055732484077, 85.17117834394905, 84.45461783439491, 84.56409235668791, 84.41480891719745, 83.62858280254777, 83.84753184713377, 83.79777070063695, 82.87221337579618, 83.05135350318471, 82.40445859872611, 81.76751592356688, 82.21536624203821, 81.60828025477707, 81.94665605095541, 80.95143312101911, 80.36425159235668]
lt_performance = [86.60429936305732, 86.90286624203821, 86.51472929936305, 86.58439490445859, 85.20103503184714, 86.13654458598727, 86.03702229299363, 84.77308917197452, 85.68869426751591, 85.31050955414013, 85.43988853503186, 84.156050955414, 84.18590764331209, 83.35987261146497, 83.65843949044586, 82.96178343949045, 81.94665605095541, 80.21496815286623, 81.140525477707, 80.37420382165605, 76.48288216560509]
lr_f_performance = [86.34554140127389, 84.9920382165605, 83.33001592356688, 85.43988853503186, 84.86265923566879, 85.31050955414013, 86.63415605095541, 86.03702229299363, 86.12659235668791, 85.91759554140127, 86.06687898089172, 85.46974522292994, 85.1015127388535, 84.67356687898089, 83.78781847133759, 82.71297770700637, 81.79737261146497, 80.72253184713377, 80.99124203821655, 78.86146496815286, 78.08519108280255]
lr_l_performance = [86.90286624203821, 85.04179936305732, 85.51950636942675, 85.74840764331209, 84.39490445859873, 86.76353503184714, 85.53941082802548, 86.59434713375796, 86.26592356687898, 86.43511146496814, 86.3156847133758, 85.77826433121018, 84.88256369426752, 84.22571656050955, 83.44944267515923, 82.94187898089172, 80.73248407643312, 79.65764331210191, 78.73208598726114, 77.5875796178344, 76.31369426751591]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'Binary CNN Result')
# Out:
# Text(0.5, 1.0, 'Binary CNN Result')

# %% [markdown]
# ### EPOCH = 20 Learning rate = 1e-3
# - IMDB-PRUNING-CNN-EMBEDDING-501

# %%
reinit_performance = [88.2265127388535, 88.25636942675159, 87.66918789808918, 87.609474522293, 87.390525477707, 87.52985668789809, 86.9625796178344, 87.07205414012739, 87.06210191082803, 86.67396496815286, 86.24601910828027, 86.01711783439491, 86.05692675159236, 85.15127388535032, 85.3702229299363, 85.04179936305732, 84.79299363057325, 83.3797770700637, 81.06090764331209, 83.8375796178344, 81.08081210191082]
lt_performance = [88.74402866242038, 87.98765923566879, 88.09713375796179, 87.84832802547771, 87.27109872611464, 87.11186305732484, 86.80334394904459, 86.79339171974523, 86.27587579617835, 85.52945859872611, 85.67874203821655, 84.90246815286623, 84.7531847133758, 84.45461783439491, 84.17595541401273, 82.82245222929936, 81.69785031847134, 80.04578025477707, 79.63773885350318, 78.82165605095541, 77.07006369426752]
lr_f_performance = [88.48527070063695, 87.97770700636943, 87.59952229299363, 87.25119426751591, 87.29100318471338, 87.45023885350318, 86.7734872611465, 87.14171974522293, 86.85310509554141, 86.25597133757962, 86.156449044586, 85.92754777070064, 85.29060509554141, 84.71337579617835, 83.52906050955414, 82.85230891719745, 81.56847133757962, 80.29458598726114, 79.69745222929936, 78.7420382165605, 77.72691082802548]
lr_l_performance = [87.62937898089172, 87.92794585987261, 88.28622611464968, 87.83837579617835, 87.47014331210191, 87.14171974522293, 87.08200636942675, 87.11186305732484, 87.34076433121018, 86.9327229299363, 86.24601910828027, 85.86783439490446, 84.8328025477707, 84.57404458598727, 84.30533439490446, 82.31488853503186, 81.30971337579618, 80.03582802547771, 78.36385350318471, 78.48328025477707, 77.24920382165605]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'Binary CNN Result')
# Out:
# Text(0.5, 1.0, 'Binary CNN Result')

# %% [markdown]
# ### EPOCH = 20 Learning rate = 5e-3 (채택)
# - gpu (IMDB-PRUNING-CNN-EMBEDDING-601)
# - 전반부는 1e-3보다 약간 성능이 떨어지지만, 후반부엔 1e-3보다 훨씬 성능 좋음

# %%
reinit_performance = [86.45501592356688, 85.62898089171973, 86.92277070063695, 86.79339171974523, 86.06687898089172, 86.23606687898089, 85.73845541401273, 85.28065286624204, 85.51950636942675, 84.87261146496814, 84.86265923566879, 84.74323248407643, 84.00676751592357, 83.98686305732484, 82.79259554140127, 82.65326433121018, 83.25039808917197, 77.34872611464968, 82.03622611464968, 81.40923566878982, 80.83200636942675]
lt_performance = [87.0421974522293, 86.56449044585987, 87.54976114649682, 86.95262738853503, 86.92277070063695, 86.21616242038218, 86.30573248407643, 85.77826433121018, 85.75835987261146, 85.17117834394905, 84.93232484076432, 84.30533439490446, 83.93710191082803, 84.1062898089172, 83.51910828025477, 81.88694267515923, 81.5187101910828, 80.56329617834395, 79.85668789808918, 77.46815286624204, 76.09474522292994]
lr_f_performance = [87.90804140127389, 87.46019108280255, 87.26114649681529, 87.37062101910828, 87.54976114649682, 86.3953025477707, 86.83320063694268, 86.97253184713377, 86.51472929936305, 86.40525477707006, 86.08678343949045, 85.92754777070064, 85.1015127388535, 84.66361464968153, 83.57882165605095, 83.04140127388536, 82.52388535031847, 80.94148089171973, 79.98606687898089, 79.04060509554141, 78.56289808917197]
lr_l_performance = [87.0421974522293, 87.56966560509554, 87.609474522293, 87.63933121019109, 87.62937898089172, 87.25119426751591, 86.71377388535032, 87.390525477707, 87.14171974522293, 87.10191082802548, 86.87300955414013, 86.45501592356688, 86.00716560509554, 85.14132165605095, 84.73328025477707, 83.69824840764332, 82.45421974522293, 81.41918789808918, 79.99601910828027, 78.86146496815286, 78.16480891719745]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'Binary CNN Result')
# Out:
# Text(0.5, 1.0, 'Binary CNN Result')

# %% [markdown]
# # AG_NEWS

# %% [markdown]
# ## Glove Embedding + No Early Stopping

# %% [markdown]
# ### EPOCH = 10 Learning rate = 1e-2
# - AGNEWS-PRUNING-CNN-101

# %%
reinit_performance = [89.6183473222396, 89.29009101971859, 89.34698881221419, 88.99684873949579, 89.01435572560094, 89.37324931641587, 89.25507704750831, 89.16316528280242, 89.3207283080125, 89.61397058823529, 89.53081234162596, 89.67086833064296, 89.60084033613445, 89.36011906431503, 88.93995099708813, 88.81740194408833, 88.37097337265976, 88.02083335002932, 87.7582283080125, 86.99229690207153, 84.84768907563026]
lt_performance = [89.67086833064296, 89.64898461053352, 89.90283613445378, 89.48266806722688, 89.55269606173539, 89.43890057692006, 89.57895656593708, 89.67086833064296, 89.70150561893688, 89.36887253232364, 89.16754201680672, 89.20693277310924, 88.47601538946648, 88.23529411764706, 87.97268907563026, 87.32492998868477, 86.00752799450851, 84.24807421299589, 82.75560225759234, 81.81897757434044, 75.51207983193278]
lr_f_performance = [89.3863795685167, 89.44765404492867, 89.35136554621849, 89.50455183742427, 89.58771008403362, 89.27696076761774, 89.50455183742427, 89.45203082902091, 89.69712883484465, 89.37324931641587, 89.36449579831933, 89.3251050420168, 88.703606459273, 88.30094537815127, 88.703606459273, 87.64005603910493, 86.6903011037522, 84.89145656593708, 82.30042016806722, 80.96113445378151, 78.95658261635724]
lr_l_performance = [89.79779411764706, 89.77153361344537, 89.87657563025209, 89.65336134453781, 89.67086833064296, 89.36887253232364, 89.44327731092437, 89.57020309792847, 90.06477589366817, 89.81967788784443, 89.62272410633183, 89.46953781512606, 89.29884453781513, 88.84366244829002, 88.08210782644127, 87.3030462184874, 85.92436974789915, 83.18014705882352, 79.38550420168067, 76.43995099708813, 75.03501402229821]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'Multi CNN Result')
# Out:
# Text(0.5, 1.0, 'Multi CNN Result')

# %% [markdown]
# ## Custom Embedding + Early Stopping

# %% [markdown]
# ### EPOCH = 20 Learning rate = 5e-3 (채택)
# - AGNEWS-PRUNING-CNN-401

# %%
reinit_performance = [87.57878151260505, 89.0012254735001, 88.28781512605042, 89.82405462184873, 89.72776612313855, 89.66649159663865, 89.87657563025209, 89.58771008403362, 89.86782211215557, 89.95973387686145, 89.80217085165137, 89.92034312055893, 89.73214285714286, 89.77153361344537, 89.44765404492867, 89.12815126050421, 88.64670866677741, 88.84366244829002, 88.19590336134453, 86.91789217355873, 67.08245798319328]
lt_performance = [88.5766806722689, 88.69047620717217, 89.28133755170998, 88.4453781512605, 89.73651959114716, 89.37324931641587, 89.78466386554622, 89.95098040885284, 89.58771008403362, 89.73214285714286, 90.02976192145789, 90.01663166935704, 89.93347337265976, 89.86344537815127, 89.33823529411765, 88.98809522139925, 87.6969537815126, 87.2986694844831, 85.37727589366817, 83.86729690207153, 79.04849438106312]
lr_f_performance = [88.43662463316396, 88.81740194408833, 88.83490898028141, 88.95745798319328, 89.22881654330662, 89.58771008403362, 89.63585435843268, 89.95973387686145, 90.02100840336135, 90.11292016806722, 90.25297620717217, 90.06477589366817, 90.22233891887825, 89.43890057692006, 89.14565824660934, 89.55707284582763, 88.8655462184874, 87.21551118778581, 84.02485992728161, 82.87815126050421, 81.4469537815126]
lr_l_performance = [88.33158261635724, 89.43890057692006, 89.33385856011334, 89.78466386554622, 89.81967788784443, 90.22233891887825, 90.23109243697479, 90.18294816257573, 89.97724091305453, 90.32738093568497, 90.29674369747899, 90.13480393826461, 89.71901260504201, 89.75402662734024, 89.75402662734024, 88.61169469456712, 87.86327032481923, 85.44292715417237, 84.24369747899159, 73.21866244829002, 72.39145656593708]

# %%
from matplotlib import pyplot as plt

frac = [0,0.2,0.36,0.488,0.59,0.672,0.738,0.79,0.832,0.866,0.893,0.914,0.931,0.945,0.956,0.965,0.972,0.977,0.982,0.986,0.988]

plt.plot(frac, reinit_performance)
plt.plot(frac, lt_performance)
plt.plot(frac, lr_f_performance)
plt.plot(frac, lr_l_performance)
plt.xlabel('Fraction of pruned weights')
plt.ylabel('Accuracy')
plt.legend(['random', 'lt', 'lt+lr(f)', 'lt+lr(l)'])
plt.title(f'Multi CNN Result')
# Out:
# Text(0.5, 1.0, 'Multi CNN Result')
