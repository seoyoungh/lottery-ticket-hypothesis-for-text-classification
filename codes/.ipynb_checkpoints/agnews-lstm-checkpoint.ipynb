# %% [markdown]
# [reference](https://github.com/bentrevett/pytorch-sentiment-analysis)

# %%
# Importing Libraries
import os
import copy
import time
import torch
import torch.nn as nn
import torchtext
from torchtext import data
from torchtext import datasets
from torchtext.vocab import GloVe
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/lt-module'
os.chdir(path)

# %%
# Custom Libraries
import DataLoader
import Model

# %% [markdown]
# ## Define functions - to load dataset & model

# %%
# load dataset
def load_dataset(dataset, architecture, batch_size, device, path):
    if dataset == "imdb":
      if architecture == "cnn":
        data = DataLoader.IMDB_CNN_CUSTOM(batch_size, device, path)
      elif architecture == "lstm":
        data = DataLoader.IMDB_LSTM(batch_size, device, path)

    elif dataset == "agnews":
        data = DataLoader.AGNEWS(batch_size, device, path)

    else:
        raise ValueError(dataset + "is not supported")

    return data

# load model and set hyperparameters
def load_model(architecture, data_choice, batch_size):

    if architecture == "cnn":
      # hyperparameters
      vocab_size = len(dataset.TEXT.vocab)
      embedding_dim = 100
      n_filters = 100
      filter_sizes = [3,4,5]
      dropout = 0.5
      pad_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.pad_token]
      
      if data_choice == "imdb":
        # binary-class
        output_dim = 1
        model = Model.binaryCNN(vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout, pad_idx)
      
      elif data_choice == "agnews":
        # multi-class
        output_dim = 4
        model = Model.multiCNN(vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout, pad_idx)

      unk_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.unk_token]
      model.embedding.weight.data[unk_idx] = torch.zeros(embedding_dim)
      model.embedding.weight.data[pad_idx] = torch.zeros(embedding_dim)

      return model

    elif architecture == "lstm":
      # hyperparameters
      vocab_size = len(dataset.TEXT.vocab)
      embedding_dim = 100
      hidden_dim = 256
      output_dim = 1
      n_layers = 2
      bidirectional = True
      dropout = 0.5
      pad_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.pad_token]
      
      if data_choice == "imdb":
        # binary-class
        output_dim = 1
      
      elif data_choice == "agnews":
        # multi-class
        output_dim = 4
      
      model = Model.LSTM(vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout, pad_idx)

      unk_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.unk_token]
      model.embedding.weight.data[unk_idx] = torch.zeros(embedding_dim)
      model.embedding.weight.data[pad_idx] = torch.zeros(embedding_dim)

      return model

    # temporary
    elif architecture == "bert":
        return None

    else:
        raise ValueError(architecture + "is not supported")

# %% [markdown]
# ## Weight initialization

# %%
# weight initializtion
def initialize_xavier_normal(m):
    
  """
	Function to initialize a layer by picking weights from a xavier normal distribution
	Arguments
	---------
	m : The layer of the neural network
	Returns
	-------
	None
	"""
  
  if type(m) == torch.nn.Conv2d:
    torch.nn.init.xavier_normal_(m.weight.data)
    m.bias.data.fill_(0)

  elif isinstance(m, torch.nn.Linear):
    torch.nn.init.xavier_normal_(m.weight.data)
    m.bias.data.fill_(0)

  elif type(m) in [torch.nn.GRU, torch.nn.LSTM, torch.nn.RNN]:
    for name, param in m.named_parameters():
        if 'weight_ih' in name:
          torch.nn.init.xavier_normal_(param.data)
        elif 'weight_hh' in name:
          torch.nn.init.orthogonal_(param.data)
        elif 'bias' in name:
          param.data.fill_(0)

# %% [markdown]
# ## train and test functions

# %%
def categorical_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """
    max_preds = preds.argmax(dim = 1, keepdim = True) # get the index of the max probability
    correct = max_preds.squeeze(1).eq(y)
    return correct.sum() / torch.FloatTensor([y.shape[0]])

# %%
def train(model, iterator, optimizer, criterion):
    # EPS = 1e-6
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for batch in iterator:
      
      optimizer.zero_grad()
      text, text_lengths = batch.text
      target = batch.label
      predictions = model(text, text_lengths).squeeze(1)
      loss = criterion(predictions, target)
      acc = categorical_accuracy(predictions, target)
      loss.backward()
      step = 0

      # Freezing Pruned weights by making their gradients Zero
      for name, p in model.named_parameters():
        weight_dev = param.device
        tensor = p.data.cpu().numpy()
        grad_tensor = p.grad.data.cpu().numpy()
        grad_tensor = np.where(mask[step] == 0, 0, grad_tensor)
        p.grad.data = torch.from_numpy(grad_tensor).to(device)
        step += 1
      
      step = 0

      optimizer.step()
        
      epoch_loss += loss.item()
      epoch_acc += acc.item()
      
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
          text, text_lengths = batch.text
          target = batch.label
          
          predictions = model(text, text_lengths).squeeze(1)
            
          loss = criterion(predictions, batch.label)
            
          acc = categorical_accuracy(predictions, batch.label)

          epoch_loss += loss.item()
          epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# ## Pruning Functions

# %%
# Prune by Percentile module
def prune_by_percentile(percent):
  global step
  global mask
  global model
  # Calculate percentile value
  step = 0
  for name, param in model.named_parameters():
    # if 'weight' in name:
    tensor = param.data.cpu().numpy()
    nz_count = np.count_nonzero(tensor)

    # bias가 all pruned 되는 경우 발생
    if nz_count == 0:
      step += 1

    else: 
      alive = tensor[np.nonzero(tensor)] # flattened array of nonzero values
      percentile_value = np.percentile(abs(alive), percent)

      # Convert Tensors to numpy and calculate
      weight_dev = param.device
      new_mask = np.where(abs(tensor) < percentile_value, 0, mask[step])
                
      # Apply new weight and mask
      param.data = torch.from_numpy(tensor * new_mask).to(weight_dev)
      mask[step] = new_mask
      step += 1

  step = 0

# %%
# Function to make an empty mask of the same size as the model
def make_mask(model):
  global step
  global mask
  
  step = 0
  for name, param in model.named_parameters(): 
    # if 'weight' in name:
    step += 1
  mask = [None]* step 
  step = 0
  for name, param in model.named_parameters(): 
    # if 'weight' in name:
    tensor = param.data.cpu().numpy()
    mask[step] = np.ones_like(tensor)
    step += 1
  step = 0

# %%
def original_initialization(mask_temp, initial_state_dict):
    global step
    global model
    
    step = 0
    for name, param in model.named_parameters(): 
        # if "weight" in name: 
            weight_dev = param.device
            param.data = torch.from_numpy(mask_temp[step] * initial_state_dict[name].cpu().numpy()).to(weight_dev)
            step = step + 1
        # if "bias" in name:
            # param.data = initial_state_dict[name]
    step = 0

# %%
# ANCHOR Print table of zeros and non-zeros count
def print_nonzeros(model):
    nonzero = total = 0
    for name, p in model.named_parameters():
        tensor = p.data.cpu().numpy()
        nz_count = np.count_nonzero(tensor)
        total_params = np.prod(tensor.shape)
        nonzero += nz_count
        total += total_params
        print(f'{name:20} | nonzeros = {nz_count:7} / {total_params:7} ({100 * nz_count / total_params:6.2f}%) | total_pruned = {total_params - nz_count :7} | shape = {tensor.shape}')
    print(f'alive: {nonzero}, pruned : {total - nonzero}, total: {total}, Compression rate : {total/nonzero:10.2f}x  ({100 * (total-nonzero) / total:6.2f}% pruned)')
    return (round(((total-nonzero)/total)*100,1))

# %% [markdown]
# ## Choose dataset & model

# %%
# colab에서 돌리기 때문에 우선 arg가 아니라 변수로 넘겨주기
data_choice = "agnews" # 데이터셋 선택
arch_choice = "lstm" # 모델 선택
batch_size = 64 # batch size 선택 - 32 or 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using {device} device.')
# Out:
# Using cuda device.

# %% [markdown]
# ### load dataset

# %%
dataset = load_dataset(data_choice, arch_choice, batch_size, device, path)

# %% [markdown]
# ### model setting

# %%
# check the trial number
trial = 201

# pruning setting
iteration = 20
percent = 20 # 20% prune
N_EPOCH = 10
learning_rate = 1e-3

step = 0

# %% [markdown]
# ## 1) random initialization

# %%
reinit = True # random이면 True, lt면 False
mode = 'random'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# embedding 같은 것 주기 위해
embedding_pretrained_weight = model.embedding.weight

# model initialization and save the model
model.apply(initialize_xavier_normal)
# Out:
# LSTM(
#   (embedding): Embedding(25002, 100, padding_idx=1)
#   (rnn): LSTM(100, 256, num_layers=2, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=512, out_features=4, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 4,812,396 trainable parameters

# %%
# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

criterion = criterion.to(device)

# %%
for name, param in model.named_parameters():
  print(name, param.size())
# Out:
# embedding.weight torch.Size([25002, 100])
# rnn.weight_ih_l0 torch.Size([1024, 100])
# rnn.weight_hh_l0 torch.Size([1024, 256])
# rnn.bias_ih_l0 torch.Size([1024])
# rnn.bias_hh_l0 torch.Size([1024])
# rnn.weight_ih_l0_reverse torch.Size([1024, 100])
# rnn.weight_hh_l0_reverse torch.Size([1024, 256])
# rnn.bias_ih_l0_reverse torch.Size([1024])
# rnn.bias_hh_l0_reverse torch.Size([1024])
# rnn.weight_ih_l1 torch.Size([1024, 512])
# rnn.weight_hh_l1 torch.Size([1024, 256])
# rnn.bias_ih_l1 torch.Size([1024])
# rnn.bias_hh_l1 torch.Size([1024])
# rnn.weight_ih_l1_reverse torch.Size([1024, 512])
# rnn.weight_hh_l1_reverse torch.Size([1024, 256])
# rnn.bias_ih_l1_reverse torch.Size([1024])
# rnn.bias_hh_l1_reverse torch.Size([1024])
# fc.weight torch.Size([4, 512])
# fc.bias torch.Size([4])

# %%
print(list(model.named_parameters()))
# Out:
# [('embedding.weight', Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.4133, -0.1122, -0.5961,  ...,  1.1373,  0.7257, -0.3588],
#         ...,
#         [ 0.3156,  0.5453, -0.4841,  ..., -0.6731, -0.0976,  0.4093],
#         [-0.7371, -0.1087,  0.1321,  ..., -0.1678,  0.1071,  0.3718],
#         [ 1.2929, -0.9231, -1.1145,  ...,  0.2666, -1.6894,  0.2001]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_ih_l0', Parameter containing:
# tensor([[-0.0182, -0.0061,  0.0979,  ...,  0.0072, -0.0296,  0.0094],
#         [-0.0077,  0.0336,  0.0634,  ..., -0.0570,  0.0152,  0.0356],
#         [-0.0317,  0.0618,  0.0462,  ...,  0.0386,  0.0099,  0.0388],
#         ...,
#         [ 0.0419, -0.0476,  0.0191,  ...,  0.0508, -0.0260,  0.0005],
#         [ 0.1052,  0.0882, -0.0405,  ...,  0.0046, -0.0149,  0.0206],
#         [ 0.0042,  0.0425,  0.0306,  ...,  0.0008, -0.0264, -0.0441]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_hh_l0', Parameter containing:
# tensor([[ 0.0454, -0.0098,  0.0096,  ..., -0.0011, -0.0123, -0.0651],
#         [ 0.0184, -0.0133,  0.0026,  ...,  0.0277,  0.0070,  0.0069],
#         [-0.0287, -0.0237,  0.0309,  ...,  0.0276, -0.0031,  0.0008],
#         ...,
#         [-0.0046, -0.0103, -0.0169,  ...,  0.0097,  0.0459, -0.0177],
#         [-0.0103, -0.0303, -0.0267,  ...,  0.0345,  0.0036,  0.0242],
#         [-0.0161, -0.0675,  0.0582,  ...,  0.0339, -0.0166,  0.0050]],
#        device='cuda:0', requires_grad=True)), ('rnn.bias_ih_l0', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.bias_hh_l0', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.weight_ih_l0_reverse', Parameter containing:
# tensor([[ 0.0124, -0.0211, -0.0175,  ...,  0.0096,  0.0536, -0.0073],
#         [ 0.0184, -0.0595, -0.0565,  ...,  0.0557,  0.0561,  0.0366],
#         [ 0.0407,  0.0339, -0.0292,  ...,  0.0365, -0.0479,  0.0453],
#         ...,
#         [ 0.0221, -0.0136, -0.0358,  ...,  0.0215, -0.0082, -0.0083],
#         [ 0.0644,  0.0201,  0.0618,  ..., -0.0444,  0.0050,  0.0250],
#         [-0.0027,  0.0011,  0.0338,  ..., -0.0500,  0.1025,  0.0641]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_hh_l0_reverse', Parameter containing:
# tensor([[-0.0327, -0.0074, -0.0474,  ...,  0.0135, -0.0131,  0.0097],
#         [-0.0122, -0.0078, -0.0169,  ..., -0.0250,  0.0394, -0.0291],
#         [ 0.0094,  0.0214, -0.0372,  ...,  0.0145, -0.0083,  0.0282],
#         ...,
#         [-0.0565, -0.0247, -0.0018,  ..., -0.0104,  0.0039,  0.0073],
#         [-0.0261, -0.0282,  0.0069,  ..., -0.0449,  0.0726,  0.0324],
#         [-0.0201,  0.0172,  0.0087,  ...,  0.0105,  0.0250,  0.0193]],
#        device='cuda:0', requires_grad=True)), ('rnn.bias_ih_l0_reverse', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.bias_hh_l0_reverse', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.weight_ih_l1', Parameter containing:
# tensor([[ 0.0057, -0.0250,  0.0141,  ..., -0.0508,  0.0745, -0.0162],
#         [ 0.0396,  0.0328,  0.0124,  ...,  0.0192, -0.0341, -0.0238],
#         [-0.0141,  0.0299, -0.0274,  ..., -0.0504, -0.0038,  0.0428],
#         ...,
#         [ 0.0482,  0.0038, -0.0258,  ...,  0.0132, -0.0075, -0.0166],
#         [ 0.0449, -0.0476,  0.0113,  ...,  0.0308,  0.0134,  0.0377],
#         [ 0.0123, -0.0385, -0.0270,  ...,  0.0142, -0.0512, -0.0161]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_hh_l1', Parameter containing:
# tensor([[ 0.0085, -0.0398,  0.0256,  ..., -0.0030,  0.0038,  0.0040],
#         [-0.0303,  0.0130, -0.0058,  ...,  0.0164,  0.0037,  0.0274],
#         [-0.0071, -0.0093,  0.0024,  ..., -0.0437, -0.0302,  0.0013],
#         ...,
#         [ 0.0220, -0.0564,  0.0008,  ...,  0.0593,  0.0002,  0.0254],
#         [-0.0219, -0.0103,  0.0044,  ...,  0.0380,  0.0275,  0.0008],
#         [ 0.0102,  0.0290,  0.0155,  ..., -0.0027,  0.0533,  0.0718]],
#        device='cuda:0', requires_grad=True)), ('rnn.bias_ih_l1', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.bias_hh_l1', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.weight_ih_l1_reverse', Parameter containing:
# tensor([[ 0.0092,  0.0229,  0.0252,  ...,  0.0505,  0.0276, -0.0341],
#         [-0.0438, -0.0826, -0.0214,  ...,  0.0170,  0.0331,  0.0114],
#         [ 0.0188,  0.0090,  0.0018,  ..., -0.0650,  0.0828, -0.0002],
#         ...,
#         [ 0.0686, -0.0509,  0.0363,  ...,  0.0201, -0.0813, -0.0325],
#         [-0.0124, -0.0244, -0.0184,  ...,  0.0099,  0.0976,  0.1005],
#         [ 0.0314,  0.0460,  0.0470,  ...,  0.0014, -0.0318, -0.0235]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_hh_l1_reverse', Parameter containing:
# tensor([[ 0.0592, -0.0122, -0.0124,  ..., -0.0115,  0.0036,  0.0163],
#         [-0.0159,  0.0187, -0.0236,  ..., -0.0140, -0.0186, -0.0054],
#         [ 0.0292, -0.0259, -0.0108,  ...,  0.0521, -0.0191, -0.0071],
#         ...,
#         [ 0.0551,  0.0313, -0.0476,  ..., -0.0375,  0.0379,  0.0413],
#         [ 0.0112, -0.0208, -0.0240,  ..., -0.0251, -0.0040, -0.0224],
#         [-0.0204,  0.0411,  0.0031,  ...,  0.0049, -0.0145, -0.0191]],
#        device='cuda:0', requires_grad=True)), ('rnn.bias_ih_l1_reverse', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.bias_hh_l1_reverse', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('fc.weight', Parameter containing:
# tensor([[-0.0177,  0.0433,  0.0440,  ...,  0.1090, -0.0046,  0.0214],
#         [-0.0797, -0.0157,  0.0680,  ...,  0.1578, -0.1548,  0.0502],
#         [ 0.0644,  0.0523, -0.0154,  ..., -0.0428, -0.0559,  0.0474],
#         [ 0.0439,  0.0687,  0.0776,  ..., -0.0158,  0.0118,  0.0300]],
#        device='cuda:0', requires_grad=True)), ('fc.bias', Parameter containing:
# tensor([0., 0., 0., 0.], device='cuda:0', requires_grad=True))]

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.46065060562763505 0.8416130106571936
# 1 0.3530784971965725 0.8776642984014209
# 2 0.3157103949955947 0.8911800621669627
# 3 0.288157759588311 0.90089365008881
# 4 0.2639991523727748 0.9088310390763765
# 5 0.263289320274367 0.9116896092362344
# 6 0.25418194656658977 0.9139376110124334
# 7 0.2661443572378921 0.9131882770870338
# 8 0.2517628838766373 0.9156860568383659
# 9 0.2579735633396075 0.9164076376554174
# 0.9167104343406293
# embedding.weight     | nonzeros = 2500100 / 2500200 (100.00%) | total_pruned =     100 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# fc.weight            | nonzeros =    2048 /    2048 (100.00%) | total_pruned =       0 | shape = (4, 512)
# fc.bias              | nonzeros =       4 /       4 (100.00%) | total_pruned =       0 | shape = (4,)
# alive: 4812296, pruned : 100, total: 4812396, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.28034260906742264 0.9101909413854352
# 1 0.2787794091144898 0.9147979573712256
# 2 0.2614981727757314 0.9162688721136767
# 3 0.26703867426085853 0.9155750444049734
# 4 0.2555282607469476 0.9192662078152753
# 5 0.2706182060786399 0.917767539964476
# 6 0.2708932807996578 0.9197935168738899
# 7 0.2911498078093806 0.9167406749555951
# 8 0.2524351515454864 0.9205706039076377
# 9 0.27358067152793414 0.9198767761989343
# 0.9199929973658394
# embedding.weight     | nonzeros = 2000080 / 2500200 ( 80.00%) | total_pruned =  500120 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# fc.weight            | nonzeros =    1638 /    2048 ( 79.98%) | total_pruned =     410 | shape = (4, 512)
# fc.bias              | nonzeros =       3 /       4 ( 75.00%) | total_pruned =       1 | shape = (4,)
# alive: 3849833, pruned : 962563, total: 4812396, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.2750121523158006 0.916934946714032
# 1 0.28617324846503894 0.9164353907637656
# 2 0.2674304959174001 0.9175177619893428
# 3 0.2636664155407496 0.9189331705150977
# 4 0.29007818055592255 0.9168794404973357
# 5 0.27541549792629044 0.918988676731794
# 6 0.28058975387106566 0.9197657637655418
# 7 0.2801128766610292 0.9191274422735346
# 8 0.28562228938276824 0.9204318383658969
# 9 0.2978634451372056 0.919821269982238
# 0.9172356444246629
# embedding.weight     | nonzeros = 1600064 / 2500200 ( 64.00%) | total_pruned =  900136 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# fc.weight            | nonzeros =    1310 /    2048 ( 63.96%) | total_pruned =     738 | shape = (4, 512)
# fc.bias              | nonzeros =       2 /       4 ( 50.00%) | total_pruned =       2 | shape = (4,)
# alive: 3079864, pruned : 1732532, total: 4812396, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.2857045482208896 0.9161578596802842
# 1 0.2825205844295994 0.9185446269982238
# 2 0.27624212620286914 0.9184613676731794
# 3 0.3091886090362845 0.916934946714032
# 4 0.3310292203402805 0.9149644760213144
# 5 0.3344901043882008 0.9181005772646537
# 6 0.32786144046890375 0.9163798845470693
# 7 0.34855536105141016 0.9172124777975134
# 8 0.3166194831949144 0.9182393428063943
# 9 0.334012394810681 0.9177952930728241
# 0.9154849438106313
# embedding.weight     | nonzeros = 1280051 / 2500200 ( 51.20%) | total_pruned = 1220149 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# fc.weight            | nonzeros =    1048 /    2048 ( 51.17%) | total_pruned =    1000 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2463888, pruned : 2348508, total: 4812396, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.2894926788434254 0.9160190941385435
# 1 0.31676257152249293 0.9135213143872114
# 2 0.33587182722456393 0.9173234902309059
# 3 0.3426602902238259 0.9122169182948491
# 4 0.3610527263573813 0.915297513321492
# 5 0.3600775999336323 0.9152420071047958
# 6 0.35977500813746854 0.9142428952042628
# 7 0.36720808314202524 0.9159080817051509
# 8 0.3930618190727665 0.9152697602131439
# 9 0.36997072915769913 0.9159358348134992
# 0.9144345236425641
# embedding.weight     | nonzeros = 1024041 / 2500200 ( 40.96%) | total_pruned = 1476159 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# fc.weight            | nonzeros =     838 /    2048 ( 40.92%) | total_pruned =    1210 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1971106, pruned : 2841290, total: 4812396, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.33328636542796347 0.9053619005328597
# 1 0.3304474620052595 0.9137710923623446
# 2 0.3630609841385383 0.9135490674955595
# 3 0.3792006410956118 0.9139931172291297
# 4 0.37273124111634326 0.9133547957371225
# 5 0.3736372633703172 0.9139931172291297
# 6 0.3996627971655681 0.9125499555950266
# 7 0.4015670416985852 0.9130217584369449
# 8 0.4111639071110351 0.9134103019538188
# 9 0.44524972337640517 0.9108570159857904
# 0.9111957284582763
# embedding.weight     | nonzeros =  819233 / 2500200 ( 32.77%) | total_pruned = 1680967 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# fc.weight            | nonzeros =     670 /    2048 ( 32.71%) | total_pruned =    1378 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1576880, pruned : 3235516, total: 4812396, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.34760084213295267 0.9109680284191829
# 1 0.3451678543409488 0.9125499555950266
# 2 0.3958330088382716 0.9106904973357016
# 3 0.39655566377628126 0.9103019538188277
# 4 0.4089354862513593 0.9113565719360568
# 5 0.42872580966281953 0.9097191385435168
# 6 0.4422473728749405 0.9115230905861457
# 7 0.43031886304177835 0.9104129662522202
# 8 0.4308299413248632 0.9092195825932504
# 9 0.5073511471730354 0.9098023978685613
# 0.9108018208952511
# embedding.weight     | nonzeros =  655386 / 2500200 ( 26.21%) | total_pruned = 1844814 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# fc.weight            | nonzeros =     536 /    2048 ( 26.17%) | total_pruned =    1512 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1261501, pruned : 3550895, total: 4812396, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.32017747182101275 0.9090808170515098
# 1 0.38781001438679535 0.9101631882770871
# 2 0.4141140175953534 0.9074156305506217
# 3 0.4147331705664286 0.9105794849023091
# 4 0.4256737838676249 0.9095248667850799
# 5 0.408785737342934 0.9122169182948491
# 6 0.43125926655573277 0.9104129662522202
# 7 0.4209173851965746 0.9116618561278863
# 8 0.47425112799041597 0.9106904973357016
# 9 0.481611964190263 0.9100521758436945
# 0.9079569327731093
# embedding.weight     | nonzeros =  524309 / 2500200 ( 20.97%) | total_pruned = 1975891 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# fc.weight            | nonzeros =     429 /    2048 ( 20.95%) | total_pruned =    1619 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1009195, pruned : 3803201, total: 4812396, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.3358696049664891 0.9086090142095915
# 1 0.4001373200483792 0.9064442717584369
# 2 0.41996139733593907 0.9083869893428064
# 3 0.44951753685214485 0.9082759769094139
# 4 0.43432747725509835 0.9101631882770871
# 5 0.4405420641770477 0.9085257548845471
# 6 0.4812953128027821 0.9081094582593251
# 7 0.49982829829330555 0.909136323268206
# 8 0.48745488703290585 0.9076931616341031
# 9 0.4754104249023867 0.9091918294849023
# 0.9083508403361344
# embedding.weight     | nonzeros =  419447 / 2500200 ( 16.78%) | total_pruned = 2080753 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# fc.weight            | nonzeros =     343 /    2048 ( 16.75%) | total_pruned =    1705 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 807353, pruned : 4005043, total: 4812396, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.3230728953514334 0.9096913854351687
# 1 0.35728071805678613 0.9097191385435168
# 2 0.3853282498172608 0.9090808170515098
# 3 0.4279872001649987 0.9091918294849023
# 4 0.47061266876148394 0.9074711367673179
# 5 0.43125874867586694 0.9076099023090586
# 6 0.4492419033772833 0.9087477797513321
# 7 0.4461725959322725 0.9097746447602132
# 8 0.47083122829276386 0.9098301509769094
# 9 0.45782866703634206 0.9069715808170515
# 0.9083508403361344
# embedding.weight     | nonzeros =  335557 / 2500200 ( 13.42%) | total_pruned = 2164643 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# fc.weight            | nonzeros =     274 /    2048 ( 13.38%) | total_pruned =    1774 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 645882, pruned : 4166514, total: 4812396, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.36565505489574657 0.9065830373001776
# 1 0.37964168894989664 0.9070548401420959
# 2 0.41971117839031913 0.9070270870337478
# 3 0.4316036161134552 0.9074156305506217
# 4 0.44696059502449487 0.9050843694493783
# 5 0.47689267965678794 0.9064997779751333
# 6 0.4467495650807346 0.9073046181172292
# 7 0.49683665695598556 0.9077486678507993
# 8 0.49541586062822945 0.9070270870337478
# 9 0.4740623618454588 0.9076931616341031
# 0.9082633051551691
# embedding.weight     | nonzeros =  268445 / 2500200 ( 10.74%) | total_pruned = 2231755 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# fc.weight            | nonzeros =     219 /    2048 ( 10.69%) | total_pruned =    1829 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 516697, pruned : 4295699, total: 4812396, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.35675680833218576 0.9055284191829485
# 1 0.3925241388274658 0.9053896536412078
# 2 0.3902042927700186 0.9053341474245116
# 3 0.41999869884635266 0.9053619005328597
# 4 0.42845817702966305 0.9052786412078153
# 5 0.46391641554384627 0.9059724689165186
# 6 0.4495850924301568 0.9061112344582594
# 7 0.4756677250508517 0.9063610124333925
# 8 0.4943444023990663 0.9065275310834814
# 9 0.4622044965143433 0.904196269982238
# 0.9058998597770178
# embedding.weight     | nonzeros =  214756 / 2500200 (  8.59%) | total_pruned = 2285444 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# fc.weight            | nonzeros =     175 /    2048 (  8.54%) | total_pruned =    1873 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 413356, pruned : 4399040, total: 4812396, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.35567019504973035 0.9028363676731794
# 1 0.37904566021050534 0.9052231349911191
# 2 0.40599287599225925 0.9050566163410302
# 3 0.43882644355303707 0.9047513321492007
# 4 0.429996505071993 0.9047790852575488
# 5 0.43365146067873517 0.9055006660746003
# 6 0.4478967733644809 0.904196269982238
# 7 0.4550936391608555 0.9042795293072824
# 8 0.4690379290949044 0.9044738010657194
# 9 0.4747044229119037 0.9047790852575488
# 0.906862745264999
# embedding.weight     | nonzeros =  171806 / 2500200 (  6.87%) | total_pruned = 2328394 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# fc.weight            | nonzeros =     140 /    2048 (  6.84%) | total_pruned =    1908 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 330679, pruned : 4481717, total: 4812396, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.37129562547294753 0.9013376998223801
# 1 0.3954484441332506 0.9039187388987566
# 2 0.40036199427810276 0.9049178507992895
# 3 0.4159562993086676 0.9032249111900533
# 4 0.4200145146490255 0.9052508880994672
# 5 0.44107470501273816 0.9055561722912966
# 6 0.44720317062063286 0.9035024422735346
# 7 0.4368071188524921 0.9049178507992895
# 8 0.459069536744119 0.9043350355239786
# 9 0.45975155888710895 0.90625
# 0.9058123250969318
# embedding.weight     | nonzeros =  137445 / 2500200 (  5.50%) | total_pruned = 2362755 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# fc.weight            | nonzeros =     112 /    2048 (  5.47%) | total_pruned =    1936 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 264540, pruned : 4547856, total: 4812396, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.3684960316873253 0.9014487122557726
# 1 0.3693154402255853 0.9029196269982238
# 2 0.38425486331365566 0.9035579484902309
# 3 0.4019087498716441 0.9036967140319716
# 4 0.4076317150979493 0.9035024422735346
# 5 0.4160177400319127 0.9028086145648313
# 6 0.4336320981333697 0.9031694049733571
# 7 0.4443882711721356 0.9035024422735346
# 8 0.44327158499575264 0.9027253552397868
# 9 0.4330999290464747 0.9031971580817052
# 0.9046306024078562
# embedding.weight     | nonzeros =  109956 / 2500200 (  4.40%) | total_pruned = 2390244 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# fc.weight            | nonzeros =      89 /    2048 (  4.35%) | total_pruned =    1959 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 211630, pruned : 4600766, total: 4812396, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.36963066587069104 0.8987566607460036
# 1 0.38228299278521094 0.899672513321492
# 2 0.40343344528856645 0.9015042184724689
# 3 0.4006772872993514 0.9004218472468917
# 4 0.41786102889697885 0.9011711811722913
# 5 0.41609582545311846 0.9014487122557726
# 6 0.4395502774213601 0.9018372557726465
# 7 0.42991939224765946 0.9018927619893428
# 8 0.42175919663650685 0.9004496003552398
# 9 0.43187101953373447 0.9002275754884547
# 0.9015231092436975
# embedding.weight     | nonzeros =   87965 / 2500200 (  3.52%) | total_pruned = 2412235 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# fc.weight            | nonzeros =      71 /    2048 (  3.47%) | total_pruned =    1977 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 169299, pruned : 4643097, total: 4812396, Compression rate :      28.43x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.3643950916327152 0.8979795737122558
# 1 0.38326966913241634 0.8985623889875666
# 2 0.38314891526505324 0.9001165630550622
# 3 0.40547310513962015 0.8998112788632326
# 4 0.4029518412029103 0.89925621669627
# 5 0.39752362252975654 0.8994504884547069
# 6 0.40141057466251073 0.8996447602131439
# 7 0.40349062630612254 0.899672513321492
# 8 0.4188431474805328 0.9000610568383659
# 9 0.4221988604296508 0.900088809946714
# 0.9006477589366817
# embedding.weight     | nonzeros =   70372 / 2500200 (  2.81%) | total_pruned = 2429828 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# fc.weight            | nonzeros =      57 /    2048 (  2.78%) | total_pruned =    1991 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 135436, pruned : 4676960, total: 4812396, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.3708105229112596 0.8934558170515098
# 1 0.39079746696932594 0.8946769538188277
# 2 0.3938999602779561 0.8952597690941385
# 3 0.40539637983149684 0.8960923623445826
# 4 0.40979622730565113 0.8954817939609236
# 5 0.4115290210167108 0.8975632770870338
# 6 0.410285359797718 0.8967029307282416
# 7 0.4165347898759437 0.8973690053285968
# 8 0.4202116040585705 0.8968139431616341
# 9 0.4296411497429093 0.8975632770870338
# 0.8949579831932774
# embedding.weight     | nonzeros =   56297 / 2500200 (  2.25%) | total_pruned = 2443903 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# fc.weight            | nonzeros =      45 /    2048 (  2.20%) | total_pruned =    2003 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 108343, pruned : 4704053, total: 4812396, Compression rate :      44.42x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.38161268344291255 0.8893761101243339
# 1 0.3946155103098859 0.8929007548845471
# 2 0.4027632495775475 0.8934558170515098
# 3 0.41332705133490355 0.893511323268206
# 4 0.4124806995617745 0.8945659413854352
# 5 0.41962179450936893 0.8945659413854352
# 6 0.41959721752943646 0.8939553730017762
# 7 0.4163992428344875 0.8942329040852576
# 8 0.4249385951076953 0.8940386323268206
# 9 0.43029266677558636 0.8952875222024866
# 0.8963147757434043
# embedding.weight     | nonzeros =   45037 / 2500200 (  1.80%) | total_pruned = 2455163 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# fc.weight            | nonzeros =      36 /    2048 (  1.76%) | total_pruned =    2012 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 86670, pruned : 4725726, total: 4812396, Compression rate :      55.53x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.374069256059574 0.8872391207815276
# 1 0.3928415995524604 0.890208703374778
# 2 0.3984753853917704 0.8904307282415631
# 3 0.40433517659370843 0.8910968028419183
# 4 0.40562152308552507 0.8916796181172292
# 5 0.4086026188555185 0.8907637655417406
# 6 0.404014180123237 0.8919016429840142
# 7 0.4126244274052406 0.8914298401420959
# 8 0.4229789757125119 0.8930117673179396
# 9 0.4259929670580062 0.8919016429840142
# 0.8925070026341606
# embedding.weight     | nonzeros =   36029 / 2500200 (  1.44%) | total_pruned = 2464171 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# fc.weight            | nonzeros =      29 /    2048 (  1.42%) | total_pruned =    2019 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 69331, pruned : 4743065, total: 4812396, Compression rate :      69.41x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.39097858427446436 0.8801343250444049
# 1 0.40690290234771226 0.8837422291296625
# 2 0.41572224331910507 0.8836034635879219
# 3 0.4249639643412447 0.88363121669627
# 4 0.4261497806155555 0.8850188721136767
# 5 0.42658190757406755 0.8846303285968028
# 6 0.42657698844071495 0.8856294404973357
# 7 0.43540667025058083 0.8859347246891652
# 8 0.44241465163147525 0.8844083037300178
# 9 0.44278307254450994 0.8856571936056838
# 0.8881740194408834
# embedding.weight     | nonzeros =   28823 / 2500200 (  1.15%) | total_pruned = 2471377 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# fc.weight            | nonzeros =      23 /    2048 (  1.12%) | total_pruned =    2025 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 55459, pruned : 4756937, total: 4812396, Compression rate :      86.77x  ( 98.85% pruned)

# %%
# random
print(performance)
print(valid_losses)

reinit_performance = performance
reinit_valid_losses = valid_losses
# Out:
# [91.67104343406292, 91.99929973658394, 91.72356444246628, 91.54849438106312, 91.4434523642564, 91.11957284582763, 91.08018208952511, 90.79569327731093, 90.83508403361344, 90.83508403361344, 90.8263305155169, 90.58998597770179, 90.6862745264999, 90.58123250969318, 90.46306024078562, 90.15231092436974, 90.06477589366817, 89.49579831932773, 89.63147757434044, 89.25070026341606, 88.81740194408833]
# [0.2579735633396075, 0.27358067152793414, 0.2978634451372056, 0.334012394810681, 0.36997072915769913, 0.44524972337640517, 0.5073511471730354, 0.481611964190263, 0.4754104249023867, 0.45782866703634206, 0.4740623618454588, 0.4622044965143433, 0.4747044229119037, 0.45975155888710895, 0.4330999290464747, 0.43187101953373447, 0.4221988604296508, 0.4296411497429093, 0.43029266677558636, 0.4259929670580062, 0.44278307254450994]

# %% [markdown]
# ## 2) lt

# %%
reinit = False # random이면 True, lt면 False
mode = 'lt'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)
initial_state_dict = copy.deepcopy(model.state_dict())

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

criterion = criterion.to(device)

# %%
for name, param in model.named_parameters():
  print(name, param.size())
# Out:
# embedding.weight torch.Size([25002, 100])
# rnn.weight_ih_l0 torch.Size([1024, 100])
# rnn.weight_hh_l0 torch.Size([1024, 256])
# rnn.bias_ih_l0 torch.Size([1024])
# rnn.bias_hh_l0 torch.Size([1024])
# rnn.weight_ih_l0_reverse torch.Size([1024, 100])
# rnn.weight_hh_l0_reverse torch.Size([1024, 256])
# rnn.bias_ih_l0_reverse torch.Size([1024])
# rnn.bias_hh_l0_reverse torch.Size([1024])
# rnn.weight_ih_l1 torch.Size([1024, 512])
# rnn.weight_hh_l1 torch.Size([1024, 256])
# rnn.bias_ih_l1 torch.Size([1024])
# rnn.bias_hh_l1 torch.Size([1024])
# rnn.weight_ih_l1_reverse torch.Size([1024, 512])
# rnn.weight_hh_l1_reverse torch.Size([1024, 256])
# rnn.bias_ih_l1_reverse torch.Size([1024])
# rnn.bias_hh_l1_reverse torch.Size([1024])
# fc.weight torch.Size([4, 512])
# fc.bias torch.Size([4])

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  count = 0
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.4425300905914385 0.8448046181172292
# 1 0.34368463854436127 0.8834646980461812
# 2 0.2967500912875837 0.8958425843694494
# 3 0.2879317391193993 0.9011156749555951
# 4 0.2766686928810859 0.9068883214920072
# 5 0.2941314962727297 0.9080261989342806
# 6 0.2592108170890628 0.9151032415630551
# 7 0.24688043241880397 0.916934946714032
# 8 0.24764901322526048 0.9180450710479574
# 9 0.25478339226019847 0.9182115896980462
# 0.9174982494666797
# embedding.weight     | nonzeros = 2500100 / 2500200 (100.00%) | total_pruned =     100 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# fc.weight            | nonzeros =    2048 /    2048 (100.00%) | total_pruned =       0 | shape = (4, 512)
# fc.bias              | nonzeros =       4 /       4 (100.00%) | total_pruned =       0 | shape = (4,)
# alive: 4812296, pruned : 100, total: 4812396, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.3740230470591392 0.8698656749555951
# 1 0.32197350958696375 0.8909580373001776
# 2 0.2902730982386727 0.9013654529307282
# 3 0.28182391790577194 0.9077764209591475
# 4 0.28211806146146773 0.9121059058614565
# 5 0.26086681677594276 0.9133825488454707
# 6 0.27054346957265485 0.9136323268206039
# 7 0.27219264510006613 0.9123001776198935
# 8 0.25257105886817083 0.9184336145648313
# 9 0.25439854130665 0.9187388987566607
# 0.9187675068358413
# embedding.weight     | nonzeros = 2000080 / 2500200 ( 80.00%) | total_pruned =  500120 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# fc.weight            | nonzeros =    1638 /    2048 ( 79.98%) | total_pruned =     410 | shape = (4, 512)
# fc.bias              | nonzeros =       3 /       4 ( 75.00%) | total_pruned =       1 | shape = (4,)
# alive: 3849833, pruned : 962563, total: 4812396, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.3382138328008076 0.8854906749555951
# 1 0.3079185387116342 0.8965364120781527
# 2 0.2894700956572224 0.9071103463587922
# 3 0.30529061900732996 0.9056116785079928
# 4 0.2786160830150277 0.9102464476021315
# 5 0.262984973390059 0.9129384991119005
# 6 0.26531185232910126 0.9167129218472468
# 7 0.25192519934553503 0.9167129218472468
# 8 0.26138752258877346 0.9162688721136767
# 9 0.25063009309991 0.9191274422735346
# 0.9182422967518077
# embedding.weight     | nonzeros = 1600064 / 2500200 ( 64.00%) | total_pruned =  900136 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# fc.weight            | nonzeros =    1310 /    2048 ( 63.96%) | total_pruned =     738 | shape = (4, 512)
# fc.bias              | nonzeros =       2 /       4 ( 50.00%) | total_pruned =       2 | shape = (4,)
# alive: 3079864, pruned : 1732532, total: 4812396, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.3210752734064156 0.8923456927175843
# 1 0.3061053598759494 0.9037522202486679
# 2 0.30064043427154186 0.9048068383658969
# 3 0.26796501142437673 0.9129107460035524
# 4 0.2650232323764643 0.9140763765541741
# 5 0.27103668975364253 0.9149367229129662
# 6 0.2661422386394936 0.9151032415630551
# 7 0.271723017533232 0.9159913410301954
# 8 0.24884088992490228 0.9184891207815276
# 9 0.26199866418245366 0.9186001332149201
# 0.9188988093568498
# embedding.weight     | nonzeros = 1280051 / 2500200 ( 51.20%) | total_pruned = 1220149 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# fc.weight            | nonzeros =    1048 /    2048 ( 51.17%) | total_pruned =    1000 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2463888, pruned : 2348508, total: 4812396, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.30616769293524976 0.8931505328596803
# 1 0.2914782828067431 0.9035024422735346
# 2 0.2756957107489899 0.9095248667850799
# 3 0.2953398209561463 0.91160634991119
# 4 0.2848284492537141 0.9121336589698046
# 5 0.2685149228216859 0.9141318827708703
# 6 0.26525552340553243 0.917351243339254
# 7 0.2547106584319001 0.9183226021314387
# 8 0.25690454855018674 0.9174622557726465
# 9 0.25844997642677586 0.9188221580817052
# 0.9178046218487395
# embedding.weight     | nonzeros = 1024041 / 2500200 ( 40.96%) | total_pruned = 1476159 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# fc.weight            | nonzeros =     838 /    2048 ( 40.92%) | total_pruned =    1210 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1971106, pruned : 2841290, total: 4812396, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.311025131000851 0.8953152753108348
# 1 0.2760757481841433 0.9064997779751333
# 2 0.2851400387739733 0.9067218028419183
# 3 0.26737872231255416 0.9106904973357016
# 4 0.28611511132327533 0.9096358792184724
# 5 0.28233029254005815 0.9138543516873889
# 6 0.26013924749022216 0.9160468472468917
# 7 0.2618275068065095 0.9175177619893428
# 8 0.2557520132022207 0.9175455150976909
# 9 0.2707624379512366 0.9160190941385435
# 0.9129464285714286
# embedding.weight     | nonzeros =  819233 / 2500200 ( 32.77%) | total_pruned = 1680967 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# fc.weight            | nonzeros =     670 /    2048 ( 32.71%) | total_pruned =    1378 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1576880, pruned : 3235516, total: 4812396, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.30798600939289394 0.891457593250444
# 1 0.28625364793500935 0.9027531083481349
# 2 0.28933882574694725 0.9073046181172292
# 3 0.26403380967478135 0.9106627442273535
# 4 0.26263876069092307 0.9132715364120781
# 5 0.26101341946497164 0.9147146980461812
# 6 0.25910766984519695 0.9154362788632326
# 7 0.26146066757531083 0.9171847246891652
# 8 0.2728247063244374 0.9172402309058615
# 9 0.25693596065289226 0.9189331705150977
# 0.9165353639786985
# embedding.weight     | nonzeros =  655386 / 2500200 ( 26.21%) | total_pruned = 1844814 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# fc.weight            | nonzeros =     536 /    2048 ( 26.17%) | total_pruned =    1512 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1261501, pruned : 3550895, total: 4812396, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.31097993729421025 0.8950099911190054
# 1 0.2799307760016639 0.9040575044404974
# 2 0.2710750855366513 0.9086367673179396
# 3 0.26609011609802025 0.9102464476021315
# 4 0.25965795337948716 0.9131605239786856
# 5 0.2609200569078141 0.9137710923623446
# 6 0.2717987175412198 0.9145759325044405
# 7 0.25442127462767633 0.917351243339254
# 8 0.26501721237020215 0.9158803285968028
# 9 0.2641534540623585 0.9164353907637656
# 0.9168417368616376
# embedding.weight     | nonzeros =  524309 / 2500200 ( 20.97%) | total_pruned = 1975891 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# fc.weight            | nonzeros =     429 /    2048 ( 20.95%) | total_pruned =    1619 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1009195, pruned : 3803201, total: 4812396, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.29532115943531373 0.895148756660746
# 1 0.27679254100732437 0.9047790852575488
# 2 0.27640548869504283 0.9077209147424512
# 3 0.2678648935925368 0.9099134103019538
# 4 0.26455340360425295 0.9105239786856127
# 5 0.26771698241679537 0.9139098579040853
# 6 0.2660493349811959 0.9141596358792184
# 7 0.26759568897289343 0.9134103019538188
# 8 0.25808161792889583 0.9161856127886323
# 9 0.2589743698419437 0.9171569715808171
# 0.9187237394957983
# embedding.weight     | nonzeros =  419447 / 2500200 ( 16.78%) | total_pruned = 2080753 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# fc.weight            | nonzeros =     343 /    2048 ( 16.75%) | total_pruned =    1705 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 807353, pruned : 4005043, total: 4812396, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.30847670902790864 0.8944271758436945
# 1 0.2951945830335043 0.9031138987566607
# 2 0.28595681240878085 0.9074988898756661
# 3 0.27534311776567205 0.9089975577264654
# 4 0.26916168214749964 0.9112455595026643
# 5 0.2711143968180219 0.9115785968028419
# 6 0.2657008375501058 0.9131882770870338
# 7 0.27491079187963563 0.9142428952042628
# 8 0.25502044595050133 0.9154362788632326
# 9 0.265988693944779 0.9152142539964476
# 0.9149159663865546
# embedding.weight     | nonzeros =  335557 / 2500200 ( 13.42%) | total_pruned = 2164643 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# fc.weight            | nonzeros =     274 /    2048 ( 13.38%) | total_pruned =    1774 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 645882, pruned : 4166514, total: 4812396, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.3130575316771203 0.8897646536412078
# 1 0.2893200862729264 0.8995615008880995
# 2 0.2810871117015503 0.9048623445825933
# 3 0.27619254363115153 0.9076376554174067
# 4 0.2762308025659851 0.9091918294849023
# 5 0.27377131482715295 0.9097468916518651
# 6 0.26931336978996306 0.9083592362344582
# 7 0.261087884828713 0.9119116341030196
# 8 0.2778633607346333 0.9114120781527532
# 9 0.26559453369589725 0.9124944493783304
# 0.9132090336134454
# embedding.weight     | nonzeros =  268445 / 2500200 ( 10.74%) | total_pruned = 2231755 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# fc.weight            | nonzeros =     219 /    2048 ( 10.69%) | total_pruned =    1829 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 516697, pruned : 4295699, total: 4812396, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.32091804931261186 0.8853519094138543
# 1 0.2942987920097729 0.8985068827708703
# 2 0.2841762436395031 0.9015319715808171
# 3 0.282986669240397 0.9042795293072824
# 4 0.27424362090583326 0.9067495559502664
# 5 0.27640514964896185 0.9066107904085258
# 6 0.26758559021708384 0.9108570159857904
# 7 0.27031771204108457 0.9114398312611013
# 8 0.2702002937063495 0.9114675843694494
# 9 0.2676521922688316 0.9136045737122558
# 0.9136029411764706
# embedding.weight     | nonzeros =  214756 / 2500200 (  8.59%) | total_pruned = 2285444 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# fc.weight            | nonzeros =     175 /    2048 (  8.54%) | total_pruned =    1873 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 413356, pruned : 4399040, total: 4812396, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.3340171464118398 0.8837699822380106
# 1 0.307776429893889 0.8937333481349912
# 2 0.29904319709878197 0.8977020426287744
# 3 0.28840413164234924 0.9020870337477798
# 4 0.2828596521261583 0.9034746891651865
# 5 0.2863258436606737 0.905417406749556
# 6 0.2775015227172398 0.9062222468916519
# 7 0.27327249898057476 0.9076099023090586
# 8 0.27797557720765603 0.9078319271758437
# 9 0.2753369511397916 0.908720026642984
# 0.9086572127181942
# embedding.weight     | nonzeros =  171805 / 2500200 (  6.87%) | total_pruned = 2328395 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# fc.weight            | nonzeros =     140 /    2048 (  6.84%) | total_pruned =    1908 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 330678, pruned : 4481718, total: 4812396, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.3430014405578216 0.8784968916518651
# 1 0.3161448765592401 0.8903752220248667
# 2 0.3089278335608608 0.8950932504440497
# 3 0.29652894838989363 0.8979240674955595
# 4 0.29059378825935334 0.9007548845470693
# 5 0.2976935990121659 0.9016984902309059
# 6 0.2897011513456199 0.9035579484902309
# 7 0.2881578466396772 0.904196269982238
# 8 0.2843689674008671 0.9055006660746003
# 9 0.28526257577999026 0.9053619005328597
# 0.9051120446509674
# embedding.weight     | nonzeros =  137444 / 2500200 (  5.50%) | total_pruned = 2362756 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# fc.weight            | nonzeros =     112 /    2048 (  5.47%) | total_pruned =    1936 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 264539, pruned : 4547857, total: 4812396, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.34315880714894187 0.8773312611012434
# 1 0.32574072117267133 0.8880439609236235
# 2 0.3129688861149613 0.8929562611012434
# 3 0.3060684305041711 0.8940108792184724
# 4 0.3003477121109464 0.8987844138543517
# 5 0.3001966219904897 0.8982293516873889
# 6 0.2994074606490495 0.8993949822380106
# 7 0.29294451671200894 0.9002275754884547
# 8 0.2951324080327132 0.9015042184724689
# 9 0.2939089261124417 0.9026976021314387
# 0.9033613445378151
# embedding.weight     | nonzeros =  109955 / 2500200 (  4.40%) | total_pruned = 2390245 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# fc.weight            | nonzeros =      89 /    2048 (  4.35%) | total_pruned =    1959 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 211629, pruned : 4600767, total: 4812396, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.3648311295819537 0.8699211811722913
# 1 0.33626365713894263 0.8827431172291297
# 2 0.3221791813623153 0.8871836145648313
# 3 0.32028117727944844 0.8883214920071048
# 4 0.3115756373247049 0.8925954706927176
# 5 0.3076842819203227 0.8945104351687388
# 6 0.3057171013437833 0.8956483126110124
# 7 0.30455498256245844 0.8968972024866785
# 8 0.29939339535400195 0.8971192273534636
# 9 0.29952694776552347 0.8978685612788633
# 0.8985031512605042
# embedding.weight     | nonzeros =   87964 / 2500200 (  3.52%) | total_pruned = 2412236 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# fc.weight            | nonzeros =      71 /    2048 (  3.47%) | total_pruned =    1977 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 169298, pruned : 4643098, total: 4812396, Compression rate :      28.43x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.3841814420733528 0.8648978685612788
# 1 0.34517355467694055 0.8786634103019538
# 2 0.3359748233344611 0.8834091918294849
# 3 0.3315252660216224 0.8861289964476021
# 4 0.3234165693082405 0.8889043072824157
# 5 0.3183495800985192 0.8898756660746003
# 6 0.31329444202480317 0.8917628774422736
# 7 0.31391738526536345 0.8912910746003553
# 8 0.3124682943371404 0.8919293960923623
# 9 0.3082628239667437 0.8940108792184724
# 0.8921130950711355
# embedding.weight     | nonzeros =   70371 / 2500200 (  2.81%) | total_pruned = 2429829 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# fc.weight            | nonzeros =      57 /    2048 (  2.78%) | total_pruned =    1991 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 135435, pruned : 4676961, total: 4812396, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.3928024332745408 0.8618172735346359
# 1 0.367866076390072 0.86964365008881
# 2 0.35418588847093957 0.8752220248667851
# 3 0.34710839933998633 0.8784691385435168
# 4 0.3417851677525054 0.8821047957371225
# 5 0.34299275774316823 0.8843527975133215
# 6 0.3341121288648348 0.8853796625222025
# 7 0.3328700461482785 0.8851853907637656
# 8 0.328049814272308 0.8883492451154529
# 9 0.3295927064536308 0.8863787744227354
# 0.8812587536683604
# embedding.weight     | nonzeros =   56297 / 2500200 (  2.25%) | total_pruned = 2443903 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# fc.weight            | nonzeros =      45 /    2048 (  2.20%) | total_pruned =    2003 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 108343, pruned : 4704053, total: 4812396, Compression rate :      44.42x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.422595479983843 0.8496614120781527
# 1 0.3876031333213378 0.8602353463587922
# 2 0.3794349734911275 0.8653696714031972
# 3 0.37282573791025586 0.8696991563055062
# 4 0.36387843973140627 0.8723912078152753
# 5 0.35812182527293535 0.8743339253996447
# 6 0.357328088034348 0.8767761989342806
# 7 0.3586373504773973 0.8765819271758437
# 8 0.3485330917523449 0.8799678063943162
# 9 0.34389051455561054 0.8796070159857904
# 0.8753939075630253
# embedding.weight     | nonzeros =   45037 / 2500200 (  1.80%) | total_pruned = 2455163 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# fc.weight            | nonzeros =      36 /    2048 (  1.76%) | total_pruned =    2012 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 86670, pruned : 4725726, total: 4812396, Compression rate :      55.53x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.4454272083316137 0.8413077264653641
# 1 0.4081904989887247 0.8557393428063943
# 2 0.3937895301444916 0.8619560390763765
# 3 0.3821646519647134 0.8658137211367674
# 4 0.3807075092201758 0.8679784635879219
# 5 0.3755179845345857 0.8691163410301954
# 6 0.37038606632216364 0.8710868117229129
# 7 0.3679616307065579 0.8711700710479574
# 8 0.36703075122147744 0.8710868117229129
# 9 0.3646020691587092 0.8712255772646537
# 0.8631827731092437
# embedding.weight     | nonzeros =   36029 / 2500200 (  1.44%) | total_pruned = 2464171 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# fc.weight            | nonzeros =      29 /    2048 (  1.42%) | total_pruned =    2019 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 69331, pruned : 4743065, total: 4812396, Compression rate :      69.41x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.4796358580778801 0.8315386323268206
# 1 0.44345771213646046 0.8436667406749556
# 2 0.4280866638229594 0.84910634991119
# 3 0.4158662282042933 0.8536856127886323
# 4 0.40855923863739885 0.8563499111900533
# 5 0.4004996890933327 0.8585146536412078
# 6 0.40055562006590845 0.8603186056838366
# 7 0.39867158211952947 0.8608459147424512
# 8 0.3903196523558236 0.8626221136767318
# 9 0.39220759259672505 0.8642873001776199
# 0.8566176470588235
# embedding.weight     | nonzeros =   28823 / 2500200 (  1.15%) | total_pruned = 2471377 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# fc.weight            | nonzeros =      23 /    2048 (  1.12%) | total_pruned =    2025 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 55459, pruned : 4756937, total: 4812396, Compression rate :      86.77x  ( 98.85% pruned)

# %%
# lt
print(performance)
print(valid_losses)
lt_performance = performance
lt_valid_losses = valid_losses
# Out:
# [91.74982494666797, 91.87675068358413, 91.82422967518077, 91.88988093568497, 91.78046218487394, 91.29464285714286, 91.65353639786986, 91.68417368616376, 91.87237394957984, 91.49159663865547, 91.32090336134453, 91.36029411764706, 90.86572127181942, 90.51120446509674, 90.33613445378151, 89.85031512605042, 89.21130950711354, 88.12587536683604, 87.53939075630252, 86.31827731092437, 85.66176470588235]
# [0.25478339226019847, 0.25439854130665, 0.25063009309991, 0.26199866418245366, 0.25844997642677586, 0.2707624379512366, 0.25693596065289226, 0.2641534540623585, 0.2589743698419437, 0.265988693944779, 0.26559453369589725, 0.2676521922688316, 0.2753369511397916, 0.28526257577999026, 0.2939089261124417, 0.29952694776552347, 0.3082628239667437, 0.3295927064536308, 0.34389051455561054, 0.3646020691587092, 0.39220759259672505]

# %% [markdown]
# ## 3) lt+lr (last epoch)

# %%
reinit = False # random이면 True, lt면 False
mode = 'lr_l'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

criterion = criterion.to(device)

# %%
for name, param in model.named_parameters():
  print(name, param.size())
# Out:
# embedding.weight torch.Size([25002, 100])
# rnn.weight_ih_l0 torch.Size([1024, 100])
# rnn.weight_hh_l0 torch.Size([1024, 256])
# rnn.bias_ih_l0 torch.Size([1024])
# rnn.bias_hh_l0 torch.Size([1024])
# rnn.weight_ih_l0_reverse torch.Size([1024, 100])
# rnn.weight_hh_l0_reverse torch.Size([1024, 256])
# rnn.bias_ih_l0_reverse torch.Size([1024])
# rnn.bias_hh_l0_reverse torch.Size([1024])
# rnn.weight_ih_l1 torch.Size([1024, 512])
# rnn.weight_hh_l1 torch.Size([1024, 256])
# rnn.bias_ih_l1 torch.Size([1024])
# rnn.bias_hh_l1 torch.Size([1024])
# rnn.weight_ih_l1_reverse torch.Size([1024, 512])
# rnn.weight_hh_l1_reverse torch.Size([1024, 256])
# rnn.bias_ih_l1_reverse torch.Size([1024])
# rnn.bias_hh_l1_reverse torch.Size([1024])
# fc.weight torch.Size([4, 512])
# fc.bias torch.Size([4])

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)
  
  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  # late rewinding after the last epoch
  if pruning_iter == 0:
     initial_state_dict = copy.deepcopy(model.state_dict())

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.43145262798357287 0.8448601243339254
# 1 0.3526589562934468 0.8822990674955595
# 2 0.3373533128156967 0.8864897868561279
# 3 0.29217160249304286 0.9013654529307282
# 4 0.269145242290879 0.9060002220248667
# 5 0.2561660493669459 0.9128829928952042
# 6 0.25366810691041697 0.9154085257548845
# 7 0.2626210951823642 0.9137433392539964
# 8 0.25327873740140117 0.9176287744227354
# 9 0.2571922519159889 0.9182115896980462
# 0.9155287116515536
# embedding.weight     | nonzeros = 2500100 / 2500200 (100.00%) | total_pruned =     100 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# fc.weight            | nonzeros =    2048 /    2048 (100.00%) | total_pruned =       0 | shape = (4, 512)
# fc.bias              | nonzeros =       4 /       4 (100.00%) | total_pruned =       0 | shape = (4,)
# alive: 4812296, pruned : 100, total: 4812396, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.2471831961903807 0.9182670959147424
# 1 0.25817342880669963 0.9209036412078153
# 2 0.2528989342823757 0.9222080373001776
# 3 0.24912557309595984 0.9207926287744227
# 4 0.2572761394851055 0.9208481349911191
# 5 0.27161355092327505 0.9222357904085258
# 6 0.25977700913976715 0.9217917406749556
# 7 0.2816413243302867 0.9199322824156305
# 8 0.2627016435481515 0.9190164298401421
# 9 0.27851588419947915 0.9200710479573713
# 0.9220938377019738
# embedding.weight     | nonzeros = 2000080 / 2500200 ( 80.00%) | total_pruned =  500120 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# fc.weight            | nonzeros =    1638 /    2048 ( 79.98%) | total_pruned =     410 | shape = (4, 512)
# fc.bias              | nonzeros =       3 /       4 ( 75.00%) | total_pruned =       1 | shape = (4,)
# alive: 3849833, pruned : 962563, total: 4812396, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.24786786503137004 0.9208203818827708
# 1 0.2651356084381444 0.9192384547069272
# 2 0.25867829582989743 0.9219027531083481
# 3 0.25650787457731117 0.9209591474245116
# 4 0.27350776976215957 0.9198767761989343
# 5 0.2556181036756369 0.9221802841918295
# 6 0.2719155062208379 0.9207371225577264
# 7 0.2742390517396836 0.9208203818827708
# 8 0.2768649340592338 0.9208481349911191
# 9 0.2837045765192402 0.919821269982238
# 0.9226190477860075
# embedding.weight     | nonzeros = 1600064 / 2500200 ( 64.00%) | total_pruned =  900136 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# fc.weight            | nonzeros =    1310 /    2048 ( 63.96%) | total_pruned =     738 | shape = (4, 512)
# fc.bias              | nonzeros =       2 /       4 ( 50.00%) | total_pruned =       2 | shape = (4,)
# alive: 3079864, pruned : 1732532, total: 4812396, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.25879714627076955 0.9187388987566607
# 1 0.2660799808535546 0.9199045293072824
# 2 0.2531532700476278 0.9222357904085258
# 3 0.2712373702983714 0.9192384547069272
# 4 0.26723080251835696 0.9211534191829485
# 5 0.2896303308839855 0.9201265541740675
# 6 0.2790348091316583 0.9205428507992895
# 7 0.2823893118279177 0.9200432948490231
# 8 0.2785353043760118 0.92023756660746
# 9 0.2766826276933745 0.9195992451154529
# 0.9235381654330662
# embedding.weight     | nonzeros = 1280051 / 2500200 ( 51.20%) | total_pruned = 1220149 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# fc.weight            | nonzeros =    1048 /    2048 ( 51.17%) | total_pruned =    1000 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2463888, pruned : 2348508, total: 4812396, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.2644883308519955 0.9211256660746003
# 1 0.27031777654220324 0.9196269982238011
# 2 0.27765585441096 0.9203485790408525
# 3 0.26621447001512744 0.9224855683836589
# 4 0.27367102043938096 0.9209036412078153
# 5 0.2772416294507722 0.9222080373001776
# 6 0.28753148919206317 0.9184336145648313
# 7 0.2697308897594946 0.9218194937833037
# 8 0.28986967123422913 0.9199322824156305
# 9 0.2947630960490971 0.9194604795737122
# 0.9195553219618917
# embedding.weight     | nonzeros = 1024041 / 2500200 ( 40.96%) | total_pruned = 1476159 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# fc.weight            | nonzeros =     838 /    2048 ( 40.92%) | total_pruned =    1210 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1971106, pruned : 2841290, total: 4812396, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.2564503208338738 0.9211256660746003
# 1 0.2582544775954307 0.9220137655417406
# 2 0.25702376866822346 0.9223468028419183
# 3 0.2672339764127564 0.9203208259325044
# 4 0.2676835838493562 0.9207371225577264
# 5 0.26814727126877114 0.9198767761989343
# 6 0.2702400769796851 0.9212921847246892
# 7 0.2766545193193755 0.9212366785079928
# 8 0.28246574028896343 0.9216252220248667
# 9 0.2813820012582079 0.9214309502664298
# 0.9229691875081102
# embedding.weight     | nonzeros =  819233 / 2500200 ( 32.77%) | total_pruned = 1680967 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# fc.weight            | nonzeros =     670 /    2048 ( 32.71%) | total_pruned =    1378 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1576880, pruned : 3235516, total: 4812396, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.26154763162546324 0.9197380106571936
# 1 0.2558070407406184 0.9212921847246892
# 2 0.2611011839628908 0.92023756660746
# 3 0.2672325444918913 0.9215974689165186
# 4 0.2766879864870761 0.9206816163410302
# 5 0.26399821919417193 0.9216807282415631
# 6 0.2726562283420356 0.9186833925399644
# 7 0.2763754582317086 0.9208481349911191
# 8 0.27248169528568567 0.9215697158081705
# 9 0.2825452032173135 0.921042406749556
# 0.9235819327731093
# embedding.weight     | nonzeros =  655386 / 2500200 ( 26.21%) | total_pruned = 1844814 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# fc.weight            | nonzeros =     536 /    2048 ( 26.17%) | total_pruned =    1512 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1261501, pruned : 3550895, total: 4812396, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.25885640266707055 0.9196547513321492
# 1 0.25337989731868776 0.9215142095914742
# 2 0.2634639142405367 0.9194604795737122
# 3 0.259759259861803 0.9187944049733571
# 4 0.26506965031076496 0.9205150976909414
# 5 0.2688804977452697 0.9194604795737122
# 6 0.2728932385231975 0.9202653197158082
# 7 0.27639214518657 0.9212089253996447
# 8 0.2657975681741485 0.9214031971580817
# 9 0.2697640933777945 0.9202930728241563
# 0.9230129553490326
# embedding.weight     | nonzeros =  524309 / 2500200 ( 20.97%) | total_pruned = 1975891 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# fc.weight            | nonzeros =     429 /    2048 ( 20.95%) | total_pruned =    1619 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1009195, pruned : 3803201, total: 4812396, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.25211938066642936 0.9192662078152753
# 1 0.25436881895062924 0.921042406749556
# 2 0.2596014569220704 0.9204040852575488
# 3 0.25567988066092057 0.9223468028419183
# 4 0.25866053296752656 0.9209036412078153
# 5 0.2553104843074194 0.9201543072824157
# 6 0.25845048462783465 0.9217917406749556
# 7 0.2765080380198905 0.9205428507992895
# 8 0.2647098222545631 0.9210146536412078
# 9 0.25813463290898564 0.9220970248667851
# 0.9216999301389486
# embedding.weight     | nonzeros =  419447 / 2500200 ( 16.78%) | total_pruned = 2080753 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# fc.weight            | nonzeros =     343 /    2048 ( 16.75%) | total_pruned =    1705 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 807353, pruned : 4005043, total: 4812396, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.2477747420573584 0.9189054174067496
# 1 0.25109666510820916 0.9202653197158082
# 2 0.25134023204346584 0.9193217140319716
# 3 0.25210449867261503 0.9216252220248667
# 4 0.2525866459178379 0.9216252220248667
# 5 0.251145882141606 0.9207926287744227
# 6 0.25402903461706416 0.9211811722912966
# 7 0.2625180171177347 0.9219027531083481
# 8 0.2582518793228967 0.9197935168738899
# 9 0.2541146230061752 0.9215974689165186
# 0.9202118345669338
# embedding.weight     | nonzeros =  335557 / 2500200 ( 13.42%) | total_pruned = 2164643 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# fc.weight            | nonzeros =     274 /    2048 ( 13.38%) | total_pruned =    1774 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 645882, pruned : 4166514, total: 4812396, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.25060466766608863 0.9174067495559503
# 1 0.2568423216848189 0.9190441829484902
# 2 0.2494214580743367 0.9201265541740675
# 3 0.24969802786088274 0.9207926287744227
# 4 0.25742431815389416 0.9186278863232682
# 5 0.2488616059119044 0.9195437388987566
# 6 0.26109493455682514 0.9203763321492007
# 7 0.25760840931758416 0.9209036412078153
# 8 0.25287977616148827 0.9210979129662522
# 9 0.2540732260783522 0.9205428507992895
# 0.9217874648190346
# embedding.weight     | nonzeros =  268445 / 2500200 ( 10.74%) | total_pruned = 2231755 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# fc.weight            | nonzeros =     219 /    2048 ( 10.69%) | total_pruned =    1829 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 516697, pruned : 4295699, total: 4812396, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.25496549013055875 0.914464920071048
# 1 0.2586246938122102 0.9147702042628775
# 2 0.24986860284260862 0.9152142539964476
# 3 0.25668116852965334 0.9168516873889876
# 4 0.2517796834570159 0.9166574156305506
# 5 0.25012142075884086 0.9182115896980462
# 6 0.25055554422812926 0.9186001332149201
# 7 0.248663515132086 0.9186833925399644
# 8 0.25550985961431244 0.9187666518650088
# 9 0.24683570512446373 0.9192384547069272
# 0.9185924369747899
# embedding.weight     | nonzeros =  214756 / 2500200 (  8.59%) | total_pruned = 2285444 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# fc.weight            | nonzeros =     175 /    2048 (  8.54%) | total_pruned =    1873 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 413356, pruned : 4399040, total: 4812396, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.2641891481364758 0.9142984014209592
# 1 0.25448376380343846 0.9154640319715808
# 2 0.2502161621580936 0.9168239342806395
# 3 0.2482050352698427 0.9175732682060391
# 4 0.24758694888643432 0.9180173179396093
# 5 0.2534265325323647 0.9178785523978685
# 6 0.2513362525666189 0.9182115896980462
# 7 0.25503937768225504 0.9192662078152753
# 8 0.24960263723054268 0.9183226021314387
# 9 0.24654309607737865 0.9193494671403197
# 0.9192927169198749
# embedding.weight     | nonzeros =  171805 / 2500200 (  6.87%) | total_pruned = 2328395 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# fc.weight            | nonzeros =     140 /    2048 (  6.84%) | total_pruned =    1908 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 330678, pruned : 4481718, total: 4812396, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.26440992618068976 0.9118283747779752
# 1 0.25980792907240335 0.9128552397868561
# 2 0.25745532232573254 0.9149922291296625
# 3 0.2536817303201974 0.9154362788632326
# 4 0.2520911270094172 0.9172402309058615
# 5 0.2553894098080549 0.9161578596802842
# 6 0.25307591480978797 0.9164908969804618
# 7 0.2534294841053431 0.9176287744227354
# 8 0.25370128023343863 0.9169626998223801
# 9 0.2500740755713325 0.9173789964476021
# 0.9164478292986125
# embedding.weight     | nonzeros =  137444 / 2500200 (  5.50%) | total_pruned = 2362756 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# fc.weight            | nonzeros =     112 /    2048 (  5.47%) | total_pruned =    1936 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 264539, pruned : 4547857, total: 4812396, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.2831274519226188 0.9071103463587922
# 1 0.27181336175167325 0.9103852131438721
# 2 0.2703125457317431 0.9130495115452931
# 3 0.2715220310482102 0.9122169182948491
# 4 0.2661936126325154 0.9125777087033747
# 5 0.26482419600151147 0.9134103019538188
# 6 0.26783838194710585 0.9128829928952042
# 7 0.26186595807516977 0.9138821047957372
# 8 0.2615936426594721 0.9138821047957372
# 9 0.26294100680099025 0.9147424511545293
# 0.9166666664997069
# embedding.weight     | nonzeros =  109955 / 2500200 (  4.40%) | total_pruned = 2390245 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# fc.weight            | nonzeros =      89 /    2048 (  4.35%) | total_pruned =    1959 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 211629, pruned : 4600767, total: 4812396, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.2903553549180446 0.9023923179396093
# 1 0.28067062686976596 0.9061389875666075
# 2 0.2770725452650477 0.9068328152753108
# 3 0.28007306920308256 0.9068605683836589
# 4 0.2731310179230441 0.9080539520426287
# 5 0.2719106712754068 0.9094693605683837
# 6 0.27266006517020547 0.9094138543516874
# 7 0.2749715966286657 0.9098579040852576
# 8 0.2669242507948492 0.910773756660746
# 9 0.26627229705624955 0.909941163410302
# 0.91312149843248
# embedding.weight     | nonzeros =   87964 / 2500200 (  3.52%) | total_pruned = 2412236 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# fc.weight            | nonzeros =      71 /    2048 (  3.47%) | total_pruned =    1977 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 169298, pruned : 4643098, total: 4812396, Compression rate :      28.43x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.31219955139047406 0.8925954706927176
# 1 0.30067694921304555 0.8995615008880995
# 2 0.29288992023039245 0.9029473801065719
# 3 0.2904612127737825 0.9041130106571936
# 4 0.287477093406326 0.9038077264653641
# 5 0.284986683142704 0.9049733570159858
# 6 0.2867874255069725 0.9042795293072824
# 7 0.28587768463083735 0.9052786412078153
# 8 0.2897728701977334 0.906666296625222
# 9 0.2836239071691915 0.9075266429840142
# 0.9066876749030682
# embedding.weight     | nonzeros =   70371 / 2500200 (  2.81%) | total_pruned = 2429829 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# fc.weight            | nonzeros =      57 /    2048 (  2.78%) | total_pruned =    1991 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 135435, pruned : 4676961, total: 4812396, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.32610847112651564 0.8857126998223801
# 1 0.3168297210446895 0.8917628774422736
# 2 0.3076058030806707 0.8958703374777975
# 3 0.304776951781479 0.8973134991119005
# 4 0.29636932946543076 0.9013376998223801
# 5 0.29617728832381285 0.9014764653641207
# 6 0.30611642187074173 0.9023923179396093
# 7 0.2983178619930577 0.9001998223801065
# 8 0.29232053798797075 0.9024755772646537
# 9 0.2972433092502702 0.9018372557726465
# 0.8998161764705882
# embedding.weight     | nonzeros =   56297 / 2500200 (  2.25%) | total_pruned = 2443903 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# fc.weight            | nonzeros =      45 /    2048 (  2.20%) | total_pruned =    2003 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 108343, pruned : 4704053, total: 4812396, Compression rate :      44.42x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.3401301951341159 0.8831316607460036
# 1 0.32319649723135135 0.8879051953818827
# 2 0.32439991270835455 0.8923734458259325
# 3 0.31942588051195464 0.8944549289520426
# 4 0.31180708933965723 0.8962311278863233
# 5 0.310604673244562 0.89761878330373
# 6 0.3077878502626005 0.8980905861456483
# 7 0.30824189020740944 0.89761878330373
# 8 0.30561059105605365 0.8983958703374778
# 9 0.30318846749257605 0.8990896980461812
# 0.8962710084033614
# embedding.weight     | nonzeros =   45037 / 2500200 (  1.80%) | total_pruned = 2455163 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# fc.weight            | nonzeros =      36 /    2048 (  1.76%) | total_pruned =    2012 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 86670, pruned : 4725726, total: 4812396, Compression rate :      55.53x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.36331150253993155 0.8733348134991119
# 1 0.3525760326713165 0.8797457815275311
# 2 0.35115720234731906 0.8831316607460036
# 3 0.34420485891150326 0.8867673179396093
# 4 0.34448748148091096 0.8869615896980462
# 5 0.35150375568885256 0.8828541296625222
# 6 0.33216831689207527 0.8892928507992895
# 7 0.3310828113342845 0.8900421847246892
# 8 0.3316198536302385 0.8881827264653641
# 9 0.3397329295563576 0.8891540852575488
# 0.887955182239789
# embedding.weight     | nonzeros =   36029 / 2500200 (  1.44%) | total_pruned = 2464171 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# fc.weight            | nonzeros =      29 /    2048 (  1.42%) | total_pruned =    2019 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 69331, pruned : 4743065, total: 4812396, Compression rate :      69.41x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.37726349321394154 0.8680894760213144
# 1 0.36610805008686137 0.8734458259325044
# 2 0.35801952598586706 0.8764709147424512
# 3 0.3548464230352725 0.8801343250444049
# 4 0.35264424985311066 0.8810224245115453
# 5 0.34802617548533166 0.8829928952042628
# 6 0.3458633274104625 0.8835479573712256
# 7 0.3435739661379987 0.8837699822380106
# 8 0.3397670059661723 0.8856016873889876
# 9 0.3405035078942405 0.885684946714032
# 0.88047093854231
# embedding.weight     | nonzeros =   28823 / 2500200 (  1.15%) | total_pruned = 2471377 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# fc.weight            | nonzeros =      23 /    2048 (  1.12%) | total_pruned =    2025 | shape = (4, 512)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 55459, pruned : 4756937, total: 4812396, Compression rate :      86.77x  ( 98.85% pruned)

# %%
# lr_l
print(performance)
print(valid_losses)

lr_l_performance = performance
lr_l_valid_losses = valid_losses
# Out:
# [91.55287116515535, 92.20938377019738, 92.26190477860075, 92.35381654330662, 91.95553219618917, 92.29691875081102, 92.35819327731093, 92.30129553490326, 92.16999301389485, 92.02118345669338, 92.17874648190346, 91.85924369747899, 91.9292716919875, 91.64478292986125, 91.66666664997068, 91.31214984324801, 90.66876749030682, 89.98161764705883, 89.62710084033614, 88.7955182239789, 88.047093854231]
# [0.2571922519159889, 0.27851588419947915, 0.2837045765192402, 0.2766826276933745, 0.2947630960490971, 0.2813820012582079, 0.2825452032173135, 0.2697640933777945, 0.25813463290898564, 0.2541146230061752, 0.2540732260783522, 0.24683570512446373, 0.24654309607737865, 0.2500740755713325, 0.26294100680099025, 0.26627229705624955, 0.2836239071691915, 0.2972433092502702, 0.30318846749257605, 0.3397329295563576, 0.3405035078942405]
