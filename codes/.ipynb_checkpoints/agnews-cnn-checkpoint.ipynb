# %% [markdown]
# [reference](https://github.com/bentrevett/pytorch-sentiment-analysis)

# %%
# Importing Libraries
import os
import copy
import time
import torch
import torchtext
from torchtext import data
from torchtext import datasets
from torchtext.vocab import GloVe
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/lt-module'
os.chdir(path)

# %%
# Custom Libraries
import DataLoader
import Model

# %% [markdown]
# ## Define functions - to load dataset & model

# %%
# load dataset
def load_dataset(dataset, architecture, batch_size, device, path):
    if dataset == "imdb":
      if architecture == "cnn":
        data = DataLoader.IMDB_CNN(batch_size, device, path)
      elif architecture == "lstm":
        data = DataLoader.IMDB_LSTM(batch_size, device, path)

    elif dataset == "agnews":
        data = DataLoader.AGNEWS_CUSTOM(batch_size, device, path)

    else:
        raise ValueError(dataset + "is not supported")

    return data

# load model and set hyperparameters
def load_model(architecture, data_choice, batch_size):

    if architecture == "cnn":
      # hyperparameters
      vocab_size = len(dataset.TEXT.vocab)
      embedding_dim = 100
      n_filters = 100
      filter_sizes = [3,4,5]
      dropout = 0.5
      pad_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.pad_token]
      
      if data_choice == "imdb":
        # binary-class
        output_dim = 1
        model = Model.binaryCNN(vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout, pad_idx)
      
      elif data_choice == "agnews":
        # multi-class
        output_dim = 4
        model = Model.multiCNN(vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout, pad_idx)

      unk_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.unk_token]
      model.embedding.weight.data[unk_idx] = torch.zeros(embedding_dim)
      model.embedding.weight.data[pad_idx] = torch.zeros(embedding_dim)

      return model

    elif architecture == "lstm":
      # hyperparameters
      vocab_size = len(dataset.TEXT.vocab)
      embedding_dim = 100
      hidden_dim = 256
      output_dim = 1
      n_layers = 2
      bidirectional = True
      dropout = 0.5
      pad_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.pad_token]
      
      if data_choice == "imdb":
        # binary-class
        output_dim = 1
      
      elif data_choice == "agnews":
        # multi-class
        output_dim = 4
      
      model = Model.LSTM(vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout, pad_idx)

      unk_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.unk_token]
      model.embedding.weight.data[unk_idx] = torch.zeros(embedding_dim)
      model.embedding.weight.data[pad_idx] = torch.zeros(embedding_dim)

      return model

    # temporary
    elif architecture == "bert":
        return None

    else:
        raise ValueError(architecture + "is not supported")

# %% [markdown]
# ## Weight initialization

# %%
# weight initializtion
def initialize_xavier_normal(m):
    
  """
	Function to initialize a layer by picking weights from a xavier normal distribution
	Arguments
	---------
	m : The layer of the neural network
	Returns
	-------
	None
	"""
  
  if type(m) == torch.nn.Conv2d:
    torch.nn.init.xavier_normal_(m.weight.data)
    m.bias.data.fill_(0)

  elif isinstance(m, torch.nn.Linear):
    torch.nn.init.xavier_normal_(m.weight.data)
    m.bias.data.fill_(0)

  elif type(m) in [torch.nn.GRU, torch.nn.LSTM, torch.nn.RNN]:
    for name, param in m.named_parameters():
        if 'weight_ih' in name:
          torch.nn.init.xavier_normal_(param.data)
        elif 'weight_hh' in name:
          torch.nn.init.orthogonal_(param.data)
        elif 'bias' in name:
          param.data.fill_(0)

# %% [markdown]
# ## train and test functions

# %%
def categorical_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """
    max_preds = preds.argmax(dim = 1, keepdim = True) # get the index of the max probability
    correct = max_preds.squeeze(1).eq(y)
    return correct.sum().float() / torch.FloatTensor([y.shape[0]]).to(device)

# %%
def train(model, iterator, optimizer, criterion):
    # EPS = 1e-6
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for batch in iterator:
      
      optimizer.zero_grad()
        
      predictions = model(batch.text[0])
        
      loss = criterion(predictions, batch.label)
        
      acc = categorical_accuracy(predictions, batch.label)
        
      loss.backward()
      step = 0

      # Freezing Pruned weights by making their gradients Zero
      for name, p in model.named_parameters():
        weight_dev = param.device
        tensor = p.data.cpu().numpy()
        grad_tensor = p.grad.data.cpu().numpy()
        grad_tensor = np.where(mask[step] == 0, 0, grad_tensor)
        p.grad.data = torch.from_numpy(grad_tensor).to(device)
        step += 1
      
      step = 0

      optimizer.step()
        
      epoch_loss += loss.item()
      epoch_acc += acc.item()
      
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
            predictions = model(batch.text[0])
            loss = criterion(predictions, batch.label)
            acc = categorical_accuracy(predictions, batch.label)
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# ## Pruning Functions

# %%
# Prune by Percentile module
def prune_by_percentile(percent):
  global step
  global mask
  global model
  # Calculate percentile value
  step = 0
  for name, param in model.named_parameters():
    # if 'weight' in name:
    tensor = param.data.cpu().numpy()
    nz_count = np.count_nonzero(tensor)

    # bias가 all pruned 되는 경우 발생
    if nz_count == 0:
      step += 1

    else: 
      alive = tensor[np.nonzero(tensor)] # flattened array of nonzero values
      percentile_value = np.percentile(abs(alive), percent)

      # Convert Tensors to numpy and calculate
      weight_dev = param.device
      new_mask = np.where(abs(tensor) < percentile_value, 0, mask[step])
                
      # Apply new weight and mask
      param.data = torch.from_numpy(tensor * new_mask).to(weight_dev)
      mask[step] = new_mask
      step += 1

  step = 0

# %%
# Function to make an empty mask of the same size as the model
def make_mask(model):
  global step
  global mask
  
  step = 0
  for name, param in model.named_parameters(): 
    # if 'weight' in name:
    step += 1
  mask = [None]* step 
  step = 0
  for name, param in model.named_parameters(): 
    # if 'weight' in name:
    tensor = param.data.cpu().numpy()
    mask[step] = np.ones_like(tensor)
    step += 1
  step = 0

# %%
def original_initialization(mask_temp, initial_state_dict):
    global step
    global model
    
    step = 0
    for name, param in model.named_parameters(): 
        # if "weight" in name: 
            weight_dev = param.device
            param.data = torch.from_numpy(mask_temp[step] * initial_state_dict[name].cpu().numpy()).to(weight_dev)
            step = step + 1
        # if "bias" in name:
            # param.data = initial_state_dict[name]
    step = 0

# %%
# ANCHOR Print table of zeros and non-zeros count
def print_nonzeros(model):
    nonzero = total = 0
    for name, p in model.named_parameters():
        tensor = p.data.cpu().numpy()
        nz_count = np.count_nonzero(tensor)
        total_params = np.prod(tensor.shape)
        nonzero += nz_count
        total += total_params
        print(f'{name:20} | nonzeros = {nz_count:7} / {total_params:7} ({100 * nz_count / total_params:6.2f}%) | total_pruned = {total_params - nz_count :7} | shape = {tensor.shape}')
    print(f'alive: {nonzero}, pruned : {total - nonzero}, total: {total}, Compression rate : {total/nonzero:10.2f}x  ({100 * (total-nonzero) / total:6.2f}% pruned)')
    return (round(((total-nonzero)/total)*100,1))

# %% [markdown]
# ## Choose dataset & model

# %%
# colab에서 돌리기 때문에 우선 arg가 아니라 변수로 넘겨주기
data_choice = "agnews" # 데이터셋 선택
arch_choice = "cnn" # 모델 선택
batch_size = 64 # batch size 선택 - 32 or 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using {device} device.')
# Out:
# Using cuda device.

# %% [markdown]
# ### load dataset

# %%
dataset = load_dataset(data_choice, arch_choice, batch_size, device, path)

# %% [markdown]
# ### model setting

# %%
# check the trial number
trial = 701

# pruning setting
iteration = 20
percent = 20 # 20% prune
N_EPOCH = 10
learning_rate = 1e-3

step = 0

# %% [markdown]
# ## 1) random initialization

# %%
reinit = True # random이면 True, lt면 False
mode = 'random'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# embedding 같은 것 주기 위해
embedding_pretrained_weight = model.embedding.weight

# model initialization and save the model
model.apply(initialize_xavier_normal)
# Out:
# multiCNN(
#   (embedding): Embedding(50002, 100)
#   (convs): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(3, 100), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(4, 100), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(5, 100), stride=(1, 1))
#   )
#   (fc): Linear(in_features=300, out_features=4, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 5,121,704 trainable parameters

# %%
# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.CrossEntropyLoss()

criterion = criterion.to(device)

# %%
for name, param in model.named_parameters():
  print(name, param.size())
# Out:
# embedding.weight torch.Size([50002, 100])
# convs.0.weight torch.Size([100, 1, 3, 100])
# convs.0.bias torch.Size([100])
# convs.1.weight torch.Size([100, 1, 4, 100])
# convs.1.bias torch.Size([100])
# convs.2.weight torch.Size([100, 1, 5, 100])
# convs.2.bias torch.Size([100])
# fc.weight torch.Size([4, 300])
# fc.bias torch.Size([4])

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  # torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(valid_loss, test_acc)
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.39022655285511093 0.8604018650088809
# 1 0.3198869676820497 0.8886267761989343
# 2 0.3032792782076828 0.8973134991119005
# 3 0.2990458602512497 0.9010601687388987
# 4 0.3122489953191941 0.9003940941385435
# 5 0.33301677768239435 0.8983681172291297
# 6 0.3658247694048905 0.8983403641207816
# 7 0.3950029783096449 0.8988676731793961
# 8 0.4441098316273194 0.8953985346358793
# 9 0.4753120859148606 0.8968972024866785
# 0.4753120859148606 0.89749649843248
# 0.89749649843248
# embedding.weight     | nonzeros = 5000200 / 5000200 (100.00%) | total_pruned =       0 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   30000 /   30000 (100.00%) | total_pruned =       0 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.1.weight       | nonzeros =   40000 /   40000 (100.00%) | total_pruned =       0 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.2.weight       | nonzeros =   50000 /   50000 (100.00%) | total_pruned =       0 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# fc.weight            | nonzeros =    1200 /    1200 (100.00%) | total_pruned =       0 | shape = (4, 300)
# fc.bias              | nonzeros =       4 /       4 (100.00%) | total_pruned =       0 | shape = (4,)
# alive: 5121704, pruned : 0, total: 5121704, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.33796744068280576 0.8992007104795737
# 1 0.38700696924572303 0.8967029307282416
# 2 0.4378378567720894 0.8960923623445826
# 3 0.48607818767772476 0.8949267317939609
# 4 0.5540637189065822 0.8914298401420959
# 5 0.5820029018691627 0.8940386323268206
# 6 0.6311452038367783 0.8926509769094139
# 7 0.6646738040751445 0.8927619893428064
# 8 0.7236382798126322 0.8924567051509769
# 9 0.7555259749521609 0.8894593694493783
# 0.7555259749521609 0.8878238797187805
# 0.8878238797187805
# embedding.weight     | nonzeros = 4000160 / 5000200 ( 80.00%) | total_pruned = 1000040 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   24000 /   30000 ( 80.00%) | total_pruned =    6000 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.1.weight       | nonzeros =   32000 /   40000 ( 80.00%) | total_pruned =    8000 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.2.weight       | nonzeros =   40000 /   50000 ( 80.00%) | total_pruned =   10000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# fc.weight            | nonzeros =     960 /    1200 ( 80.00%) | total_pruned =     240 | shape = (4, 300)
# fc.bias              | nonzeros =       3 /       4 ( 75.00%) | total_pruned =       1 | shape = (4,)
# alive: 4097363, pruned : 1024341, total: 5121704, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.4237332271600595 0.8945659413854352
# 1 0.5133267263801219 0.8955928063943162
# 2 0.5884908886107767 0.8919016429840142
# 3 0.6490851244169616 0.8910690497335702
# 4 0.7188056130326133 0.8893483570159858
# 5 0.7489968517503236 0.8895148756660746
# 6 0.8003577767097148 0.8912910746003553
# 7 0.8232655291318178 0.8895426287744227
# 8 0.8717282719895257 0.8896813943161634
# 9 0.9099183871028663 0.88898756660746
# 0.9099183871028663 0.8887867647058824
# 0.8887867647058824
# embedding.weight     | nonzeros = 3200128 / 5000200 ( 64.00%) | total_pruned = 1800072 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   19200 /   30000 ( 64.00%) | total_pruned =   10800 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.1.weight       | nonzeros =   25600 /   40000 ( 64.00%) | total_pruned =   14400 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.2.weight       | nonzeros =   32000 /   50000 ( 64.00%) | total_pruned =   18000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# fc.weight            | nonzeros =     768 /    1200 ( 64.00%) | total_pruned =     432 | shape = (4, 300)
# fc.bias              | nonzeros =       2 /       4 ( 50.00%) | total_pruned =       2 | shape = (4,)
# alive: 3277890, pruned : 1843814, total: 5121704, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.45580549278093063 0.8928730017761989
# 1 0.5646409866562176 0.892678730017762
# 2 0.6581376303230506 0.8904862344582594
# 3 0.7258408263269448 0.8905694937833037
# 4 0.7900313183993637 0.8891818383658969
# 5 0.8194669998783559 0.8897369005328597
# 6 0.8504845652774558 0.8885990230905861
# 7 0.8954506136161039 0.8884880106571936
# 8 0.913412047299934 0.88898756660746
# 9 0.9623206359678367 0.8858792184724689
# 0.9623206359678367 0.8847601538946649
# 0.8847601538946649
# embedding.weight     | nonzeros = 2560103 / 5000200 ( 51.20%) | total_pruned = 2440097 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   15360 /   30000 ( 51.20%) | total_pruned =   14640 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.1.weight       | nonzeros =   20480 /   40000 ( 51.20%) | total_pruned =   19520 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.2.weight       | nonzeros =   25600 /   50000 ( 51.20%) | total_pruned =   24400 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# fc.weight            | nonzeros =     614 /    1200 ( 51.17%) | total_pruned =     586 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2622311, pruned : 2499393, total: 5121704, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.4629260469835953 0.8932615452930728
# 1 0.5772707027355855 0.8907915186500888
# 2 0.6744183922723286 0.8899311722912966
# 3 0.7384005695751821 0.8891540852575488
# 4 0.794754895362606 0.8879884547069272
# 5 0.8500865968772405 0.8891818383658969
# 6 0.8875937987504391 0.8873501332149201
# 7 0.9287008695668527 0.8874888987566607
# 8 0.9584206186440074 0.886933836589698
# 9 1.0030643474647682 0.886517539964476
# 1.0030643474647682 0.8873424369747899
# 0.8873424369747899
# embedding.weight     | nonzeros = 2048082 / 5000200 ( 40.96%) | total_pruned = 2952118 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   12288 /   30000 ( 40.96%) | total_pruned =   17712 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.1.weight       | nonzeros =   16384 /   40000 ( 40.96%) | total_pruned =   23616 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.2.weight       | nonzeros =   20480 /   50000 ( 40.96%) | total_pruned =   29520 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# fc.weight            | nonzeros =     491 /    1200 ( 40.92%) | total_pruned =     709 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2097849, pruned : 3023855, total: 5121704, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.46117566966660134 0.8911245559502664
# 1 0.5858248876956528 0.8905139875666075
# 2 0.6688486871948105 0.8899034191829485
# 3 0.734922726145039 0.8874611456483126
# 4 0.8013892381166259 0.8869060834813499
# 5 0.8622087684429381 0.8876831705150977
# 6 0.8945672960613223 0.8880994671403197
# 7 0.9371479940352561 0.8861567495559503
# 8 0.9689599446444499 0.8865452930728241
# 9 0.9891640447534217 0.8864620337477798
# 0.9891640447534217 0.8848476890756303
# 0.8848476890756303
# embedding.weight     | nonzeros = 1638466 / 5000200 ( 32.77%) | total_pruned = 3361734 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    9830 /   30000 ( 32.77%) | total_pruned =   20170 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      32 /     100 ( 32.00%) | total_pruned =      68 | shape = (100,)
# convs.1.weight       | nonzeros =   13107 /   40000 ( 32.77%) | total_pruned =   26893 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# convs.2.weight       | nonzeros =   16384 /   50000 ( 32.77%) | total_pruned =   33616 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# fc.weight            | nonzeros =     393 /    1200 ( 32.75%) | total_pruned =     807 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1678279, pruned : 3443425, total: 5121704, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.4431150977344287 0.8925122113676732
# 1 0.5631561115992852 0.8886822824156305
# 2 0.6380129555549612 0.8897369005328597
# 3 0.703773433805239 0.8877664298401421
# 4 0.7621169620934629 0.8876554174067496
# 5 0.8100934644993957 0.8873223801065719
# 6 0.8541430399999631 0.8878496891651865
# 7 0.8841562511185995 0.8866285523978685
# 8 0.9096397356708434 0.8880439609236235
# 9 0.9399090366715939 0.8864897868561279
# 0.9399090366715939 0.8859856444246629
# 0.8859856444246629
# embedding.weight     | nonzeros = 1310773 / 5000200 ( 26.21%) | total_pruned = 3689427 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    7864 /   30000 ( 26.21%) | total_pruned =   22136 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      25 /     100 ( 25.00%) | total_pruned =      75 | shape = (100,)
# convs.1.weight       | nonzeros =   10485 /   40000 ( 26.21%) | total_pruned =   29515 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      25 /     100 ( 25.00%) | total_pruned =      75 | shape = (100,)
# convs.2.weight       | nonzeros =   13107 /   50000 ( 26.21%) | total_pruned =   36893 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      25 /     100 ( 25.00%) | total_pruned =      75 | shape = (100,)
# fc.weight            | nonzeros =     314 /    1200 ( 26.17%) | total_pruned =     886 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1342619, pruned : 3779085, total: 5121704, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.4427622750643012 0.8932615452930728
# 1 0.5461798085290178 0.8891818383658969
# 2 0.6081758153915975 0.8886822824156305
# 3 0.6726374693808757 0.8892650976909414
# 4 0.7081773124030811 0.8887100355239786
# 5 0.7569066906491787 0.8878496891651865
# 6 0.7923630931237663 0.8876554174067496
# 7 0.8270955081957974 0.8867950710479574
# 8 0.8663004855861057 0.8868228241563055
# 9 0.8827481743793597 0.8867118117229129
# 0.8827481743793597 0.8870798319327731
# 0.8870798319327731
# embedding.weight     | nonzeros = 1048619 / 5000200 ( 20.97%) | total_pruned = 3951581 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    6291 /   30000 ( 20.97%) | total_pruned =   23709 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      20 /     100 ( 20.00%) | total_pruned =      80 | shape = (100,)
# convs.1.weight       | nonzeros =    8388 /   40000 ( 20.97%) | total_pruned =   31612 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      19 /     100 ( 19.00%) | total_pruned =      81 | shape = (100,)
# convs.2.weight       | nonzeros =   10485 /   50000 ( 20.97%) | total_pruned =   39515 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      19 /     100 ( 19.00%) | total_pruned =      81 | shape = (100,)
# fc.weight            | nonzeros =     251 /    1200 ( 20.92%) | total_pruned =     949 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1074093, pruned : 4047611, total: 5121704, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.41305560604909014 0.8917351243339254
# 1 0.5043988869418795 0.8888765541740675
# 2 0.5664563591556449 0.8886545293072824
# 3 0.6170661946709829 0.8873223801065719
# 4 0.6589792998961287 0.8873778863232682
# 5 0.6907825482757779 0.8869615896980462
# 6 0.726120383763226 0.8880717140319716
# 7 0.7552368469837372 0.8872113676731794
# 8 0.7881349126054024 0.8864897868561279
# 9 0.8125276883516533 0.8870726021314387
# 0.8125276883516533 0.887386204314833
# 0.887386204314833
# embedding.weight     | nonzeros =  838895 / 5000200 ( 16.78%) | total_pruned = 4161305 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    5033 /   30000 ( 16.78%) | total_pruned =   24967 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      15 /     100 ( 15.00%) | total_pruned =      85 | shape = (100,)
# convs.1.weight       | nonzeros =    6710 /   40000 ( 16.77%) | total_pruned =   33290 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      14 /     100 ( 14.00%) | total_pruned =      86 | shape = (100,)
# convs.2.weight       | nonzeros =    8388 /   50000 ( 16.78%) | total_pruned =   41612 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      14 /     100 ( 14.00%) | total_pruned =      86 | shape = (100,)
# fc.weight            | nonzeros =     201 /    1200 ( 16.75%) | total_pruned =     999 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 859271, pruned : 4262433, total: 5121704, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.40601607006486523 0.8930395204262878
# 1 0.48656764728568 0.8897369005328597
# 2 0.5479989294277018 0.8900421847246892
# 3 0.5882327569254507 0.8886267761989343
# 4 0.6245573619736249 0.8878219360568383
# 5 0.6491864132934761 0.8878774422735346
# 6 0.6832246306700943 0.8866285523978685
# 7 0.7053739551448993 0.8872113676731794
# 8 0.7237057147831301 0.8879051953818827
# 9 0.7475807722500769 0.8875999111900533
# 0.7475807722500769 0.8888742998868477
# 0.8888742998868477
# embedding.weight     | nonzeros =  671116 / 5000200 ( 13.42%) | total_pruned = 4329084 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    4026 /   30000 ( 13.42%) | total_pruned =   25974 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.1.weight       | nonzeros =    5368 /   40000 ( 13.42%) | total_pruned =   34632 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.2.weight       | nonzeros =    6710 /   50000 ( 13.42%) | total_pruned =   43290 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      11 /     100 ( 11.00%) | total_pruned =      89 | shape = (100,)
# fc.weight            | nonzeros =     161 /    1200 ( 13.42%) | total_pruned =    1039 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 687413, pruned : 4434291, total: 5121704, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.39761450011316246 0.8917351243339254
# 1 0.4694827452283783 0.8912910746003553
# 2 0.5186365775068805 0.8879051953818827
# 3 0.5565997522380567 0.8875166518650088
# 4 0.5816429258401954 0.8877941829484902
# 5 0.5994062354306601 0.8889598134991119
# 6 0.6251310228773759 0.8887932948490231
# 7 0.6453460623426645 0.8886822824156305
# 8 0.6627851256471686 0.8878496891651865
# 9 0.6769227872021185 0.8878496891651865
# 0.6769227872021185 0.889924720054915
# 0.889924720054915
# embedding.weight     | nonzeros =  536893 / 5000200 ( 10.74%) | total_pruned = 4463307 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    3221 /   30000 ( 10.74%) | total_pruned =   26779 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       7 /     100 (  7.00%) | total_pruned =      93 | shape = (100,)
# convs.1.weight       | nonzeros =    4294 /   40000 ( 10.73%) | total_pruned =   35706 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.2.weight       | nonzeros =    5368 /   50000 ( 10.74%) | total_pruned =   44632 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       9 /     100 (  9.00%) | total_pruned =      91 | shape = (100,)
# fc.weight            | nonzeros =     129 /    1200 ( 10.75%) | total_pruned =    1071 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 549930, pruned : 4571774, total: 5121704, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.39538803415581397 0.8924844582593251
# 1 0.4571350078176224 0.8905417406749556
# 2 0.510701285759533 0.8893206039076377
# 3 0.5430439869777282 0.8887100355239786
# 4 0.5650172718489612 0.8890153197158082
# 5 0.5842488127277559 0.8888488010657194
# 6 0.6059456727290476 0.8888765541740675
# 7 0.618378419824421 0.8883492451154529
# 8 0.6399748862611848 0.8874611456483126
# 9 0.6512185487090602 0.8891818383658969
# 0.6512185487090602 0.8900560225759234
# 0.8900560225759234
# embedding.weight     | nonzeros =  429514 / 5000200 (  8.59%) | total_pruned = 4570686 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2577 /   30000 (  8.59%) | total_pruned =   27423 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.1.weight       | nonzeros =    3435 /   40000 (  8.59%) | total_pruned =   36565 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.2.weight       | nonzeros =    4294 /   50000 (  8.59%) | total_pruned =   45706 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       7 /     100 (  7.00%) | total_pruned =      93 | shape = (100,)
# fc.weight            | nonzeros =     103 /    1200 (  8.58%) | total_pruned =    1097 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 439942, pruned : 4681762, total: 5121704, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.3772490023954591 0.8919849023090586
# 1 0.43644796014096765 0.8891263321492007
# 2 0.47470505412611746 0.8892928507992895
# 3 0.49900340275519706 0.8884602575488455
# 4 0.5181804511937615 0.8882382326820604
# 5 0.5342505437273989 0.8876554174067496
# 6 0.5424328038705096 0.8871558614564832
# 7 0.557123035516302 0.8869893428063943
# 8 0.5738369384788797 0.8869893428063943
# 9 0.5808652799591408 0.8875721580817052
# 0.5808652799591408 0.8859418765837405
# 0.8859418765837405
# embedding.weight     | nonzeros =  343611 / 5000200 (  6.87%) | total_pruned = 4656589 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2061 /   30000 (  6.87%) | total_pruned =   27939 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.1.weight       | nonzeros =    2748 /   40000 (  6.87%) | total_pruned =   37252 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.2.weight       | nonzeros =    3435 /   50000 (  6.87%) | total_pruned =   46565 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# fc.weight            | nonzeros =      82 /    1200 (  6.83%) | total_pruned =    1118 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 351952, pruned : 4769752, total: 5121704, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.38816658702313395 0.8878774422735346
# 1 0.4403721511725429 0.8868505772646537
# 2 0.47043631869230956 0.8858514653641207
# 3 0.49510413565347056 0.8846858348134992
# 4 0.5193904017831892 0.8843527975133215
# 5 0.5232417947314117 0.8844915630550622
# 6 0.5432711990759419 0.884047513321492
# 7 0.5493701913048303 0.8834924511545293
# 8 0.5660796609784098 0.8835479573712256
# 9 0.5689287138769906 0.8838254884547069
# 0.5689287138769906 0.8834033613445378
# 0.8834033613445378
# embedding.weight     | nonzeros =  274889 / 5000200 (  5.50%) | total_pruned = 4725311 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1649 /   30000 (  5.50%) | total_pruned =   28351 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.1.weight       | nonzeros =    2198 /   40000 (  5.50%) | total_pruned =   37802 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.2.weight       | nonzeros =    2748 /   50000 (  5.50%) | total_pruned =   47252 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# fc.weight            | nonzeros =      65 /    1200 (  5.42%) | total_pruned =    1135 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 281561, pruned : 4840143, total: 5121704, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.38261744767083367 0.8896813943161634
# 1 0.42813412518427435 0.8882104795737122
# 2 0.444625714567174 0.8886545293072824
# 3 0.46054462349740377 0.886933836589698
# 4 0.4705728813732906 0.8874888987566607
# 5 0.4849865762037134 0.8867395648312612
# 6 0.4934687964241045 0.8862677619893428
# 7 0.5010099676991838 0.886101243339254
# 8 0.502907016908429 0.885684946714032
# 9 0.5116592826140585 0.8859624777975134
# 0.5116592826140585 0.8856792715417237
# 0.8856792715417237
# embedding.weight     | nonzeros =  219911 / 5000200 (  4.40%) | total_pruned = 4780289 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1319 /   30000 (  4.40%) | total_pruned =   28681 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.1.weight       | nonzeros =    1758 /   40000 (  4.39%) | total_pruned =   38242 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.2.weight       | nonzeros =    2198 /   50000 (  4.40%) | total_pruned =   47802 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# fc.weight            | nonzeros =      52 /    1200 (  4.33%) | total_pruned =    1148 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 225247, pruned : 4896457, total: 5121704, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.3928044826010669 0.8819105239786856
# 1 0.4327046082989473 0.8816329928952042
# 2 0.4521142452885769 0.8820770426287744
# 3 0.4728768787344299 0.8814942273534636
# 4 0.47994321388925293 0.8820492895204263
# 5 0.4916589856883891 0.8819105239786856
# 6 0.4981002930806516 0.8821047957371225
# 7 0.5041078028159934 0.8822713143872114
# 8 0.5079923335729137 0.8822435612788633
# 9 0.5198670501537872 0.8819382770870338
# 0.5198670501537872 0.8829656864414696
# 0.8829656864414696
# embedding.weight     | nonzeros =  175929 / 5000200 (  3.52%) | total_pruned = 4824271 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1055 /   30000 (  3.52%) | total_pruned =   28945 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    1406 /   40000 (  3.52%) | total_pruned =   38594 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.2.weight       | nonzeros =    1758 /   50000 (  3.52%) | total_pruned =   48242 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# fc.weight            | nonzeros =      41 /    1200 (  3.42%) | total_pruned =    1159 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 180195, pruned : 4941509, total: 5121704, Compression rate :      28.42x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.3660185099686918 0.8855461811722913
# 1 0.390889859028809 0.8851298845470693
# 2 0.4031752980054484 0.8847690941385435
# 3 0.41325569970137893 0.8842972912966253
# 4 0.4166329165202686 0.8849633658969804
# 5 0.4205284113495331 0.8836034635879219
# 6 0.4235568366614774 0.8837977353463587
# 7 0.4276007281254057 0.8842972912966253
# 8 0.4299451474358409 0.884047513321492
# 9 0.42634532832727495 0.8838809946714032
# 0.42634532832727495 0.8847601538946649
# 0.8847601538946649
# embedding.weight     | nonzeros =  140743 / 5000200 (  2.81%) | total_pruned = 4859457 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     844 /   30000 (  2.81%) | total_pruned =   29156 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    1125 /   40000 (  2.81%) | total_pruned =   38875 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1406 /   50000 (  2.81%) | total_pruned =   48594 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      33 /    1200 (  2.75%) | total_pruned =    1167 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 144155, pruned : 4977549, total: 5121704, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.37498850085595575 0.8834924511545293
# 1 0.40441488549708793 0.8827986234458259
# 2 0.4197510781302572 0.88199378330373
# 3 0.42533771645734303 0.8821603019538188
# 4 0.43049675364173007 0.8816607460035524
# 5 0.4343987141932703 0.8811889431616341
# 6 0.4359392967814543 0.8812722024866785
# 7 0.43926319704419187 0.8800510657193605
# 8 0.4408920684177594 0.8804951154529307
# 9 0.44597341731144363 0.8805783747779752
# 0.44597341731144363 0.8808210782644128
# 0.8808210782644128
# embedding.weight     | nonzeros =  112594 / 5000200 (  2.25%) | total_pruned = 4887606 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     675 /   30000 (  2.25%) | total_pruned =   29325 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     900 /   40000 (  2.25%) | total_pruned =   39100 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1125 /   50000 (  2.25%) | total_pruned =   48875 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      26 /    1200 (  2.17%) | total_pruned =    1174 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 115324, pruned : 5006380, total: 5121704, Compression rate :      44.41x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.42211789250552495 0.8664520426287744
# 1 0.43985827079747486 0.8662022646536413
# 2 0.4606301935181207 0.8653141651865008
# 3 0.46864185466052266 0.8652864120781527
# 4 0.4721541747708886 0.865119893428064
# 5 0.4789796705377581 0.8647868561278863
# 6 0.48421923327218364 0.8665353019538188
# 7 0.4853985477470483 0.8660079928952042
# 8 0.48876933991366445 0.8659802397868561
# 9 0.486070367256196 0.8664520426287744
# 0.486070367256196 0.8674282211215556
# 0.8674282211215556
# embedding.weight     | nonzeros =   90075 / 5000200 (  1.80%) | total_pruned = 4910125 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     540 /   30000 (  1.80%) | total_pruned =   29460 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     720 /   40000 (  1.80%) | total_pruned =   39280 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     900 /   50000 (  1.80%) | total_pruned =   49100 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      21 /    1200 (  1.75%) | total_pruned =    1179 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 92260, pruned : 5029444, total: 5121704, Compression rate :      55.51x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.5208442168670904 0.8434724689165186
# 1 0.518737477688764 0.8450543960923623
# 2 0.5220765904796377 0.8463310390763765
# 3 0.523009011032288 0.8462755328596803
# 4 0.5273734495063606 0.8453319271758437
# 5 0.5265032265030946 0.8461645204262878
# 6 0.5269793395687483 0.848273756660746
# 7 0.5331124133078073 0.8465808170515098
# 8 0.5329911132966753 0.8478852131438721
# 9 0.5283759110714731 0.8478019538188277
# 0.5283759110714731 0.8501838235294118
# 0.8501838235294118
# embedding.weight     | nonzeros =   72060 / 5000200 (  1.44%) | total_pruned = 4928140 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     432 /   30000 (  1.44%) | total_pruned =   29568 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     576 /   40000 (  1.44%) | total_pruned =   39424 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     720 /   50000 (  1.44%) | total_pruned =   49280 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      17 /    1200 (  1.42%) | total_pruned =    1183 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 73809, pruned : 5047895, total: 5121704, Compression rate :      69.39x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.5072811478434617 0.8511045737122558
# 1 0.5039031903456308 0.8524922291296625
# 2 0.5051439651329448 0.8516873889875666
# 3 0.5073840888928404 0.8539353907637656
# 4 0.5100515798018785 0.8514931172291297
# 5 0.513328536398722 0.8518539076376554
# 6 0.5128071408513701 0.8540464031971581
# 7 0.515754157323291 0.8528807726465364
# 8 0.5160476567676923 0.8522702042628775
# 9 0.5151197171702213 0.8538243783303731
# 0.5151197171702213 0.8546918765837405
# 0.8546918765837405
# embedding.weight     | nonzeros =   57648 / 5000200 (  1.15%) | total_pruned = 4942552 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     345 /   30000 (  1.15%) | total_pruned =   29655 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     461 /   40000 (  1.15%) | total_pruned =   39539 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     576 /   50000 (  1.15%) | total_pruned =   49424 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      13 /    1200 (  1.08%) | total_pruned =    1187 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 59047, pruned : 5062657, total: 5121704, Compression rate :      86.74x  ( 98.85% pruned)

# %%
# random
print(performance)
print(valid_losses)

reinit_performance = performance
reinit_valid_losses = valid_losses
# Out:
# [89.74964984324801, 88.78238797187805, 88.87867647058823, 88.47601538946648, 88.73424369747899, 88.48476890756302, 88.59856444246628, 88.7079831932773, 88.7386204314833, 88.88742998868477, 88.99247200549149, 89.00560225759234, 88.59418765837404, 88.34033613445378, 88.56792715417237, 88.29656864414696, 88.47601538946648, 88.08210782644127, 86.74282211215557, 85.01838235294117, 85.46918765837404]
# [0.4753120859148606, 0.7555259749521609, 0.9099183871028663, 0.9623206359678367, 1.0030643474647682, 0.9891640447534217, 0.9399090366715939, 0.8827481743793597, 0.8125276883516533, 0.7475807722500769, 0.6769227872021185, 0.6512185487090602, 0.5808652799591408, 0.5689287138769906, 0.5116592826140585, 0.5198670501537872, 0.42634532832727495, 0.44597341731144363, 0.486070367256196, 0.5283759110714731, 0.5151197171702213]

# %% [markdown]
# ## 2) lt

# %%
reinit = False # random이면 True, lt면 False
mode = 'lt'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)
initial_state_dict = copy.deepcopy(model.state_dict())

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.CrossEntropyLoss()

criterion = criterion.to(device)

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  # torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.3973680879675897 0.8603463587921847
# 1 0.3326022846667265 0.8841030195381883
# 2 0.31597164027114955 0.8924011989342806
# 3 0.308833584119938 0.8985623889875666
# 4 0.3189982404571761 0.8986734014209592
# 5 0.34070290709129447 0.8977853019538188
# 6 0.37353301312622234 0.8991729573712256
# 7 0.40519313037488114 0.8959258436944938
# 8 0.4662757303737779 0.8916796181172292
# 9 0.4903469795582826 0.8941773978685613
# 0.8917629553490326
# embedding.weight     | nonzeros = 5000200 / 5000200 (100.00%) | total_pruned =       0 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   30000 /   30000 (100.00%) | total_pruned =       0 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.1.weight       | nonzeros =   40000 /   40000 (100.00%) | total_pruned =       0 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.2.weight       | nonzeros =   50000 /   50000 (100.00%) | total_pruned =       0 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# fc.weight            | nonzeros =    1200 /    1200 (100.00%) | total_pruned =       0 | shape = (4, 300)
# fc.bias              | nonzeros =       4 /       4 (100.00%) | total_pruned =       0 | shape = (4,)
# alive: 5121704, pruned : 0, total: 5121704, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.3755573678106652 0.8704484902309059
# 1 0.32226720908871764 0.8894316163410302
# 2 0.31973240187732405 0.8953985346358793
# 3 0.3278154819396525 0.8979518206039077
# 4 0.35059479303777114 0.8953707815275311
# 5 0.37641009595741387 0.8977297957371225
# 6 0.4055198273037562 0.8946492007104796
# 7 0.44431654182568747 0.8950932504440497
# 8 0.49003305866467384 0.8923179396092362
# 9 0.5200342282977081 0.8940386323268206
# 0.8927258403361344
# embedding.weight     | nonzeros = 4000160 / 5000200 ( 80.00%) | total_pruned = 1000040 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   24000 /   30000 ( 80.00%) | total_pruned =    6000 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.1.weight       | nonzeros =   32000 /   40000 ( 80.00%) | total_pruned =    8000 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.2.weight       | nonzeros =   40000 /   50000 ( 80.00%) | total_pruned =   10000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# fc.weight            | nonzeros =     960 /    1200 ( 80.00%) | total_pruned =     240 | shape = (4, 300)
# fc.bias              | nonzeros =       3 /       4 ( 75.00%) | total_pruned =       1 | shape = (4,)
# alive: 4097363, pruned : 1024341, total: 5121704, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.34848819577613216 0.8801898312611013
# 1 0.32963806913163163 0.8921236678507993
# 2 0.330076638880462 0.8941773978685613
# 3 0.3469499348353456 0.8958148312611013
# 4 0.3684836792847271 0.89598134991119
# 5 0.401674775111441 0.8950099911190054
# 6 0.4308700485119421 0.8936500888099467
# 7 0.4666261026920291 0.8944826820603907
# 8 0.49963083006168646 0.8939831261101243
# 9 0.528166301833833 0.8928730017761989
# 0.8920255603910494
# embedding.weight     | nonzeros = 3200128 / 5000200 ( 64.00%) | total_pruned = 1800072 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   19200 /   30000 ( 64.00%) | total_pruned =   10800 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.1.weight       | nonzeros =   25600 /   40000 ( 64.00%) | total_pruned =   14400 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.2.weight       | nonzeros =   32000 /   50000 ( 64.00%) | total_pruned =   18000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# fc.weight            | nonzeros =     768 /    1200 ( 64.00%) | total_pruned =     432 | shape = (4, 300)
# fc.bias              | nonzeros =       2 /       4 ( 50.00%) | total_pruned =       2 | shape = (4,)
# alive: 3277890, pruned : 1843814, total: 5121704, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.3446626527231603 0.8839642539964476
# 1 0.337359691326561 0.8907915186500888
# 2 0.3496672528362494 0.8930672735346359
# 3 0.37101353545049554 0.8923179396092362
# 4 0.3912924068498543 0.893511323268206
# 5 0.41848304119212537 0.8936500888099467
# 6 0.44921843193100885 0.8922901865008881
# 7 0.48055023304434896 0.8910968028419183
# 8 0.5146684732609039 0.8927897424511545
# 9 0.5485064474192529 0.8907637655417406
# 0.8905374648190346
# embedding.weight     | nonzeros = 2560102 / 5000200 ( 51.20%) | total_pruned = 2440098 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   15360 /   30000 ( 51.20%) | total_pruned =   14640 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.1.weight       | nonzeros =   20480 /   40000 ( 51.20%) | total_pruned =   19520 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.2.weight       | nonzeros =   25600 /   50000 ( 51.20%) | total_pruned =   24400 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# fc.weight            | nonzeros =     614 /    1200 ( 51.17%) | total_pruned =     586 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2622310, pruned : 2499394, total: 5121704, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.34076878535486826 0.8838532415630551
# 1 0.3430072601461125 0.890208703374778
# 2 0.35763684973090915 0.8888488010657194
# 3 0.368609021888007 0.8927342362344582
# 4 0.3983384256497634 0.8928452486678508
# 5 0.42186791241106114 0.8920681616341031
# 6 0.45252163939717266 0.8931227797513321
# 7 0.4775907041039318 0.8921514209591475
# 8 0.5065973840238689 0.8909580373001776
# 9 0.5314629773675922 0.8905417406749556
# 0.8901435572560094
# embedding.weight     | nonzeros = 2048082 / 5000200 ( 40.96%) | total_pruned = 2952118 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   12288 /   30000 ( 40.96%) | total_pruned =   17712 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.1.weight       | nonzeros =   16384 /   40000 ( 40.96%) | total_pruned =   23616 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.2.weight       | nonzeros =   20480 /   50000 ( 40.96%) | total_pruned =   29520 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# fc.weight            | nonzeros =     491 /    1200 ( 40.92%) | total_pruned =     709 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2097849, pruned : 3023855, total: 5121704, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.3457104710235093 0.881577486678508
# 1 0.34522601950013776 0.8896813943161634
# 2 0.3588198829883938 0.8907082593250444
# 3 0.3728176144110519 0.8930395204262878
# 4 0.3920065458755623 0.8925677175843695
# 5 0.4141802331176297 0.8921791740674956
# 6 0.4332051276463807 0.8917073712255773
# 7 0.4574727648877428 0.8918461367673179
# 8 0.47963564722099034 0.8902919626998224
# 9 0.5035648893376359 0.8917628774422736
# 0.8874737394957983
# embedding.weight     | nonzeros = 1638466 / 5000200 ( 32.77%) | total_pruned = 3361734 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    9830 /   30000 ( 32.77%) | total_pruned =   20170 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      32 /     100 ( 32.00%) | total_pruned =      68 | shape = (100,)
# convs.1.weight       | nonzeros =   13107 /   40000 ( 32.77%) | total_pruned =   26893 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      32 /     100 ( 32.00%) | total_pruned =      68 | shape = (100,)
# convs.2.weight       | nonzeros =   16384 /   50000 ( 32.77%) | total_pruned =   33616 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      32 /     100 ( 32.00%) | total_pruned =      68 | shape = (100,)
# fc.weight            | nonzeros =     393 /    1200 ( 32.75%) | total_pruned =     807 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1678277, pruned : 3443427, total: 5121704, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.34299062787047313 0.8831871669626998
# 1 0.3451377470980913 0.8886545293072824
# 2 0.35299281445646175 0.8909025310834814
# 3 0.36462693283008496 0.8919849023090586
# 4 0.3791505471860318 0.8928174955595026
# 5 0.3948139588403984 0.8919571492007105
# 6 0.410902511953545 0.8926232238010657
# 7 0.42795083852034876 0.8924289520426287
# 8 0.44726858057907154 0.892678730017762
# 9 0.46586191793738285 0.8917351243339254
# 0.8892244396089506
# embedding.weight     | nonzeros = 1310773 / 5000200 ( 26.21%) | total_pruned = 3689427 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    7864 /   30000 ( 26.21%) | total_pruned =   22136 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      25 /     100 ( 25.00%) | total_pruned =      75 | shape = (100,)
# convs.1.weight       | nonzeros =   10485 /   40000 ( 26.21%) | total_pruned =   29515 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      24 /     100 ( 24.00%) | total_pruned =      76 | shape = (100,)
# convs.2.weight       | nonzeros =   13107 /   50000 ( 26.21%) | total_pruned =   36893 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      25 /     100 ( 25.00%) | total_pruned =      75 | shape = (100,)
# fc.weight            | nonzeros =     314 /    1200 ( 26.17%) | total_pruned =     886 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1342618, pruned : 3779086, total: 5121704, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.3411388037772601 0.8841030195381883
# 1 0.3436457210354388 0.887738676731794
# 2 0.34864574522491326 0.8893483570159858
# 3 0.35693862580166563 0.8905972468916519
# 4 0.36553902722246695 0.8916518650088809
# 5 0.3743429422479034 0.8924289520426287
# 6 0.388851865767096 0.8915408525754884
# 7 0.39940730942583597 0.8918461367673179
# 8 0.41207365835537113 0.8926232238010657
# 9 0.42392328485712527 0.8925122113676732
# 0.8902310924369747
# embedding.weight     | nonzeros = 1048618 / 5000200 ( 20.97%) | total_pruned = 3951582 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    6291 /   30000 ( 20.97%) | total_pruned =   23709 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      20 /     100 ( 20.00%) | total_pruned =      80 | shape = (100,)
# convs.1.weight       | nonzeros =    8388 /   40000 ( 20.97%) | total_pruned =   31612 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      19 /     100 ( 19.00%) | total_pruned =      81 | shape = (100,)
# convs.2.weight       | nonzeros =   10485 /   50000 ( 20.97%) | total_pruned =   39515 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      20 /     100 ( 20.00%) | total_pruned =      80 | shape = (100,)
# fc.weight            | nonzeros =     251 /    1200 ( 20.92%) | total_pruned =     949 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1074093, pruned : 4047611, total: 5121704, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.3431832627467745 0.8811889431616341
# 1 0.3400313652494383 0.8850743783303731
# 2 0.3405798921517889 0.8892373445825933
# 3 0.347030281040447 0.8915408525754884
# 4 0.3504372017218634 0.8918738898756661
# 5 0.3537691125979558 0.8923456927175843
# 6 0.3635535724446604 0.8929285079928952
# 7 0.370858336918984 0.8919849023090586
# 8 0.38062034920891863 0.8921514209591475
# 9 0.38590874453033874 0.893511323268206
# 0.8947829133322259
# embedding.weight     | nonzeros =  838894 / 5000200 ( 16.78%) | total_pruned = 4161306 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    5033 /   30000 ( 16.78%) | total_pruned =   24967 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      16 /     100 ( 16.00%) | total_pruned =      84 | shape = (100,)
# convs.1.weight       | nonzeros =    6710 /   40000 ( 16.77%) | total_pruned =   33290 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      15 /     100 ( 15.00%) | total_pruned =      85 | shape = (100,)
# convs.2.weight       | nonzeros =    8388 /   50000 ( 16.78%) | total_pruned =   41612 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      16 /     100 ( 16.00%) | total_pruned =      84 | shape = (100,)
# fc.weight            | nonzeros =     201 /    1200 ( 16.75%) | total_pruned =     999 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 859274, pruned : 4262430, total: 5121704, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.34188630174494766 0.8807726465364121
# 1 0.3384177852153189 0.8849356127886323
# 2 0.33706621222485844 0.8876276642984015
# 3 0.3409701429049403 0.8890708259325044
# 4 0.34350298290820397 0.89226243339254
# 5 0.343844307441807 0.8919293960923623
# 6 0.34737830262566666 0.893511323268206
# 7 0.3528842495506849 0.8937333481349912
# 8 0.35731099271893724 0.8937055950266429
# 9 0.36560916666149906 0.8952320159857904
# 0.8948266806722689
# embedding.weight     | nonzeros =  671115 / 5000200 ( 13.42%) | total_pruned = 4329085 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    4026 /   30000 ( 13.42%) | total_pruned =   25974 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# convs.1.weight       | nonzeros =    5368 /   40000 ( 13.42%) | total_pruned =   34632 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      12 /     100 ( 12.00%) | total_pruned =      88 | shape = (100,)
# convs.2.weight       | nonzeros =    6710 /   50000 ( 13.42%) | total_pruned =   43290 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      12 /     100 ( 12.00%) | total_pruned =      88 | shape = (100,)
# fc.weight            | nonzeros =     161 /    1200 ( 13.42%) | total_pruned =    1039 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 687418, pruned : 4434286, total: 5121704, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.3445398317415062 0.8812444493783304
# 1 0.3328040362630192 0.8867395648312612
# 2 0.3305350301698757 0.8888765541740675
# 3 0.33024138504565653 0.8907082593250444
# 4 0.3323817984016983 0.8920959147424512
# 5 0.331675216278101 0.893095026642984
# 6 0.3351632908518471 0.8929007548845471
# 7 0.33580333365067067 0.8937888543516874
# 8 0.3388983376716949 0.8942884103019538
# 9 0.33990500031657794 0.8946492007104796
# 0.8955707284582763
# embedding.weight     | nonzeros =  536892 / 5000200 ( 10.74%) | total_pruned = 4463308 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    3221 /   30000 ( 10.74%) | total_pruned =   26779 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.1.weight       | nonzeros =    4294 /   40000 ( 10.73%) | total_pruned =   35706 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       9 /     100 (  9.00%) | total_pruned =      91 | shape = (100,)
# convs.2.weight       | nonzeros =    5368 /   50000 ( 10.74%) | total_pruned =   44632 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       9 /     100 (  9.00%) | total_pruned =      91 | shape = (100,)
# fc.weight            | nonzeros =     129 /    1200 ( 10.75%) | total_pruned =    1071 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 549933, pruned : 4571771, total: 5121704, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.34918438898462334 0.8787466696269982
# 1 0.3329240465414715 0.8842140319715808
# 2 0.3308570815819327 0.8871003552397868
# 3 0.3262909491276402 0.8902919626998224
# 4 0.32508893377729897 0.8904584813499112
# 5 0.3249351187893661 0.8931782859680284
# 6 0.32373440186377306 0.8933170515097691
# 7 0.3282654907386485 0.8943994227353463
# 8 0.3295919142620469 0.8940386323268206
# 9 0.3286562784960358 0.8952597690941385
# 0.8940826328862616
# embedding.weight     | nonzeros =  429513 / 5000200 (  8.59%) | total_pruned = 4570687 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2577 /   30000 (  8.59%) | total_pruned =   27423 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.1.weight       | nonzeros =    3435 /   40000 (  8.59%) | total_pruned =   36565 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       7 /     100 (  7.00%) | total_pruned =      93 | shape = (100,)
# convs.2.weight       | nonzeros =    4294 /   50000 (  8.59%) | total_pruned =   45706 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       7 /     100 (  7.00%) | total_pruned =      93 | shape = (100,)
# fc.weight            | nonzeros =     103 /    1200 (  8.58%) | total_pruned =    1097 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 439945, pruned : 4681759, total: 5121704, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.36757486681478696 0.8743894316163411
# 1 0.3435665663186176 0.8810224245115453
# 2 0.3336283209267177 0.8837422291296625
# 3 0.3283304161521181 0.8873501332149201
# 4 0.3233911138227239 0.8906527531083481
# 5 0.3203806666823577 0.890625
# 6 0.3189730944920854 0.8925399644760214
# 7 0.3188105299875519 0.89226243339254
# 8 0.3170672752050812 0.8938998667850799
# 9 0.3163802387725502 0.8944549289520426
# 0.8944765404492867
# embedding.weight     | nonzeros =  343610 / 5000200 (  6.87%) | total_pruned = 4656590 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2061 /   30000 (  6.87%) | total_pruned =   27939 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.1.weight       | nonzeros =    2748 /   40000 (  6.87%) | total_pruned =   37252 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.2.weight       | nonzeros =    3435 /   50000 (  6.87%) | total_pruned =   46565 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# fc.weight            | nonzeros =      82 /    1200 (  6.83%) | total_pruned =    1118 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 351953, pruned : 4769751, total: 5121704, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.3778830994496231 0.8715308614564832
# 1 0.3499248904460581 0.8792739786856127
# 2 0.3395214395727433 0.8814109680284192
# 3 0.33588028634231715 0.8833259325044405
# 4 0.33032300365099526 0.8857404529307282
# 5 0.32744800595510387 0.8885157637655418
# 6 0.3263204126096898 0.8887377886323268
# 7 0.3247943065587438 0.8903474689165186
# 8 0.32290143309389346 0.8907915186500888
# 9 0.3212431762896836 0.8920404085257548
# 0.8904499301389486
# embedding.weight     | nonzeros =  274888 / 5000200 (  5.50%) | total_pruned = 4725312 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1649 /   30000 (  5.50%) | total_pruned =   28351 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.1.weight       | nonzeros =    2198 /   40000 (  5.50%) | total_pruned =   37802 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.2.weight       | nonzeros =    2748 /   50000 (  5.50%) | total_pruned =   47252 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# fc.weight            | nonzeros =      65 /    1200 (  5.42%) | total_pruned =    1135 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 281562, pruned : 4840142, total: 5121704, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.3960991926279521 0.8678396980461812
# 1 0.3640424495341246 0.8738343694493783
# 2 0.35111457375779775 0.8787744227353463
# 3 0.34409460132829117 0.8812999555950266
# 4 0.3402813004080014 0.8829928952042628
# 5 0.3343856635410008 0.8843805506216696
# 6 0.3323313851632363 0.8849356127886323
# 7 0.32960763180191704 0.8869615896980462
# 8 0.3273456594890205 0.8874333925399644
# 9 0.32699318510954983 0.8884325044404974
# 0.8898809522139925
# embedding.weight     | nonzeros =  219910 / 5000200 (  4.40%) | total_pruned = 4780290 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1319 /   30000 (  4.40%) | total_pruned =   28681 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.1.weight       | nonzeros =    1758 /   40000 (  4.39%) | total_pruned =   38242 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.2.weight       | nonzeros =    2198 /   50000 (  4.40%) | total_pruned =   47802 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# fc.weight            | nonzeros =      52 /    1200 (  4.33%) | total_pruned =    1148 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 225248, pruned : 4896456, total: 5121704, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.4276372628951475 0.8589864564831261
# 1 0.38741042717570046 0.8656472024866785
# 2 0.3732633176631895 0.8690053285968028
# 3 0.36547544989470215 0.8722524422735346
# 4 0.3593619772171863 0.8729740230905861
# 5 0.35320780932122503 0.8753607904085258
# 6 0.35033316261980346 0.8778030639431617
# 7 0.34746783487763433 0.8782193605683837
# 8 0.3462916306645128 0.8793572380106572
# 9 0.34439483272130095 0.8787744227353463
# 0.8834908965255032
# embedding.weight     | nonzeros =  175928 / 5000200 (  3.52%) | total_pruned = 4824272 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1055 /   30000 (  3.52%) | total_pruned =   28945 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.1.weight       | nonzeros =    1406 /   40000 (  3.52%) | total_pruned =   38594 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.2.weight       | nonzeros =    1758 /   50000 (  3.52%) | total_pruned =   48242 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# fc.weight            | nonzeros =      41 /    1200 (  3.42%) | total_pruned =    1159 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 180196, pruned : 4941508, total: 5121704, Compression rate :      28.42x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.47477057600661876 0.8413354795737122
# 1 0.42835522516337793 0.8543794404973357
# 2 0.41081275400700673 0.858542406749556
# 3 0.40141572615009324 0.8596525310834814
# 4 0.3934175172261563 0.8628718916518651
# 5 0.3861987766963603 0.8659802397868561
# 6 0.38109775712683824 0.8683392539964476
# 7 0.3772053218282905 0.8683947602131439
# 8 0.37369293965677175 0.8693383658969804
# 9 0.370932291286665 0.8710313055062167
# 0.8735556722689075
# embedding.weight     | nonzeros =  140742 / 5000200 (  2.81%) | total_pruned = 4859458 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     844 /   30000 (  2.81%) | total_pruned =   29156 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.1.weight       | nonzeros =    1125 /   40000 (  2.81%) | total_pruned =   38875 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1406 /   50000 (  2.81%) | total_pruned =   48594 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      33 /    1200 (  2.75%) | total_pruned =    1167 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 144155, pruned : 4977549, total: 5121704, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.5243001148620783 0.8236845026642984
# 1 0.4722843851404493 0.8366452042628775
# 2 0.45231820909607473 0.8428063943161634
# 3 0.4383917430524928 0.846220026642984
# 4 0.42871295167447515 0.8488010657193605
# 5 0.4208948314090658 0.8512433392539964
# 6 0.4170100701506354 0.8541019094138543
# 7 0.4127223683193617 0.8546014653641207
# 8 0.40714737549291835 0.8561001332149201
# 9 0.40570705643065974 0.8574322824156305
# 0.8601628151260504
# embedding.weight     | nonzeros =  112593 / 5000200 (  2.25%) | total_pruned = 4887607 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     675 /   30000 (  2.25%) | total_pruned =   29325 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     900 /   40000 (  2.25%) | total_pruned =   39100 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1125 /   50000 (  2.25%) | total_pruned =   48875 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      26 /    1200 (  2.17%) | total_pruned =    1174 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 115323, pruned : 5006381, total: 5121704, Compression rate :      44.41x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.5725861114597024 0.8091418738898757
# 1 0.5206484373519942 0.8209369449378331
# 2 0.49763420486382703 0.8260435168738899
# 3 0.483444273183999 0.8300122113676732
# 4 0.4754031247940728 0.8332593250444049
# 5 0.46529458132679996 0.8376998223801065
# 6 0.4594597936497065 0.8389209591474245
# 7 0.45567773282858764 0.8398645648312612
# 8 0.45033579495723886 0.8413909857904085
# 9 0.4441659479248164 0.8441385435168739
# 0.844450279945085
# embedding.weight     | nonzeros =   90074 / 5000200 (  1.80%) | total_pruned = 4910126 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     540 /   30000 (  1.80%) | total_pruned =   29460 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     720 /   40000 (  1.80%) | total_pruned =   39280 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     900 /   50000 (  1.80%) | total_pruned =   49100 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      21 /    1200 (  1.75%) | total_pruned =    1179 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 92259, pruned : 5029445, total: 5121704, Compression rate :      55.51x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.6465120902069932 0.7921292184724689
# 1 0.5901157112285945 0.8075044404973357
# 2 0.5629605721702161 0.8142484458259325
# 3 0.5454214960535191 0.8168017317939609
# 4 0.5321073401752416 0.8211867229129662
# 5 0.5253475347457728 0.8234902309058615
# 6 0.5137826575439417 0.8244893428063943
# 7 0.5082888123488342 0.8272646536412078
# 8 0.5085258931914083 0.8279584813499112
# 9 0.5013490178908484 0.8302619893428064
# 0.828168767340043
# embedding.weight     | nonzeros =   72059 / 5000200 (  1.44%) | total_pruned = 4928141 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     432 /   30000 (  1.44%) | total_pruned =   29568 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     576 /   40000 (  1.44%) | total_pruned =   39424 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     720 /   50000 (  1.44%) | total_pruned =   49280 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      17 /    1200 (  1.42%) | total_pruned =    1183 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 73808, pruned : 5047896, total: 5121704, Compression rate :      69.39x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.6576128724704415 0.7826099023090586
# 1 0.6067232637935803 0.7942662078152753
# 2 0.5798823671220251 0.8016485346358793
# 3 0.5616155976221151 0.8072546625222025
# 4 0.5492001993790083 0.8111956039076377
# 5 0.5412535630431204 0.8132770870337478
# 6 0.5321123788123339 0.8167739786856127
# 7 0.5254692939469064 0.8175788188277087
# 8 0.5244969693914082 0.8182171403197158
# 9 0.5208952652082033 0.8200210923623446
# 0.8203781512605042
# embedding.weight     | nonzeros =   57647 / 5000200 (  1.15%) | total_pruned = 4942553 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     345 /   30000 (  1.15%) | total_pruned =   29655 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     461 /   40000 (  1.15%) | total_pruned =   39539 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     576 /   50000 (  1.15%) | total_pruned =   49424 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      13 /    1200 (  1.08%) | total_pruned =    1187 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 59046, pruned : 5062658, total: 5121704, Compression rate :      86.74x  ( 98.85% pruned)

# %%
# lt
print(performance)
print(valid_losses)
lt_performance = performance
lt_valid_losses = valid_losses
# Out:
# [89.17629553490326, 89.27258403361344, 89.20255603910493, 89.05374648190346, 89.01435572560094, 88.74737394957984, 88.92244396089507, 89.02310924369748, 89.47829133322259, 89.48266806722688, 89.55707284582763, 89.40826328862616, 89.44765404492867, 89.04499301389485, 88.98809522139925, 88.34908965255032, 87.35556722689076, 86.01628151260505, 84.44502799450851, 82.8168767340043, 82.03781512605042]
# [0.4903469795582826, 0.5200342282977081, 0.528166301833833, 0.5485064474192529, 0.5314629773675922, 0.5035648893376359, 0.46586191793738285, 0.42392328485712527, 0.38590874453033874, 0.36560916666149906, 0.33990500031657794, 0.3286562784960358, 0.3163802387725502, 0.3212431762896836, 0.32699318510954983, 0.34439483272130095, 0.370932291286665, 0.40570705643065974, 0.4441659479248164, 0.5013490178908484, 0.5208952652082033]

# %% [markdown]
# ## 3) lt+lr (last epoch)

# %%
reinit = False # random이면 True, lt면 False
mode = 'lr_l'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.CrossEntropyLoss()

criterion = criterion.to(device)

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  # torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  # late rewinding after the last epoch
  if pruning_iter == 0:
     initial_state_dict = copy.deepcopy(model.state_dict())

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.3983324510450632 0.8598190497335702
# 1 0.33071174894064187 0.8859347246891652
# 2 0.31402966333470483 0.8939831261101243
# 3 0.30595468736020437 0.8987844138543517
# 4 0.3240867186847207 0.8966751776198935
# 5 0.34322303917993446 0.8995615008880995
# 6 0.3638875876548394 0.8986734014209592
# 7 0.39925411522229654 0.8989231793960923
# 8 0.44341993281290226 0.8986456483126111
# 9 0.47760290064936634 0.8980905861456483
# 0.8988095236425641
# embedding.weight     | nonzeros = 5000200 / 5000200 (100.00%) | total_pruned =       0 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   30000 /   30000 (100.00%) | total_pruned =       0 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.1.weight       | nonzeros =   40000 /   40000 (100.00%) | total_pruned =       0 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.2.weight       | nonzeros =   50000 /   50000 (100.00%) | total_pruned =       0 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# fc.weight            | nonzeros =    1200 /    1200 (100.00%) | total_pruned =       0 | shape = (4, 300)
# fc.bias              | nonzeros =       4 /       4 (100.00%) | total_pruned =       0 | shape = (4,)
# alive: 5121704, pruned : 0, total: 5121704, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.5104292459607284 0.8964531527531083
# 1 0.5397406163795804 0.8957870781527532
# 2 0.5872415801242232 0.8969249555950266
# 3 0.6089673584317177 0.8966474245115453
# 4 0.6540703233132936 0.8958425843694494
# 5 0.6742961894899447 0.8967029307282416
# 6 0.7044037463040906 0.8965364120781527
# 7 0.7415670426843645 0.8952875222024866
# 8 0.7643689862444176 0.8963421403197158
# 9 0.7856049215665905 0.8941218916518651
# 0.8941264007271839
# embedding.weight     | nonzeros = 4000160 / 5000200 ( 80.00%) | total_pruned = 1000040 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   24000 /   30000 ( 80.00%) | total_pruned =    6000 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.1.weight       | nonzeros =   32000 /   40000 ( 80.00%) | total_pruned =    8000 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.2.weight       | nonzeros =   40000 /   50000 ( 80.00%) | total_pruned =   10000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# fc.weight            | nonzeros =     960 /    1200 ( 80.00%) | total_pruned =     240 | shape = (4, 300)
# fc.bias              | nonzeros =       3 /       4 ( 75.00%) | total_pruned =       1 | shape = (4,)
# alive: 4097363, pruned : 1024341, total: 5121704, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.5234015915066428 0.8982293516873889
# 1 0.5565709016049284 0.8964531527531083
# 2 0.6119160565909918 0.8972579928952042
# 3 0.6404580561854408 0.8962033747779752
# 4 0.6836264677325902 0.8963976465364121
# 5 0.714475203044117 0.8943439165186501
# 6 0.7527093617402705 0.8954540408525755
# 7 0.777356134671354 0.8949822380106572
# 8 0.7986117757717892 0.8941218916518651
# 9 0.8272611256457243 0.8929285079928952
# 0.893294817760211
# embedding.weight     | nonzeros = 3200128 / 5000200 ( 64.00%) | total_pruned = 1800072 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   19200 /   30000 ( 64.00%) | total_pruned =   10800 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.1.weight       | nonzeros =   25600 /   40000 ( 64.00%) | total_pruned =   14400 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.2.weight       | nonzeros =   32000 /   50000 ( 64.00%) | total_pruned =   18000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# fc.weight            | nonzeros =     768 /    1200 ( 64.00%) | total_pruned =     432 | shape = (4, 300)
# fc.bias              | nonzeros =       2 /       4 ( 50.00%) | total_pruned =       2 | shape = (4,)
# alive: 3277890, pruned : 1843814, total: 5121704, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.49508836770225084 0.8960368561278863
# 1 0.5484458667219518 0.8977575488454707
# 2 0.588240939834309 0.8965919182948491
# 3 0.635450053110646 0.8962033747779752
# 4 0.6637399948328621 0.8945104351687388
# 5 0.6966386273020273 0.8947879662522202
# 6 0.7124752198742144 0.8952875222024866
# 7 0.7417596538218655 0.8952320159857904
# 8 0.7827773766503644 0.8944271758436945
# 9 0.789449169230606 0.893511323268206
# 0.8944765404492867
# embedding.weight     | nonzeros = 2560102 / 5000200 ( 51.20%) | total_pruned = 2440098 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   15360 /   30000 ( 51.20%) | total_pruned =   14640 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.1.weight       | nonzeros =   20480 /   40000 ( 51.20%) | total_pruned =   19520 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.2.weight       | nonzeros =   25600 /   50000 ( 51.20%) | total_pruned =   24400 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# fc.weight            | nonzeros =     614 /    1200 ( 51.17%) | total_pruned =     586 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2622310, pruned : 2499394, total: 5121704, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.4603472642057127 0.8954540408525755
# 1 0.5105206674214231 0.8947879662522202
# 2 0.5543396547002483 0.8944549289520426
# 3 0.5961356538589415 0.8942329040852576
# 4 0.6303981143061476 0.8930395204262878
# 5 0.6697135837909932 0.8936223357015985
# 6 0.703320280803437 0.894316163410302
# 7 0.7205147687225812 0.8941496447602132
# 8 0.7486788503005588 0.8925677175843695
# 9 0.764360493566381 0.8924289520426287
# 0.891237745264999
# embedding.weight     | nonzeros = 2048081 / 5000200 ( 40.96%) | total_pruned = 2952119 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   12288 /   30000 ( 40.96%) | total_pruned =   17712 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.1.weight       | nonzeros =   16384 /   40000 ( 40.96%) | total_pruned =   23616 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.2.weight       | nonzeros =   20480 /   50000 ( 40.96%) | total_pruned =   29520 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# fc.weight            | nonzeros =     491 /    1200 ( 40.92%) | total_pruned =     709 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 2097848, pruned : 3023856, total: 5121704, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.4307010005987919 0.8948712255772646
# 1 0.48216412431555494 0.8944271758436945
# 2 0.5186695171620194 0.8943994227353463
# 3 0.5515018828109 0.8946769538188277
# 4 0.582897197603039 0.8943716696269982
# 5 0.6171659766948662 0.8945104351687388
# 6 0.647589687896325 0.8933170515097691
# 7 0.6698535590810573 0.8942051509769094
# 8 0.697997487183217 0.8925399644760214
# 9 0.716475346135174 0.8932615452930728
# 0.8921568629120579
# embedding.weight     | nonzeros = 1638465 / 5000200 ( 32.77%) | total_pruned = 3361735 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    9830 /   30000 ( 32.77%) | total_pruned =   20170 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# convs.1.weight       | nonzeros =   13107 /   40000 ( 32.77%) | total_pruned =   26893 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# convs.2.weight       | nonzeros =   16384 /   50000 ( 32.77%) | total_pruned =   33616 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# fc.weight            | nonzeros =     393 /    1200 ( 32.75%) | total_pruned =     807 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1678279, pruned : 3443425, total: 5121704, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.40061979589745617 0.8948712255772646
# 1 0.4377899735460478 0.8935668294849023
# 2 0.4657060299345512 0.8935390763765542
# 3 0.501522303373614 0.8937055950266429
# 4 0.5278938781757687 0.8937611012433393
# 5 0.5523044095270428 0.8930395204262878
# 6 0.5751531715171397 0.8925399644760214
# 7 0.6002672861154864 0.8927897424511545
# 8 0.6239712813676402 0.8940941385435168
# 9 0.6415816216107597 0.8945104351687388
# 0.8930759805591166
# embedding.weight     | nonzeros = 1310772 / 5000200 ( 26.21%) | total_pruned = 3689428 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    7864 /   30000 ( 26.21%) | total_pruned =   22136 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# convs.1.weight       | nonzeros =   10485 /   40000 ( 26.21%) | total_pruned =   29515 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# convs.2.weight       | nonzeros =   13107 /   50000 ( 26.21%) | total_pruned =   36893 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# fc.weight            | nonzeros =     314 /    1200 ( 26.17%) | total_pruned =     886 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1342621, pruned : 3779083, total: 5121704, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.37686294732949505 0.8932615452930728
# 1 0.40363763215299037 0.8940663854351687
# 2 0.42874605082025913 0.8943994227353463
# 3 0.4518994629204432 0.8938166074600356
# 4 0.4712469007547566 0.8936223357015985
# 5 0.4960861403840804 0.8940941385435168
# 6 0.510714866376654 0.893511323268206
# 7 0.5267475560850499 0.8927064831261101
# 8 0.5412531414830795 0.8938166074600356
# 9 0.5579049952872441 0.8929285079928952
# 0.8929446780381083
# embedding.weight     | nonzeros = 1048617 / 5000200 ( 20.97%) | total_pruned = 3951583 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    6291 /   30000 ( 20.97%) | total_pruned =   23709 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# convs.1.weight       | nonzeros =    8388 /   40000 ( 20.97%) | total_pruned =   31612 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# convs.2.weight       | nonzeros =   10485 /   50000 ( 20.97%) | total_pruned =   39515 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# fc.weight            | nonzeros =     251 /    1200 ( 20.92%) | total_pruned =     949 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 1074096, pruned : 4047608, total: 5121704, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.35347848619922884 0.8938443605683837
# 1 0.3722329745503377 0.8940663854351687
# 2 0.3860339406873827 0.8945659413854352
# 3 0.3998496813044534 0.8952597690941385
# 4 0.41358838504929674 0.895148756660746
# 5 0.42454767076598005 0.8941496447602132
# 6 0.4397452338085862 0.8947879662522202
# 7 0.44923752500488695 0.8949822380106572
# 8 0.46180060274659557 0.8953985346358793
# 9 0.47395647187397993 0.8947047069271759
# 0.8960521707013875
# embedding.weight     | nonzeros =  838893 / 5000200 ( 16.78%) | total_pruned = 4161307 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    5033 /   30000 ( 16.78%) | total_pruned =   24967 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# convs.1.weight       | nonzeros =    6710 /   40000 ( 16.77%) | total_pruned =   33290 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# convs.2.weight       | nonzeros =    8388 /   50000 ( 16.78%) | total_pruned =   41612 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# fc.weight            | nonzeros =     201 /    1200 ( 16.75%) | total_pruned =     999 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 859277, pruned : 4262427, total: 5121704, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.3340979043134202 0.8941218916518651
# 1 0.3430841151950798 0.8953152753108348
# 2 0.3568393997304211 0.8968139431616341
# 3 0.3648765146104556 0.8962588809946714
# 4 0.3703239225492139 0.8973412522202486
# 5 0.3781743324843531 0.8980628330373002
# 6 0.3863226920606148 0.8972579928952042
# 7 0.39460846913881686 0.8981738454706927
# 8 0.4010851295790213 0.8978685612788633
# 9 0.4070228692549438 0.8976742895204263
# 0.8956144957983193
# embedding.weight     | nonzeros =  671114 / 5000200 ( 13.42%) | total_pruned = 4329086 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    4026 /   30000 ( 13.42%) | total_pruned =   25974 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# convs.1.weight       | nonzeros =    5368 /   40000 ( 13.42%) | total_pruned =   34632 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# convs.2.weight       | nonzeros =    6710 /   50000 ( 13.42%) | total_pruned =   43290 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# fc.weight            | nonzeros =     161 /    1200 ( 13.42%) | total_pruned =    1039 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 687419, pruned : 4434285, total: 5121704, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.32622714509023765 0.8904584813499112
# 1 0.3331848531711241 0.8929840142095915
# 2 0.336745905244498 0.8939553730017762
# 3 0.34110345912156015 0.8944826820603907
# 4 0.34410616832840724 0.8953152753108348
# 5 0.34761701740091255 0.8961756216696269
# 6 0.35069700689729116 0.8963421403197158
# 7 0.3559336192193764 0.8957870781527532
# 8 0.3566867285879531 0.8957315719360568
# 9 0.36305586475273927 0.8960923623445826
# 0.8981967788784444
# embedding.weight     | nonzeros =  536891 / 5000200 ( 10.74%) | total_pruned = 4463309 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    3221 /   30000 ( 10.74%) | total_pruned =   26779 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.1.weight       | nonzeros =    4294 /   40000 ( 10.73%) | total_pruned =   35706 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.2.weight       | nonzeros =    5368 /   50000 ( 10.74%) | total_pruned =   44632 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# fc.weight            | nonzeros =     129 /    1200 ( 10.75%) | total_pruned =    1071 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 549934, pruned : 4571770, total: 5121704, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.3185850271574043 0.8921791740674956
# 1 0.31615498045924223 0.8946214476021315
# 2 0.31822325777986993 0.8952042628774423
# 3 0.3179288182625147 0.8962033747779752
# 4 0.3207240418543821 0.8961756216696269
# 5 0.32166194334563336 0.8977297957371225
# 6 0.3263972705860993 0.8982571047957372
# 7 0.32659836829810357 0.8984513765541741
# 8 0.3294812531510722 0.8991729573712256
# 9 0.32829534489046086 0.8993117229129662
# 0.8950892857142857
# embedding.weight     | nonzeros =  429513 / 5000200 (  8.59%) | total_pruned = 4570687 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2577 /   30000 (  8.59%) | total_pruned =   27423 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.1.weight       | nonzeros =    3435 /   40000 (  8.59%) | total_pruned =   36565 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.2.weight       | nonzeros =    4294 /   50000 (  8.59%) | total_pruned =   45706 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# fc.weight            | nonzeros =     103 /    1200 (  8.58%) | total_pruned =    1097 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 439947, pruned : 4681757, total: 5121704, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.3233201048209962 0.889792406749556
# 1 0.31752816284634505 0.8910690497335702
# 2 0.31400985088609623 0.8934280639431617
# 3 0.31530178362130623 0.8950377442273535
# 4 0.3145601236018258 0.8958980905861457
# 5 0.31326730477129033 0.8966751776198935
# 6 0.31268873926066854 0.8977020426287744
# 7 0.31558106275073533 0.8981738454706927
# 8 0.3156455854668578 0.8976465364120781
# 9 0.31641890482437757 0.8984791296625222
# 0.8962710084033614
# embedding.weight     | nonzeros =  343610 / 5000200 (  6.87%) | total_pruned = 4656590 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2061 /   30000 (  6.87%) | total_pruned =   27939 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.1.weight       | nonzeros =    2748 /   40000 (  6.87%) | total_pruned =   37252 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.2.weight       | nonzeros =    3435 /   50000 (  6.87%) | total_pruned =   46565 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# fc.weight            | nonzeros =      82 /    1200 (  6.83%) | total_pruned =    1118 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 351955, pruned : 4769749, total: 5121704, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.3394440245896505 0.8830206483126111
# 1 0.3280163763105856 0.8873778863232682
# 2 0.3238516865615761 0.8884325044404974
# 3 0.32069884668489784 0.8900421847246892
# 4 0.31982416697226956 0.8914853463587922
# 5 0.31727251407010465 0.8915130994671403
# 6 0.3169994138182864 0.8928452486678508
# 7 0.316976449254662 0.8939276198934281
# 8 0.3174533746792516 0.8934280639431617
# 9 0.3161260039466193 0.8940108792184724
# 0.8965336134453782
# embedding.weight     | nonzeros =  274888 / 5000200 (  5.50%) | total_pruned = 4725312 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1649 /   30000 (  5.50%) | total_pruned =   28351 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.1.weight       | nonzeros =    2198 /   40000 (  5.50%) | total_pruned =   37802 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.2.weight       | nonzeros =    2748 /   50000 (  5.50%) | total_pruned =   47252 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# fc.weight            | nonzeros =      65 /    1200 (  5.42%) | total_pruned =    1135 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 281564, pruned : 4840140, total: 5121704, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.35691021890817853 0.8779695825932504
# 1 0.3424758571671524 0.8816329928952042
# 2 0.33754377210592157 0.8827708703374778
# 3 0.33349508531954053 0.8853241563055062
# 4 0.3319988219409877 0.8859902309058615
# 5 0.32866434664523386 0.8874056394316163
# 6 0.327549546771744 0.8878219360568383
# 7 0.3262087049923811 0.8888488010657194
# 8 0.3246245974985813 0.8890985790408525
# 9 0.32380168150356087 0.8895703818827708
# 0.8909313723820598
# embedding.weight     | nonzeros =  219910 / 5000200 (  4.40%) | total_pruned = 4780290 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1319 /   30000 (  4.40%) | total_pruned =   28681 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.1.weight       | nonzeros =    1758 /   40000 (  4.39%) | total_pruned =   38242 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.2.weight       | nonzeros =    2198 /   50000 (  4.40%) | total_pruned =   47802 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# fc.weight            | nonzeros =      52 /    1200 (  4.33%) | total_pruned =    1148 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 225250, pruned : 4896454, total: 5121704, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.3886633649845583 0.8690885879218473
# 1 0.36689590631784014 0.8737233570159858
# 2 0.35942363853154446 0.8751942717584369
# 3 0.35300767187402976 0.8769704706927176
# 4 0.3491015935541655 0.8772480017761989
# 5 0.3466806051802704 0.8792462255772646
# 6 0.34353195533129927 0.8801898312611013
# 7 0.34285306602511323 0.8812444493783304
# 8 0.3416362022708102 0.8814387211367674
# 9 0.33987870604481357 0.8826876110124334
# 0.8813025210084033
# embedding.weight     | nonzeros =  175928 / 5000200 (  3.52%) | total_pruned = 4824272 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1055 /   30000 (  3.52%) | total_pruned =   28945 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.1.weight       | nonzeros =    1406 /   40000 (  3.52%) | total_pruned =   38594 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.2.weight       | nonzeros =    1758 /   50000 (  3.52%) | total_pruned =   48242 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# fc.weight            | nonzeros =      41 /    1200 (  3.42%) | total_pruned =    1159 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 180198, pruned : 4941506, total: 5121704, Compression rate :      28.42x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.43948547535147486 0.8519926731793961
# 1 0.41012734624674646 0.8604018650088809
# 2 0.39778054468201385 0.8644260657193605
# 3 0.3900985659313509 0.8662022646536413
# 4 0.3827011664273948 0.8680617229129662
# 5 0.38040520365268893 0.8682837477797514
# 6 0.3753877969964889 0.8704484902309059
# 7 0.37122590948379275 0.8712255772646537
# 8 0.36824916509934574 0.8717251332149201
# 9 0.36557976667625336 0.8736678507992895
# 0.8753063723820598
# embedding.weight     | nonzeros =  140742 / 5000200 (  2.81%) | total_pruned = 4859458 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     844 /   30000 (  2.81%) | total_pruned =   29156 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.1.weight       | nonzeros =    1125 /   40000 (  2.81%) | total_pruned =   38875 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.2.weight       | nonzeros =    1406 /   50000 (  2.81%) | total_pruned =   48594 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# fc.weight            | nonzeros =      33 /    1200 (  2.75%) | total_pruned =    1167 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 144157, pruned : 4977547, total: 5121704, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.4893123775350052 0.8299567051509769
# 1 0.4661937505205296 0.8353685612788633
# 2 0.4545067818885004 0.8393372557726465
# 3 0.4422174022792711 0.841279973357016
# 4 0.43536363511642384 0.8446658525754884
# 5 0.43127408634282344 0.8453319271758437
# 6 0.42385449347815757 0.8470803730017762
# 7 0.41866615199571605 0.8481349911190054
# 8 0.4146022586347155 0.8498834369449378
# 9 0.4127507591702798 0.8501054618117229
# 0.8539915966386554
# embedding.weight     | nonzeros =  112593 / 5000200 (  2.25%) | total_pruned = 4887607 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     675 /   30000 (  2.25%) | total_pruned =   29325 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     900 /   40000 (  2.25%) | total_pruned =   39100 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1125 /   50000 (  2.25%) | total_pruned =   48875 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      26 /    1200 (  2.17%) | total_pruned =    1174 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 115323, pruned : 5006381, total: 5121704, Compression rate :      44.41x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.5424699683807671 0.8012322380106572
# 1 0.5176156128675645 0.8061722912966253
# 2 0.5083548465469061 0.8076709591474245
# 3 0.49862784357678613 0.8109735790408525
# 4 0.49425294510954015 0.8123057282415631
# 5 0.4874723028742293 0.8128885435168739
# 6 0.4844234481348026 0.8138321492007105
# 7 0.47815989857112745 0.8170515097690941
# 8 0.4742783567575377 0.8185779307282416
# 9 0.4711759389273915 0.8189942273534636
# 0.8100927872818058
# embedding.weight     | nonzeros =   90075 / 5000200 (  1.80%) | total_pruned = 4910125 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     540 /   30000 (  1.80%) | total_pruned =   29460 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     720 /   40000 (  1.80%) | total_pruned =   39280 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     900 /   50000 (  1.80%) | total_pruned =   49100 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      21 /    1200 (  1.75%) | total_pruned =    1179 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 92260, pruned : 5029444, total: 5121704, Compression rate :      55.51x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.776493269136278 0.6786745115452931
# 1 0.7605812368156855 0.6983792184724689
# 2 0.750825596255371 0.7163077264653641
# 3 0.7436318481556052 0.7240508436944938
# 4 0.7410287264449982 0.7311556394316163
# 5 0.7343047934569432 0.7349578152753108
# 6 0.7307130149689703 0.7373168294849023
# 7 0.7264105528394558 0.7374000888099467
# 8 0.7232245690789781 0.7376776198934281
# 9 0.7216688266444163 0.7383992007104796
# 0.7364758403361344
# embedding.weight     | nonzeros =   72060 / 5000200 (  1.44%) | total_pruned = 4928140 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     432 /   30000 (  1.44%) | total_pruned =   29568 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     576 /   40000 (  1.44%) | total_pruned =   39424 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     720 /   50000 (  1.44%) | total_pruned =   49280 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      17 /    1200 (  1.42%) | total_pruned =    1183 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 73809, pruned : 5047895, total: 5121704, Compression rate :      69.39x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.8822545024895541 0.5971081261101243
# 1 0.8612453620980095 0.6064054174067496
# 2 0.853594956294258 0.6133436944937833
# 3 0.8454507164802687 0.6163410301953819
# 4 0.840197118995033 0.6203652309058615
# 5 0.8343437657316032 0.6233348134991119
# 6 0.8295551617869688 0.6254718028419183
# 7 0.8257071573823214 0.6240841474245116
# 8 0.8218551721443715 0.6289686944937833
# 9 0.8191221024755051 0.6303285968028419
# 0.6295518207700312
# embedding.weight     | nonzeros =   57648 / 5000200 (  1.15%) | total_pruned = 4942552 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     345 /   30000 (  1.15%) | total_pruned =   29655 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     461 /   40000 (  1.15%) | total_pruned =   39539 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     576 /   50000 (  1.15%) | total_pruned =   49424 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      13 /    1200 (  1.08%) | total_pruned =    1187 | shape = (4, 300)
# fc.bias              | nonzeros =       1 /       4 ( 25.00%) | total_pruned =       3 | shape = (4,)
# alive: 59047, pruned : 5062657, total: 5121704, Compression rate :      86.74x  ( 98.85% pruned)

# %%
# lr_l
print(performance)
print(valid_losses)

lr_l_performance = performance
lr_l_valid_losses = valid_losses
# Out:
# [89.8809523642564, 89.41264007271839, 89.3294817760211, 89.44765404492867, 89.1237745264999, 89.21568629120578, 89.30759805591167, 89.29446780381083, 89.60521707013875, 89.56144957983193, 89.81967788784443, 89.50892857142857, 89.62710084033614, 89.65336134453781, 89.09313723820598, 88.13025210084034, 87.53063723820598, 85.39915966386555, 81.00927872818058, 73.64758403361344, 62.95518207700312]
# [0.47760290064936634, 0.7856049215665905, 0.8272611256457243, 0.789449169230606, 0.764360493566381, 0.716475346135174, 0.6415816216107597, 0.5579049952872441, 0.47395647187397993, 0.4070228692549438, 0.36305586475273927, 0.32829534489046086, 0.31641890482437757, 0.3161260039466193, 0.32380168150356087, 0.33987870604481357, 0.36557976667625336, 0.4127507591702798, 0.4711759389273915, 0.7216688266444163, 0.8191221024755051]
