# %% [markdown]
# [reference](https://github.com/bentrevett/pytorch-sentiment-analysis)

# %%
# Importing Libraries
import os
import copy
import time
import torch
import torchtext
from torchtext import data
from torchtext import datasets
from torchtext.vocab import GloVe
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/lt-module'
os.chdir(path)

# %%
# Custom Libraries
import DataLoader
import Model

# %% [markdown]
# ## Define functions - to load dataset & model

# %%
# load dataset
def load_dataset(dataset, architecture, batch_size, device, path):
    if dataset == "imdb":
      if architecture == "cnn":
        data = DataLoader.IMDB_CNN_CUSTOM(batch_size, device, path)
      elif architecture == "lstm":
        data = DataLoader.IMDB_LSTM(batch_size, device, path)

    elif dataset == "agnews":
        data = DataLoader.AGNEWS(batch_size, device, path)

    else:
        raise ValueError(dataset + "is not supported")

    return data

# load model and set hyperparameters
def load_model(architecture, data_choice, batch_size):

    if architecture == "cnn":
      # hyperparameters
      vocab_size = len(dataset.TEXT.vocab)
      embedding_dim = 100
      n_filters = 100
      filter_sizes = [3,4,5]
      dropout = 0.5
      pad_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.pad_token]
      
      if data_choice == "imdb":
        # binary-class
        output_dim = 1
        model = Model.binaryCNN(vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout, pad_idx)
      
      elif data_choice == "agnews":
        # multi-class
        output_dim = 4
        model = Model.multiCNN(vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout, pad_idx)

      unk_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.unk_token]
      model.embedding.weight.data[unk_idx] = torch.zeros(embedding_dim)
      model.embedding.weight.data[pad_idx] = torch.zeros(embedding_dim)

      return model

    elif architecture == "lstm":
      # hyperparameters
      vocab_size = len(dataset.TEXT.vocab)
      embedding_dim = 100
      hidden_dim = 256
      output_dim = 1
      n_layers = 2
      bidirectional = True
      dropout = 0.5
      pad_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.pad_token]
      
      if data_choice == "imdb":
        # binary-class
        output_dim = 1
      
      elif data_choice == "agnews":
        # multi-class
        output_dim = 4
      
      model = Model.LSTM(vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout, pad_idx)

      unk_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.unk_token]
      model.embedding.weight.data[unk_idx] = torch.zeros(embedding_dim)
      model.embedding.weight.data[pad_idx] = torch.zeros(embedding_dim)

      return model

    # temporary
    elif architecture == "bert":
        return None

    else:
        raise ValueError(architecture + "is not supported")

# %% [markdown]
# ## Weight initialization

# %%
# weight initializtion
def initialize_xavier_normal(m):
    
  """
	Function to initialize a layer by picking weights from a xavier normal distribution
	Arguments
	---------
	m : The layer of the neural network
	Returns
	-------
	None
	"""
  
  if type(m) == torch.nn.Conv2d:
    torch.nn.init.xavier_normal_(m.weight.data)
    m.bias.data.fill_(0)

  elif isinstance(m, torch.nn.Linear):
    torch.nn.init.xavier_normal_(m.weight.data)
    m.bias.data.fill_(0)

  elif type(m) in [torch.nn.GRU, torch.nn.LSTM, torch.nn.RNN]:
    for name, param in m.named_parameters():
        if 'weight_ih' in name:
          torch.nn.init.xavier_normal_(param.data)
        elif 'weight_hh' in name:
          torch.nn.init.orthogonal_(param.data)
        elif 'bias' in name:
          param.data.fill_(0)

# %% [markdown]
# ## train and test functions

# %%
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    return acc

# %%
def train(model, iterator, optimizer, criterion):
    # EPS = 1e-6
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for batch in iterator:
      
      text = batch.text[0]
      target = batch.label
        
      optimizer.zero_grad()
      predictions = model(text).squeeze(1)
      loss = criterion(predictions, target)
      acc = binary_accuracy(predictions, target)
      loss.backward()
      step = 0

      # Freezing Pruned weights by making their gradients Zero
      for name, p in model.named_parameters():
        weight_dev = param.device
        tensor = p.data.cpu().numpy()
        grad_tensor = p.grad.data.cpu().numpy()
        grad_tensor = np.where(mask[step] == 0, 0, grad_tensor)
        p.grad.data = torch.from_numpy(grad_tensor).to(device)
        step += 1
      
      step = 0

      optimizer.step()
        
      epoch_loss += loss.item()
      epoch_acc += acc.item()
      
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
          text = batch.text[0]
          target = batch.label

          predictions = model(batch.text[0]).squeeze(1)
            
          loss = criterion(predictions, batch.label)
            
          acc = binary_accuracy(predictions, batch.label)

          epoch_loss += loss.item()
          epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# ## Pruning Functions

# %%
# Prune by Percentile module
def prune_by_percentile(percent):
  global step
  global mask
  global model
  # Calculate percentile value
  step = 0
  for name, param in model.named_parameters():
    # if 'weight' in name:
    tensor = param.data.cpu().numpy()
    nz_count = np.count_nonzero(tensor)

    # bias가 all pruned 되는 경우 발생
    if nz_count == 0:
      step += 1

    else: 
      alive = tensor[np.nonzero(tensor)] # flattened array of nonzero values
      percentile_value = np.percentile(abs(alive), percent)

      # Convert Tensors to numpy and calculate
      weight_dev = param.device
      new_mask = np.where(abs(tensor) < percentile_value, 0, mask[step])
                
      # Apply new weight and mask
      param.data = torch.from_numpy(tensor * new_mask).to(weight_dev)
      mask[step] = new_mask
      step += 1

  step = 0

# %%
# Function to make an empty mask of the same size as the model
def make_mask(model):
  global step
  global mask
  
  step = 0
  for name, param in model.named_parameters(): 
    # if 'weight' in name:
    step += 1
  mask = [None]* step 
  step = 0
  for name, param in model.named_parameters(): 
    # if 'weight' in name:
    tensor = param.data.cpu().numpy()
    mask[step] = np.ones_like(tensor)
    step += 1
  step = 0

# %%
def original_initialization(mask_temp, initial_state_dict):
    global step
    global model
    
    step = 0
    for name, param in model.named_parameters(): 
        # if "weight" in name: 
            weight_dev = param.device
            param.data = torch.from_numpy(mask_temp[step] * initial_state_dict[name].cpu().numpy()).to(weight_dev)
            step = step + 1
        # if "bias" in name:
            # param.data = initial_state_dict[name]
    step = 0

# %%
# ANCHOR Print table of zeros and non-zeros count
def print_nonzeros(model):
    nonzero = total = 0
    for name, p in model.named_parameters():
        tensor = p.data.cpu().numpy()
        nz_count = np.count_nonzero(tensor)
        total_params = np.prod(tensor.shape)
        nonzero += nz_count
        total += total_params
        print(f'{name:20} | nonzeros = {nz_count:7} / {total_params:7} ({100 * nz_count / total_params:6.2f}%) | total_pruned = {total_params - nz_count :7} | shape = {tensor.shape}')
    print(f'alive: {nonzero}, pruned : {total - nonzero}, total: {total}, Compression rate : {total/nonzero:10.2f}x  ({100 * (total-nonzero) / total:6.2f}% pruned)')
    return (round(((total-nonzero)/total)*100,1))

# %% [markdown]
# ## Choose dataset & model

# %%
# colab에서 돌리기 때문에 우선 arg가 아니라 변수로 넘겨주기
data_choice = "imdb" # 데이터셋 선택
arch_choice = "cnn" # 모델 선택
batch_size = 64 # batch size 선택 - 32 or 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using {device} device.')
# Out:
# Using cuda device.

# %% [markdown]
# ### load dataset

# %%
dataset = load_dataset(data_choice, arch_choice, batch_size, device, path)

# %% [markdown]
# ### model setting

# %%
# check the trial number
trial = 601

# pruning setting
iteration = 20
percent = 20 # 20% prune
N_EPOCH = 20
learning_rate = 5e-3

step = 0

# %% [markdown]
# ## 1) random initialization

# %%
reinit = True # random이면 True, lt면 False
mode = 'random'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# embedding 같은 것 주기 위해
embedding_pretrained_weight = model.embedding.weight

# model initialization and save the model
model.apply(initialize_xavier_normal)
# Out:
# binaryCNN(
#   (embedding): Embedding(50002, 100, padding_idx=1)
#   (convs): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(3, 100), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(4, 100), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(5, 100), stride=(1, 1))
#   )
#   (fc): Linear(in_features=300, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 5,120,801 trainable parameters

# %%
# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.BCEWithLogitsLoss()

criterion = criterion.to(device)

# %%
for name, param in model.named_parameters():
  print(name, param.size())
# Out:
# embedding.weight torch.Size([50002, 100])
# convs.0.weight torch.Size([100, 1, 3, 100])
# convs.0.bias torch.Size([100])
# convs.1.weight torch.Size([100, 1, 4, 100])
# convs.1.bias torch.Size([100])
# convs.2.weight torch.Size([100, 1, 5, 100])
# convs.2.bias torch.Size([100])
# fc.weight torch.Size([1, 300])
# fc.bias torch.Size([1])

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  best_valid_loss = float('inf')
  # early stopping
  count = 0
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        best_state_dict = copy.deepcopy(model.state_dict())

    else:
        count +=1
        
    if count == 2:
        print(f'Early Stopping at {epoch}')
        break

  model.load_state_dict(best_state_dict)
  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(best_valid_loss, test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.4287474274318269 0.7951296542553191
# 1 0.31409712987852856 0.8680186170212766
# 2 0.32625685447945874 0.8732546542553191
# 3 0.4349267495439408 0.8681848404255319
# Early Stopping at 3
# 0.31409712987852856 0.8645501592356688
# embedding.weight     | nonzeros = 5000100 / 5000200 (100.00%) | total_pruned =     100 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   30000 /   30000 (100.00%) | total_pruned =       0 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.1.weight       | nonzeros =   40000 /   40000 (100.00%) | total_pruned =       0 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.2.weight       | nonzeros =   50000 /   50000 (100.00%) | total_pruned =       0 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# fc.weight            | nonzeros =     300 /     300 (100.00%) | total_pruned =       0 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 5120701, pruned : 100, total: 5120801, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.3569584427837362 0.85546875
# 1 0.3696991730521017 0.8748337765957447
# 2 0.45010001866265814 0.8731715425531915
# Early Stopping at 2
# 0.3569584427837362 0.8562898089171974
# embedding.weight     | nonzeros = 4000080 / 5000200 ( 80.00%) | total_pruned = 1000120 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   24000 /   30000 ( 80.00%) | total_pruned =    6000 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      65 /     100 ( 65.00%) | total_pruned =      35 | shape = (100,)
# convs.1.weight       | nonzeros =   32000 /   40000 ( 80.00%) | total_pruned =    8000 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.2.weight       | nonzeros =   40000 /   50000 ( 80.00%) | total_pruned =   10000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      61 /     100 ( 61.00%) | total_pruned =      39 | shape = (100,)
# fc.weight            | nonzeros =     240 /     300 ( 80.00%) | total_pruned =      60 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 4096511, pruned : 1024290, total: 5120801, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.35852400292741493 0.8726728723404256
# 1 0.40885576308566207 0.8675199468085106
# 2 0.5681587474301775 0.8626994680851063
# Early Stopping at 2
# 0.35852400292741493 0.8692277070063694
# embedding.weight     | nonzeros = 3200064 / 5000200 ( 64.00%) | total_pruned = 1800136 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   19200 /   30000 ( 64.00%) | total_pruned =   10800 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.1.weight       | nonzeros =   25600 /   40000 ( 64.00%) | total_pruned =   14400 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      39 /     100 ( 39.00%) | total_pruned =      61 | shape = (100,)
# convs.2.weight       | nonzeros =   32000 /   50000 ( 64.00%) | total_pruned =   18000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      42 /     100 ( 42.00%) | total_pruned =      58 | shape = (100,)
# fc.weight            | nonzeros =     192 /     300 ( 64.00%) | total_pruned =     108 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3277179, pruned : 1843622, total: 5120801, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.391942108010358 0.8720079787234043
# 1 0.46523835329695584 0.8643617021276596
# 2 0.665766840008028 0.8491522606382979
# Early Stopping at 2
# 0.391942108010358 0.8679339171974523
# embedding.weight     | nonzeros = 2560051 / 5000200 ( 51.20%) | total_pruned = 2440149 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   15360 /   30000 ( 51.20%) | total_pruned =   14640 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      23 /     100 ( 23.00%) | total_pruned =      77 | shape = (100,)
# convs.1.weight       | nonzeros =   20480 /   40000 ( 51.20%) | total_pruned =   19520 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# convs.2.weight       | nonzeros =   25600 /   50000 ( 51.20%) | total_pruned =   24400 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      29 /     100 ( 29.00%) | total_pruned =      71 | shape = (100,)
# fc.weight            | nonzeros =     153 /     300 ( 51.00%) | total_pruned =     147 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2621723, pruned : 2499078, total: 5120801, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.4749452567243196 0.863031914893617
# 1 0.5643358959400273 0.8620345744680851
# 2 0.6950758562443105 0.8569647606382979
# Early Stopping at 2
# 0.4749452567243196 0.8606687898089171
# embedding.weight     | nonzeros = 2048041 / 5000200 ( 40.96%) | total_pruned = 2952159 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   12288 /   30000 ( 40.96%) | total_pruned =   17712 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      16 /     100 ( 16.00%) | total_pruned =      84 | shape = (100,)
# convs.1.weight       | nonzeros =   16384 /   40000 ( 40.96%) | total_pruned =   23616 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      16 /     100 ( 16.00%) | total_pruned =      84 | shape = (100,)
# convs.2.weight       | nonzeros =   20480 /   50000 ( 40.96%) | total_pruned =   29520 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      20 /     100 ( 20.00%) | total_pruned =      80 | shape = (100,)
# fc.weight            | nonzeros =     122 /     300 ( 40.67%) | total_pruned =     178 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2097368, pruned : 3023433, total: 5120801, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.5004896314299487 0.8626163563829787
# 1 0.6016926323559056 0.8594581117021277
# 2 0.7426990697834086 0.8541389627659575
# Early Stopping at 2
# 0.5004896314299487 0.8623606687898089
# embedding.weight     | nonzeros = 1638433 / 5000200 ( 32.77%) | total_pruned = 3361767 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    9830 /   30000 ( 32.77%) | total_pruned =   20170 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       7 /     100 (  7.00%) | total_pruned =      93 | shape = (100,)
# convs.1.weight       | nonzeros =   13107 /   40000 ( 32.77%) | total_pruned =   26893 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      12 /     100 ( 12.00%) | total_pruned =      88 | shape = (100,)
# convs.2.weight       | nonzeros =   16384 /   50000 ( 32.77%) | total_pruned =   33616 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      14 /     100 ( 14.00%) | total_pruned =      86 | shape = (100,)
# fc.weight            | nonzeros =      97 /     300 ( 32.33%) | total_pruned =     203 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1677885, pruned : 3442916, total: 5120801, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.5124083332558895 0.8560505319148937
# 1 0.6602517371957607 0.8540558510638298
# 2 0.7701606823408857 0.8473238031914894
# Early Stopping at 2
# 0.5124083332558895 0.8573845541401274
# embedding.weight     | nonzeros = 1310746 / 5000200 ( 26.21%) | total_pruned = 3689454 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    7864 /   30000 ( 26.21%) | total_pruned =   22136 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.1.weight       | nonzeros =   10485 /   40000 ( 26.21%) | total_pruned =   29515 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       9 /     100 (  9.00%) | total_pruned =      91 | shape = (100,)
# convs.2.weight       | nonzeros =   13107 /   50000 ( 26.21%) | total_pruned =   36893 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       9 /     100 (  9.00%) | total_pruned =      91 | shape = (100,)
# fc.weight            | nonzeros =      77 /     300 ( 25.67%) | total_pruned =     223 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1342302, pruned : 3778499, total: 5120801, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.5607617875917795 0.8478224734042553
# 1 0.6483960889596888 0.8525598404255319
# 2 0.7746037793286303 0.8483211436170213
# Early Stopping at 2
# 0.5607617875917795 0.8528065286624203
# embedding.weight     | nonzeros = 1048597 / 5000200 ( 20.97%) | total_pruned = 3951603 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    6291 /   30000 ( 20.97%) | total_pruned =   23709 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    8388 /   40000 ( 20.97%) | total_pruned =   31612 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.2.weight       | nonzeros =   10485 /   50000 ( 20.97%) | total_pruned =   39515 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# fc.weight            | nonzeros =      61 /     300 ( 20.33%) | total_pruned =     239 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1073834, pruned : 4046967, total: 5120801, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.548591028502647 0.8513962765957447
# 1 0.6735042479444058 0.8485704787234043
# 2 0.7274400180483118 0.847406914893617
# Early Stopping at 2
# 0.548591028502647 0.8551950636942676
# embedding.weight     | nonzeros =  838877 / 5000200 ( 16.78%) | total_pruned = 4161323 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    5033 /   30000 ( 16.78%) | total_pruned =   24967 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    6710 /   40000 ( 16.77%) | total_pruned =   33290 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.2.weight       | nonzeros =    8388 /   50000 ( 16.78%) | total_pruned =   41612 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# fc.weight            | nonzeros =      49 /     300 ( 16.33%) | total_pruned =     251 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 859065, pruned : 4261736, total: 5120801, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.5693790185800258 0.8469913563829787
# 1 0.6355802523011856 0.8415890957446809
# 2 0.7117057705813266 0.8408410904255319
# Early Stopping at 2
# 0.5693790185800258 0.8487261146496815
# embedding.weight     | nonzeros =  671101 / 5000200 ( 13.42%) | total_pruned = 4329099 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    4026 /   30000 ( 13.42%) | total_pruned =   25974 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    5368 /   40000 ( 13.42%) | total_pruned =   34632 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.2.weight       | nonzeros =    6710 /   50000 ( 13.42%) | total_pruned =   43290 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# fc.weight            | nonzeros =      39 /     300 ( 13.00%) | total_pruned =     261 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 687249, pruned : 4433552, total: 5120801, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.5436741313401688 0.8445811170212766
# 1 0.6117681958415406 0.8423371010638298
# 2 0.6661746925575301 0.8410904255319149
# Early Stopping at 2
# 0.5436741313401688 0.8486265923566879
# embedding.weight     | nonzeros =  536881 / 5000200 ( 10.74%) | total_pruned = 4463319 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    3221 /   30000 ( 10.74%) | total_pruned =   26779 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    4294 /   40000 ( 10.73%) | total_pruned =   35706 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    5368 /   50000 ( 10.74%) | total_pruned =   44632 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      31 /     300 ( 10.33%) | total_pruned =     269 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 549798, pruned : 4571003, total: 5120801, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.5010251646980326 0.8439162234042553
# 1 0.5687447173639815 0.8417553191489362
# 2 0.6333495900827519 0.8441655585106383
# Early Stopping at 2
# 0.5010251646980326 0.8474323248407644
# embedding.weight     | nonzeros =  429505 / 5000200 (  8.59%) | total_pruned = 4570695 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2577 /   30000 (  8.59%) | total_pruned =   27423 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    3435 /   40000 (  8.59%) | total_pruned =   36565 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    4294 /   50000 (  8.59%) | total_pruned =   45706 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      25 /     300 (  8.33%) | total_pruned =     275 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 439839, pruned : 4680962, total: 5120801, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.48452109510594227 0.8396775265957447
# 1 0.5223822611126494 0.8428357712765957
# 2 0.5623685133425479 0.8401761968085106
# Early Stopping at 2
# 0.48452109510594227 0.8400676751592356
# embedding.weight     | nonzeros =  343604 / 5000200 (  6.87%) | total_pruned = 4656596 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2061 /   30000 (  6.87%) | total_pruned =   27939 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    2748 /   40000 (  6.87%) | total_pruned =   37252 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =    3435 /   50000 (  6.87%) | total_pruned =   46565 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      20 /     300 (  6.67%) | total_pruned =     280 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 351870, pruned : 4768931, total: 5120801, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.4767556941889702 0.8394281914893617
# 1 0.49475320547502094 0.8376828457446809
# 2 0.5195528150714458 0.8321974734042553
# Early Stopping at 2
# 0.4767556941889702 0.8398686305732485
# embedding.weight     | nonzeros =  274883 / 5000200 (  5.50%) | total_pruned = 4725317 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1649 /   30000 (  5.50%) | total_pruned =   28351 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    2198 /   40000 (  5.50%) | total_pruned =   37802 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =    2748 /   50000 (  5.50%) | total_pruned =   47252 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      16 /     300 (  5.33%) | total_pruned =     284 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 281496, pruned : 4839305, total: 5120801, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.4510242946128896 0.827376994680851
# 1 0.4657111521413986 0.8236369680851063
# 2 0.48448096374247934 0.8226396276595744
# Early Stopping at 2
# 0.4510242946128896 0.8279259554140127
# embedding.weight     | nonzeros =  219906 / 5000200 (  4.40%) | total_pruned = 4780294 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1319 /   30000 (  4.40%) | total_pruned =   28681 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    1758 /   40000 (  4.39%) | total_pruned =   38242 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =    2198 /   50000 (  4.40%) | total_pruned =   47802 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      13 /     300 (  4.33%) | total_pruned =     287 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 225196, pruned : 4895605, total: 5120801, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.4332652417744728 0.8274601063829787
# 1 0.4557085209228891 0.8248005319148937
# 2 0.46336893673906937 0.8208942819148937
# Early Stopping at 2
# 0.4332652417744728 0.8265326433121019
# embedding.weight     | nonzeros =  175925 / 5000200 (  3.52%) | total_pruned = 4824275 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1055 /   30000 (  3.52%) | total_pruned =   28945 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    1406 /   40000 (  3.52%) | total_pruned =   38594 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =    1758 /   50000 (  3.52%) | total_pruned =   48242 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      10 /     300 (  3.33%) | total_pruned =     290 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 180156, pruned : 4940645, total: 5120801, Compression rate :      28.42x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.42080433999604366 0.8335272606382979
# 1 0.4388047659650762 0.8295378989361702
# 2 0.44753413195622727 0.8295378989361702
# Early Stopping at 2
# 0.42080433999604366 0.8325039808917197
# embedding.weight     | nonzeros =  140740 / 5000200 (  2.81%) | total_pruned = 4859460 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     844 /   30000 (  2.81%) | total_pruned =   29156 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =    1125 /   40000 (  2.81%) | total_pruned =   38875 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =    1406 /   50000 (  2.81%) | total_pruned =   48594 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       8 /     300 (  2.67%) | total_pruned =     292 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 144125, pruned : 4976676, total: 5120801, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.4878029558569827 0.77734375
# 1 0.4992900818903395 0.7706117021276596
# 2 0.4934343784413439 0.7716921542553191
# Early Stopping at 2
# 0.4878029558569827 0.7734872611464968
# embedding.weight     | nonzeros =  112592 / 5000200 (  2.25%) | total_pruned = 4887608 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     675 /   30000 (  2.25%) | total_pruned =   29325 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =     900 /   40000 (  2.25%) | total_pruned =   39100 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =    1125 /   50000 (  2.25%) | total_pruned =   48875 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       6 /     300 (  2.00%) | total_pruned =     294 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 115300, pruned : 5005501, total: 5120801, Compression rate :      44.41x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.4380611387339044 0.8163231382978723
# 1 0.4384554296414903 0.8194813829787234
# 2 0.4393732081702415 0.8184009308510638
# Early Stopping at 2
# 0.4380611387339044 0.8203622611464968
# embedding.weight     | nonzeros =   90073 / 5000200 (  1.80%) | total_pruned = 4910127 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     540 /   30000 (  1.80%) | total_pruned =   29460 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =     720 /   40000 (  1.80%) | total_pruned =   39280 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =     900 /   50000 (  1.80%) | total_pruned =   49100 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       5 /     300 (  1.67%) | total_pruned =     295 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 92240, pruned : 5028561, total: 5120801, Compression rate :      55.52x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.43502075066591833 0.8165724734042553
# 1 0.4463223274400894 0.8070977393617021
# 2 0.4422741903269545 0.8113364361702128
# Early Stopping at 2
# 0.43502075066591833 0.8140923566878981
# embedding.weight     | nonzeros =   72058 / 5000200 (  1.44%) | total_pruned = 4928142 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     432 /   30000 (  1.44%) | total_pruned =   29568 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =     576 /   40000 (  1.44%) | total_pruned =   39424 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =     720 /   50000 (  1.44%) | total_pruned =   49280 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       4 /     300 (  1.33%) | total_pruned =     296 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 73792, pruned : 5047009, total: 5120801, Compression rate :      69.40x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.45707654746923043 0.8123337765957447
# 1 0.4551877124195403 0.8126662234042553
# 2 0.4550549498897918 0.8085106382978723
# 3 0.45337402899848656 0.8102559840425532
# 4 0.4594418734629103 0.8136635638297872
# 5 0.4601249094022081 0.8103390957446809
# Early Stopping at 5
# 0.45337402899848656 0.8083200636942676
# embedding.weight     | nonzeros =   57646 / 5000200 (  1.15%) | total_pruned = 4942554 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     345 /   30000 (  1.15%) | total_pruned =   29655 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.1.weight       | nonzeros =     461 /   40000 (  1.15%) | total_pruned =   39539 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       0 /     100 (  0.00%) | total_pruned =     100 | shape = (100,)
# convs.2.weight       | nonzeros =     576 /   50000 (  1.15%) | total_pruned =   49424 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       3 /     300 (  1.00%) | total_pruned =     297 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 59033, pruned : 5061768, total: 5120801, Compression rate :      86.74x  ( 98.85% pruned)

# %%
# random
print(performance)
print(valid_losses)

reinit_performance = performance
reinit_valid_losses = valid_losses
# Out:
# [86.45501592356688, 85.62898089171973, 86.92277070063695, 86.79339171974523, 86.06687898089172, 86.23606687898089, 85.73845541401273, 85.28065286624204, 85.51950636942675, 84.87261146496814, 84.86265923566879, 84.74323248407643, 84.00676751592357, 83.98686305732484, 82.79259554140127, 82.65326433121018, 83.25039808917197, 77.34872611464968, 82.03622611464968, 81.40923566878982, 80.83200636942675]
# [0.4349267495439408, 0.45010001866265814, 0.5681587474301775, 0.665766840008028, 0.6950758562443105, 0.7426990697834086, 0.7701606823408857, 0.7746037793286303, 0.7274400180483118, 0.7117057705813266, 0.6661746925575301, 0.6333495900827519, 0.5623685133425479, 0.5195528150714458, 0.48448096374247934, 0.46336893673906937, 0.44753413195622727, 0.4934343784413439, 0.4393732081702415, 0.4422741903269545, 0.4601249094022081]

# %% [markdown]
# ## 2) lt

# %%
reinit = False # random이면 True, lt면 False
mode = 'lt'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)
initial_state_dict = copy.deepcopy(model.state_dict())

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.BCEWithLogitsLoss()

criterion = criterion.to(device)

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  best_valid_loss = float('inf')
  # early stopping
  count = 0
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        best_state_dict = copy.deepcopy(model.state_dict())

    else:
        count +=1
        
    if count == 2:
        print(f'Early Stopping at {epoch}')
        break

  model.load_state_dict(best_state_dict)
  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(best_valid_loss, test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.39476124014943204 0.8192320478723404
# 1 0.3072912580868665 0.8663563829787234
# 2 0.3191868526504395 0.8785738031914894
# 3 0.45132775422423443 0.8617021276595744
# Early Stopping at 3
# 0.3072912580868665 0.870421974522293
# embedding.weight     | nonzeros = 5000100 / 5000200 (100.00%) | total_pruned =     100 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   30000 /   30000 (100.00%) | total_pruned =       0 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.1.weight       | nonzeros =   40000 /   40000 (100.00%) | total_pruned =       0 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.2.weight       | nonzeros =   50000 /   50000 (100.00%) | total_pruned =       0 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# fc.weight            | nonzeros =     300 /     300 (100.00%) | total_pruned =       0 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 5120701, pruned : 100, total: 5120801, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.3213837981382583 0.8607047872340425
# 1 0.3168559165552576 0.867935505319149
# 2 0.3213781907441134 0.8770777925531915
# 3 0.4467437599012826 0.8744182180851063
# Early Stopping at 3
# 0.3168559165552576 0.8656449044585988
# embedding.weight     | nonzeros = 4000080 / 5000200 ( 80.00%) | total_pruned = 1000120 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   24000 /   30000 ( 80.00%) | total_pruned =    6000 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      56 /     100 ( 56.00%) | total_pruned =      44 | shape = (100,)
# convs.1.weight       | nonzeros =   32000 /   40000 ( 80.00%) | total_pruned =    8000 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      71 /     100 ( 71.00%) | total_pruned =      29 | shape = (100,)
# convs.2.weight       | nonzeros =   40000 /   50000 ( 80.00%) | total_pruned =   10000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      63 /     100 ( 63.00%) | total_pruned =      37 | shape = (100,)
# fc.weight            | nonzeros =     240 /     300 ( 80.00%) | total_pruned =      60 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 4096511, pruned : 1024290, total: 5120801, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.32408158714942475 0.8595412234042553
# 1 0.3020320353593598 0.8774933510638298
# 2 0.36015474372246165 0.8726728723404256
# 3 0.44423610296972255 0.8676030585106383
# Early Stopping at 3
# 0.3020320353593598 0.8754976114649682
# embedding.weight     | nonzeros = 3200064 / 5000200 ( 64.00%) | total_pruned = 1800136 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   19200 /   30000 ( 64.00%) | total_pruned =   10800 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      34 /     100 ( 34.00%) | total_pruned =      66 | shape = (100,)
# convs.1.weight       | nonzeros =   25600 /   40000 ( 64.00%) | total_pruned =   14400 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      45 /     100 ( 45.00%) | total_pruned =      55 | shape = (100,)
# convs.2.weight       | nonzeros =   32000 /   50000 ( 64.00%) | total_pruned =   18000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      38 /     100 ( 38.00%) | total_pruned =      62 | shape = (100,)
# fc.weight            | nonzeros =     192 /     300 ( 64.00%) | total_pruned =     108 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3277174, pruned : 1843627, total: 5120801, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.3132026069500345 0.8681848404255319
# 1 0.326639947937207 0.867686170212766
# 2 0.38790360077264463 0.8611203457446809
# Early Stopping at 2
# 0.3132026069500345 0.8695262738853503
# embedding.weight     | nonzeros = 2560051 / 5000200 ( 51.20%) | total_pruned = 2440149 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   15360 /   30000 ( 51.20%) | total_pruned =   14640 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# convs.1.weight       | nonzeros =   20480 /   40000 ( 51.20%) | total_pruned =   19520 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      32 /     100 ( 32.00%) | total_pruned =      68 | shape = (100,)
# convs.2.weight       | nonzeros =   25600 /   50000 ( 51.20%) | total_pruned =   24400 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      25 /     100 ( 25.00%) | total_pruned =      75 | shape = (100,)
# fc.weight            | nonzeros =     153 /     300 ( 51.00%) | total_pruned =     147 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2621719, pruned : 2499082, total: 5120801, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.34252286409126953 0.8502327127659575
# 1 0.30917251163578413 0.8712599734042553
# 2 0.3263672640586787 0.8698470744680851
# 3 0.38274828308915837 0.86328125
# Early Stopping at 3
# 0.30917251163578413 0.8692277070063694
# embedding.weight     | nonzeros = 2048041 / 5000200 ( 40.96%) | total_pruned = 2952159 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   12288 /   30000 ( 40.96%) | total_pruned =   17712 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      11 /     100 ( 11.00%) | total_pruned =      89 | shape = (100,)
# convs.1.weight       | nonzeros =   16384 /   40000 ( 40.96%) | total_pruned =   23616 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      18 /     100 ( 18.00%) | total_pruned =      82 | shape = (100,)
# convs.2.weight       | nonzeros =   20480 /   50000 ( 40.96%) | total_pruned =   29520 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      16 /     100 ( 16.00%) | total_pruned =      84 | shape = (100,)
# fc.weight            | nonzeros =     122 /     300 ( 40.67%) | total_pruned =     178 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2097361, pruned : 3023440, total: 5120801, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.3254473058784262 0.8616190159574468
# 1 0.3312495868811582 0.8617852393617021
# 2 0.3724279914923171 0.8600398936170213
# Early Stopping at 2
# 0.3254473058784262 0.8621616242038217
# embedding.weight     | nonzeros = 1638433 / 5000200 ( 32.77%) | total_pruned = 3361767 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    9830 /   30000 ( 32.77%) | total_pruned =   20170 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       7 /     100 (  7.00%) | total_pruned =      93 | shape = (100,)
# convs.1.weight       | nonzeros =   13107 /   40000 ( 32.77%) | total_pruned =   26893 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# convs.2.weight       | nonzeros =   16384 /   50000 ( 32.77%) | total_pruned =   33616 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      11 /     100 ( 11.00%) | total_pruned =      89 | shape = (100,)
# fc.weight            | nonzeros =      97 /     300 ( 32.33%) | total_pruned =     203 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1677883, pruned : 3442918, total: 5120801, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.3342846024860727 0.8607878989361702
# 1 0.32134356876795594 0.8622007978723404
# 2 0.33670860956958 0.8605385638297872
# 3 0.3551655703006273 0.8617021276595744
# Early Stopping at 3
# 0.32134356876795594 0.8630573248407644
# embedding.weight     | nonzeros = 1310746 / 5000200 ( 26.21%) | total_pruned = 3689454 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    7864 /   30000 ( 26.21%) | total_pruned =   22136 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.1.weight       | nonzeros =   10485 /   40000 ( 26.21%) | total_pruned =   29515 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.2.weight       | nonzeros =   13107 /   50000 ( 26.21%) | total_pruned =   36893 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       9 /     100 (  9.00%) | total_pruned =      91 | shape = (100,)
# fc.weight            | nonzeros =      77 /     300 ( 25.67%) | total_pruned =     223 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1342300, pruned : 3778501, total: 5120801, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.3402963256106732 0.8535571808510638
# 1 0.3563147897019665 0.8505651595744681
# 2 0.3501608201322403 0.8561336436170213
# Early Stopping at 2
# 0.3402963256106732 0.8577826433121019
# embedding.weight     | nonzeros = 1048597 / 5000200 ( 20.97%) | total_pruned = 3951603 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    6291 /   30000 ( 20.97%) | total_pruned =   23709 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.1.weight       | nonzeros =    8388 /   40000 ( 20.97%) | total_pruned =   31612 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.2.weight       | nonzeros =   10485 /   50000 ( 20.97%) | total_pruned =   39515 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# fc.weight            | nonzeros =      61 /     300 ( 20.33%) | total_pruned =     239 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1073837, pruned : 4046964, total: 5120801, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.35722528738861387 0.8490691489361702
# 1 0.3375357374390389 0.8526429521276596
# 2 0.33601607057325383 0.8567985372340425
# 3 0.3404657407960993 0.8579621010638298
# 4 0.3604895598156021 0.8556349734042553
# Early Stopping at 4
# 0.33601607057325383 0.8575835987261147
# embedding.weight     | nonzeros =  838877 / 5000200 ( 16.78%) | total_pruned = 4161323 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    5033 /   30000 ( 16.78%) | total_pruned =   24967 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    6710 /   40000 ( 16.77%) | total_pruned =   33290 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.2.weight       | nonzeros =    8388 /   50000 ( 16.78%) | total_pruned =   41612 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# fc.weight            | nonzeros =      49 /     300 ( 16.33%) | total_pruned =     251 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 859067, pruned : 4261734, total: 5120801, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.35333796210111457 0.8465757978723404
# 1 0.35308043000862954 0.8531416223404256
# 2 0.363381042482054 0.8528922872340425
# 3 0.38633824781851567 0.8496509308510638
# Early Stopping at 3
# 0.35308043000862954 0.8517117834394905
# embedding.weight     | nonzeros =  671101 / 5000200 ( 13.42%) | total_pruned = 4329099 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    4026 /   30000 ( 13.42%) | total_pruned =   25974 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    5368 /   40000 ( 13.42%) | total_pruned =   34632 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.2.weight       | nonzeros =    6710 /   50000 ( 13.42%) | total_pruned =   43290 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# fc.weight            | nonzeros =      39 /     300 ( 13.00%) | total_pruned =     261 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 687252, pruned : 4433549, total: 5120801, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.3637087583700393 0.8434175531914894
# 1 0.3543098198368828 0.8482380319148937
# 2 0.3631811599702911 0.8489860372340425
# 3 0.3661482798609328 0.8503989361702128
# Early Stopping at 3
# 0.3543098198368828 0.8493232484076433
# embedding.weight     | nonzeros =  536881 / 5000200 ( 10.74%) | total_pruned = 4463319 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    3221 /   30000 ( 10.74%) | total_pruned =   26779 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    4294 /   40000 ( 10.73%) | total_pruned =   35706 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.2.weight       | nonzeros =    5368 /   50000 ( 10.74%) | total_pruned =   44632 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# fc.weight            | nonzeros =      31 /     300 ( 10.33%) | total_pruned =     269 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 549801, pruned : 4571000, total: 5120801, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.3755601355211532 0.839594414893617
# 1 0.3629782683354743 0.8420877659574468
# 2 0.3647938577180847 0.8422539893617021
# 3 0.36344673746126765 0.8489029255319149
# Early Stopping at 3
# 0.3629782683354743 0.8430533439490446
# embedding.weight     | nonzeros =  429505 / 5000200 (  8.59%) | total_pruned = 4570695 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2577 /   30000 (  8.59%) | total_pruned =   27423 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    3435 /   40000 (  8.59%) | total_pruned =   36565 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    4294 /   50000 (  8.59%) | total_pruned =   45706 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      25 /     300 (  8.33%) | total_pruned =     275 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 439840, pruned : 4680961, total: 5120801, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.39520628663136603 0.832779255319149
# 1 0.3792320343249656 0.8324468085106383
# 2 0.36463439781615076 0.8407579787234043
# 3 0.3666624925396544 0.8405086436170213
# 4 0.36716622019067724 0.840342420212766
# Early Stopping at 4
# 0.36463439781615076 0.8393710191082803
# embedding.weight     | nonzeros =  343604 / 5000200 (  6.87%) | total_pruned = 4656596 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2061 /   30000 (  6.87%) | total_pruned =   27939 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    2748 /   40000 (  6.87%) | total_pruned =   37252 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    3435 /   50000 (  6.87%) | total_pruned =   46565 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      20 /     300 (  6.67%) | total_pruned =     280 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 351872, pruned : 4768929, total: 5120801, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.39169323182803517 0.8336103723404256
# 1 0.37398987255514937 0.8352726063829787
# 2 0.369298522420069 0.8355219414893617
# 3 0.3630644922402311 0.8431682180851063
# 4 0.3702754148064142 0.8410073138297872
# 5 0.3754595856955077 0.8375166223404256
# Early Stopping at 5
# 0.3630644922402311 0.841062898089172
# embedding.weight     | nonzeros =  274883 / 5000200 (  5.50%) | total_pruned = 4725317 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1649 /   30000 (  5.50%) | total_pruned =   28351 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    2198 /   40000 (  5.50%) | total_pruned =   37802 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    2748 /   50000 (  5.50%) | total_pruned =   47252 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      16 /     300 (  5.33%) | total_pruned =     284 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 281498, pruned : 4839303, total: 5120801, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.40133663734540026 0.8228058510638298
# 1 0.3871664060081573 0.8259640957446809
# 2 0.38195746233488653 0.828623670212766
# 3 0.3822612798118845 0.8303690159574468
# 4 0.3825408729942555 0.832280585106383
# Early Stopping at 4
# 0.38195746233488653 0.8351910828025477
# embedding.weight     | nonzeros =  219906 / 5000200 (  4.40%) | total_pruned = 4780294 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1319 /   30000 (  4.40%) | total_pruned =   28681 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    1758 /   40000 (  4.39%) | total_pruned =   38242 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    2198 /   50000 (  4.40%) | total_pruned =   47802 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      13 /     300 (  4.33%) | total_pruned =     287 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 225198, pruned : 4895603, total: 5120801, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.4584709773672388 0.796625664893617
# 1 0.42583238056048434 0.8069315159574468
# 2 0.4185421921788378 0.8110871010638298
# 3 0.413675392165463 0.8097573138297872
# 4 0.40663689351145255 0.815658244680851
# 5 0.4041885766894259 0.8157413563829787
# 6 0.40721918642520905 0.8148271276595744
# 7 0.407268854531836 0.8163231382978723
# Early Stopping at 7
# 0.4041885766894259 0.8188694267515924
# embedding.weight     | nonzeros =  175925 / 5000200 (  3.52%) | total_pruned = 4824275 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1055 /   30000 (  3.52%) | total_pruned =   28945 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    1406 /   40000 (  3.52%) | total_pruned =   38594 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1758 /   50000 (  3.52%) | total_pruned =   48242 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =      10 /     300 (  3.33%) | total_pruned =     290 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 180158, pruned : 4940643, total: 5120801, Compression rate :      28.42x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.4418132337642477 0.8075132978723404
# 1 0.4214451456482106 0.8112533244680851
# 2 0.4128303893227526 0.8145777925531915
# 3 0.41242043198423184 0.8146609042553191
# 4 0.4113851581957746 0.8174035904255319
# 5 0.41153435099949226 0.8165724734042553
# 6 0.41115837132043026 0.8149933510638298
# 7 0.4147799167227238 0.8181515957446809
# Early Stopping at 7
# 0.41115837132043026 0.815187101910828
# embedding.weight     | nonzeros =  140740 / 5000200 (  2.81%) | total_pruned = 4859460 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     844 /   30000 (  2.81%) | total_pruned =   29156 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =    1125 /   40000 (  2.81%) | total_pruned =   38875 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1406 /   50000 (  2.81%) | total_pruned =   48594 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       8 /     300 (  2.67%) | total_pruned =     292 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 144127, pruned : 4976674, total: 5120801, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.45770522349692405 0.8008643617021277
# 1 0.4441663585603237 0.797623005319149
# 2 0.4357366754495083 0.8056017287234043
# 3 0.43690848231632656 0.8065990691489362
# 4 0.4328540581813518 0.8059341755319149
# 5 0.43417300640585577 0.811751994680851
# Early Stopping at 5
# 0.4328540581813518 0.8056329617834395
# embedding.weight     | nonzeros =  112592 / 5000200 (  2.25%) | total_pruned = 4887608 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     675 /   30000 (  2.25%) | total_pruned =   29325 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     900 /   40000 (  2.25%) | total_pruned =   39100 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1125 /   50000 (  2.25%) | total_pruned =   48875 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       6 /     300 (  2.00%) | total_pruned =     294 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 115302, pruned : 5005499, total: 5120801, Compression rate :      44.41x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.5028739871179804 0.7816655585106383
# 1 0.4753405676877245 0.7829122340425532
# 2 0.4601567950337491 0.7964594414893617
# 3 0.457407840785194 0.797124335106383
# 4 0.4592225049087342 0.7977892287234043
# 5 0.4531254638382729 0.7978723404255319
# 6 0.4564403978751061 0.7952127659574468
# Early Stopping at 6
# 0.4531254638382729 0.7985668789808917
# embedding.weight     | nonzeros =   90073 / 5000200 (  1.80%) | total_pruned = 4910127 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     540 /   30000 (  1.80%) | total_pruned =   29460 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     720 /   40000 (  1.80%) | total_pruned =   39280 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     900 /   50000 (  1.80%) | total_pruned =   49100 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       5 /     300 (  1.67%) | total_pruned =     295 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 92242, pruned : 5028559, total: 5120801, Compression rate :      55.51x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.5224242795338022 0.757064494680851
# 1 0.5053726122417348 0.7670378989361702
# 2 0.5018606729646946 0.7677027925531915
# 3 0.5002951487264735 0.7708610372340425
# 4 0.4999566266828395 0.7674534574468085
# 5 0.49938332051672835 0.773188164893617
# 6 0.4994521475535758 0.7743517287234043
# 7 0.5012094351522466 0.7746841755319149
# Early Stopping at 7
# 0.49938332051672835 0.7746815286624203
# embedding.weight     | nonzeros =   72058 / 5000200 (  1.44%) | total_pruned = 4928142 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     432 /   30000 (  1.44%) | total_pruned =   29568 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     576 /   40000 (  1.44%) | total_pruned =   39424 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     720 /   50000 (  1.44%) | total_pruned =   49280 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       4 /     300 (  1.33%) | total_pruned =     296 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 73794, pruned : 5047007, total: 5120801, Compression rate :      69.39x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.5507135432451329 0.7638796542553191
# 1 0.5251042993461832 0.765375664893617
# 2 0.5176704479975903 0.7608045212765957
# 3 0.5206068701883579 0.7657081117021277
# 4 0.5196707792421604 0.7644614361702128
# Early Stopping at 4
# 0.5176704479975903 0.7609474522292994
# embedding.weight     | nonzeros =   57646 / 5000200 (  1.15%) | total_pruned = 4942554 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     345 /   30000 (  1.15%) | total_pruned =   29655 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     461 /   40000 (  1.15%) | total_pruned =   39539 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     576 /   50000 (  1.15%) | total_pruned =   49424 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       3 /     300 (  1.00%) | total_pruned =     297 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 59035, pruned : 5061766, total: 5120801, Compression rate :      86.74x  ( 98.85% pruned)

# %%
# lt
print(performance)
print(valid_losses)
lt_performance = performance
lt_valid_losses = valid_losses
# Out:
# [87.0421974522293, 86.56449044585987, 87.54976114649682, 86.95262738853503, 86.92277070063695, 86.21616242038218, 86.30573248407643, 85.77826433121018, 85.75835987261146, 85.17117834394905, 84.93232484076432, 84.30533439490446, 83.93710191082803, 84.1062898089172, 83.51910828025477, 81.88694267515923, 81.5187101910828, 80.56329617834395, 79.85668789808918, 77.46815286624204, 76.09474522292994]
# [0.45132775422423443, 0.4467437599012826, 0.44423610296972255, 0.38790360077264463, 0.38274828308915837, 0.3724279914923171, 0.3551655703006273, 0.3501608201322403, 0.3604895598156021, 0.38633824781851567, 0.3661482798609328, 0.36344673746126765, 0.36716622019067724, 0.3754595856955077, 0.3825408729942555, 0.407268854531836, 0.4147799167227238, 0.43417300640585577, 0.4564403978751061, 0.5012094351522466, 0.5196707792421604]

# %% [markdown]
# ## 3) lt+lr (first epoch)

# %%
reinit = False # random이면 True, lt면 False
mode = 'lr_f'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.BCEWithLogitsLoss()

criterion = criterion.to(device)

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  best_valid_loss = float('inf')
  # early stopping
  count = 0

  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        best_state_dict = copy.deepcopy(model.state_dict())

    else:
        count +=1
        
    if count == 2:
        print(f'Early Stopping at {epoch}')
        break
    
    # late rewinding after the first epoch
    if pruning_iter == 0 and epoch == 0:
        initial_state_dict = copy.deepcopy(model.state_dict())

  model.load_state_dict(best_state_dict)
  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(best_valid_loss, test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.3924252216486221 0.8179022606382979
# 1 0.29334738533547583 0.879654255319149
# 2 0.4285250069930198 0.8422539893617021
# 3 0.41461936713374675 0.8729222074468085
# Early Stopping at 3
# 0.29334738533547583 0.8790804140127388
# embedding.weight     | nonzeros = 5000100 / 5000200 (100.00%) | total_pruned =     100 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   30000 /   30000 (100.00%) | total_pruned =       0 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.1.weight       | nonzeros =   40000 /   40000 (100.00%) | total_pruned =       0 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.2.weight       | nonzeros =   50000 /   50000 (100.00%) | total_pruned =       0 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# fc.weight            | nonzeros =     300 /     300 (100.00%) | total_pruned =       0 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 5120701, pruned : 100, total: 5120801, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.29305631112545094 0.8780751329787234
# 1 0.3136417990986337 0.8808178191489362
# 2 0.40466037313354775 0.871592420212766
# Early Stopping at 2
# 0.29305631112545094 0.8746019108280255
# embedding.weight     | nonzeros = 4000081 / 5000200 ( 80.00%) | total_pruned = 1000119 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   24000 /   30000 ( 80.00%) | total_pruned =    6000 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.1.weight       | nonzeros =   32000 /   40000 ( 80.00%) | total_pruned =    8000 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.2.weight       | nonzeros =   40000 /   50000 ( 80.00%) | total_pruned =   10000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# fc.weight            | nonzeros =     240 /     300 ( 80.00%) | total_pruned =      60 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 4096562, pruned : 1024239, total: 5120801, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.3019356276602187 0.8730053191489362
# 1 0.3233113075665971 0.8715093085106383
# 2 0.38330680508404336 0.8735039893617021
# Early Stopping at 2
# 0.3019356276602187 0.8726114649681529
# embedding.weight     | nonzeros = 3200065 / 5000200 ( 64.00%) | total_pruned = 1800135 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   19200 /   30000 ( 64.00%) | total_pruned =   10800 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.1.weight       | nonzeros =   25600 /   40000 ( 64.00%) | total_pruned =   14400 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.2.weight       | nonzeros =   32000 /   50000 ( 64.00%) | total_pruned =   18000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# fc.weight            | nonzeros =     192 /     300 ( 64.00%) | total_pruned =     108 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3277250, pruned : 1843551, total: 5120801, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.29910954024563446 0.8749168882978723
# 1 0.3079453443593167 0.874750664893617
# 2 0.35390813276171684 0.870595079787234
# Early Stopping at 2
# 0.29910954024563446 0.8737062101910829
# embedding.weight     | nonzeros = 2560052 / 5000200 ( 51.20%) | total_pruned = 2440148 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   15360 /   30000 ( 51.20%) | total_pruned =   14640 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.1.weight       | nonzeros =   20480 /   40000 ( 51.20%) | total_pruned =   19520 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.2.weight       | nonzeros =   25600 /   50000 ( 51.20%) | total_pruned =   24400 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# fc.weight            | nonzeros =     153 /     300 ( 51.00%) | total_pruned =     147 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2621799, pruned : 2499002, total: 5120801, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.31253791449868934 0.8681017287234043
# 1 0.3048454773156567 0.8748337765957447
# 2 0.35439109489163184 0.867935505319149
# 3 0.39517574503700786 0.8695146276595744
# Early Stopping at 3
# 0.3048454773156567 0.8754976114649682
# embedding.weight     | nonzeros = 2048041 / 5000200 ( 40.96%) | total_pruned = 2952159 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   12288 /   30000 ( 40.96%) | total_pruned =   17712 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.1.weight       | nonzeros =   16384 /   40000 ( 40.96%) | total_pruned =   23616 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.2.weight       | nonzeros =   20480 /   50000 ( 40.96%) | total_pruned =   29520 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# fc.weight            | nonzeros =     122 /     300 ( 40.67%) | total_pruned =     178 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2097439, pruned : 3023362, total: 5120801, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.33131574712535167 0.864029255319149
# 1 0.3697952017822164 0.8542220744680851
# 2 0.3877002265938419 0.86328125
# Early Stopping at 2
# 0.33131574712535167 0.863953025477707
# embedding.weight     | nonzeros = 1638433 / 5000200 ( 32.77%) | total_pruned = 3361767 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    9830 /   30000 ( 32.77%) | total_pruned =   20170 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# convs.1.weight       | nonzeros =   13107 /   40000 ( 32.77%) | total_pruned =   26893 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# convs.2.weight       | nonzeros =   16384 /   50000 ( 32.77%) | total_pruned =   33616 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# fc.weight            | nonzeros =      97 /     300 ( 32.33%) | total_pruned =     203 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1677951, pruned : 3442850, total: 5120801, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.3344827756047883 0.8544714095744681
# 1 0.31365984325554774 0.8672706117021277
# 2 0.3319186052664163 0.8654421542553191
# 3 0.3444429377212803 0.8667719414893617
# Early Stopping at 3
# 0.31365984325554774 0.8683320063694268
# embedding.weight     | nonzeros = 1310747 / 5000200 ( 26.21%) | total_pruned = 3689453 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    7864 /   30000 ( 26.21%) | total_pruned =   22136 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# convs.1.weight       | nonzeros =   10485 /   40000 ( 26.21%) | total_pruned =   29515 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# convs.2.weight       | nonzeros =   13107 /   50000 ( 26.21%) | total_pruned =   36893 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# fc.weight            | nonzeros =      77 /     300 ( 25.67%) | total_pruned =     223 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1342359, pruned : 3778442, total: 5120801, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.3260470411561905 0.8597905585106383
# 1 0.31722149498602176 0.8698470744680851
# 2 0.33349435142380124 0.866938164893617
# 3 0.35906831650657856 0.8660239361702128
# Early Stopping at 3
# 0.31722149498602176 0.8697253184713376
# embedding.weight     | nonzeros = 1048597 / 5000200 ( 20.97%) | total_pruned = 3951603 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    6291 /   30000 ( 20.97%) | total_pruned =   23709 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# convs.1.weight       | nonzeros =    8388 /   40000 ( 20.97%) | total_pruned =   31612 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# convs.2.weight       | nonzeros =   10485 /   50000 ( 20.97%) | total_pruned =   39515 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# fc.weight            | nonzeros =      61 /     300 ( 20.33%) | total_pruned =     239 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1073886, pruned : 4046915, total: 5120801, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.33022810368144767 0.8608710106382979
# 1 0.3241973937825954 0.8654421542553191
# 2 0.329724427867443 0.8641954787234043
# 3 0.3409604744074192 0.8686003989361702
# Early Stopping at 3
# 0.3241973937825954 0.8651472929936306
# embedding.weight     | nonzeros =  838877 / 5000200 ( 16.78%) | total_pruned = 4161323 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    5033 /   30000 ( 16.78%) | total_pruned =   24967 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# convs.1.weight       | nonzeros =    6710 /   40000 ( 16.77%) | total_pruned =   33290 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# convs.2.weight       | nonzeros =    8388 /   50000 ( 16.78%) | total_pruned =   41612 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# fc.weight            | nonzeros =      49 /     300 ( 16.33%) | total_pruned =     251 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 859109, pruned : 4261692, total: 5120801, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.3384619946492479 0.855219414893617
# 1 0.32478145153281535 0.8631150265957447
# 2 0.3311292644035309 0.8616190159574468
# 3 0.3314934919409929 0.8653590425531915
# Early Stopping at 3
# 0.32478145153281535 0.8640525477707006
# embedding.weight     | nonzeros =  671101 / 5000200 ( 13.42%) | total_pruned = 4329099 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    4026 /   30000 ( 13.42%) | total_pruned =   25974 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# convs.1.weight       | nonzeros =    5368 /   40000 ( 13.42%) | total_pruned =   34632 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# convs.2.weight       | nonzeros =    6710 /   50000 ( 13.42%) | total_pruned =   43290 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# fc.weight            | nonzeros =      39 /     300 ( 13.00%) | total_pruned =     261 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 687284, pruned : 4433517, total: 5120801, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.35287116856334055 0.8502327127659575
# 1 0.3351197906155535 0.8582114361702128
# 2 0.3288960452092455 0.8599567819148937
# 3 0.3328393304601629 0.859375
# 4 0.33766223054299965 0.862533244680851
# Early Stopping at 4
# 0.3288960452092455 0.8608678343949044
# embedding.weight     | nonzeros =  536881 / 5000200 ( 10.74%) | total_pruned = 4463319 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    3221 /   30000 ( 10.74%) | total_pruned =   26779 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.1.weight       | nonzeros =    4294 /   40000 ( 10.73%) | total_pruned =   35706 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.2.weight       | nonzeros =    5368 /   50000 ( 10.74%) | total_pruned =   44632 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# fc.weight            | nonzeros =      31 /     300 ( 10.33%) | total_pruned =     269 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 549826, pruned : 4570975, total: 5120801, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.3521861561593857 0.851811835106383
# 1 0.3419788493279447 0.8533909574468085
# 2 0.33408784319428686 0.85546875
# 3 0.3377823483278143 0.8561336436170213
# 4 0.3381820966271644 0.8589594414893617
# Early Stopping at 4
# 0.33408784319428686 0.8592754777070064
# embedding.weight     | nonzeros =  429505 / 5000200 (  8.59%) | total_pruned = 4570695 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2577 /   30000 (  8.59%) | total_pruned =   27423 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.1.weight       | nonzeros =    3435 /   40000 (  8.59%) | total_pruned =   36565 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.2.weight       | nonzeros =    4294 /   50000 (  8.59%) | total_pruned =   45706 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# fc.weight            | nonzeros =      25 /     300 (  8.33%) | total_pruned =     275 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 439861, pruned : 4680940, total: 5120801, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.3677367438027199 0.8406748670212766
# 1 0.3561537344246469 0.8460771276595744
# 2 0.3488110226995133 0.8502327127659575
# 3 0.3475408651568788 0.8499833776595744
# 4 0.3449943022049488 0.8541389627659575
# 5 0.34997114126986645 0.854720744680851
# 6 0.34879168400422056 0.8575465425531915
# Early Stopping at 6
# 0.3449943022049488 0.851015127388535
# embedding.weight     | nonzeros =  343604 / 5000200 (  6.87%) | total_pruned = 4656596 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2061 /   30000 (  6.87%) | total_pruned =   27939 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.1.weight       | nonzeros =    2748 /   40000 (  6.87%) | total_pruned =   37252 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.2.weight       | nonzeros =    3435 /   50000 (  6.87%) | total_pruned =   46565 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# fc.weight            | nonzeros =      20 /     300 (  6.67%) | total_pruned =     280 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 351887, pruned : 4768914, total: 5120801, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.3770628899652907 0.8392619680851063
# 1 0.360224085047524 0.843999335106383
# 2 0.35782102408244254 0.8444148936170213
# 3 0.3552327867835126 0.8464095744680851
# 4 0.35538632153196537 0.8454122340425532
# 5 0.3579772476186144 0.8460771276595744
# Early Stopping at 5
# 0.3552327867835126 0.8466361464968153
# embedding.weight     | nonzeros =  274883 / 5000200 (  5.50%) | total_pruned = 4725317 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1649 /   30000 (  5.50%) | total_pruned =   28351 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.1.weight       | nonzeros =    2198 /   40000 (  5.50%) | total_pruned =   37802 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.2.weight       | nonzeros =    2748 /   50000 (  5.50%) | total_pruned =   47252 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# fc.weight            | nonzeros =      16 /     300 (  5.33%) | total_pruned =     284 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 281510, pruned : 4839291, total: 5120801, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.41128066578444017 0.8279587765957447
# 1 0.3809259390418834 0.8395113031914894
# 2 0.37582091067699674 0.836685505319149
# 3 0.37579626922911785 0.8351063829787234
# 4 0.372595848951568 0.8377659574468085
# 5 0.37265509374915284 0.839345079787234
# 6 0.3720353035692205 0.8405086436170213
# 7 0.37125307250213113 0.8408410904255319
# 8 0.37559928047530194 0.8401761968085106
# Early Stopping at 8
# 0.37125307250213113 0.8357882165605095
# embedding.weight     | nonzeros =  219906 / 5000200 (  4.40%) | total_pruned = 4780294 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1319 /   30000 (  4.40%) | total_pruned =   28681 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.1.weight       | nonzeros =    1758 /   40000 (  4.39%) | total_pruned =   38242 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.2.weight       | nonzeros =    2198 /   50000 (  4.40%) | total_pruned =   47802 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# fc.weight            | nonzeros =      13 /     300 (  4.33%) | total_pruned =     287 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 225207, pruned : 4895594, total: 5120801, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.41872943715846284 0.8236369680851063
# 1 0.3953684889414209 0.8311170212765957
# 2 0.39392981234383073 0.8337765957446809
# 3 0.3901606634893316 0.835189494680851
# 4 0.39302461824201523 0.8324468085106383
# 5 0.3929621987044811 0.8330285904255319
# Early Stopping at 5
# 0.3901606634893316 0.8304140127388535
# embedding.weight     | nonzeros =  175925 / 5000200 (  3.52%) | total_pruned = 4824275 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1055 /   30000 (  3.52%) | total_pruned =   28945 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.1.weight       | nonzeros =    1406 /   40000 (  3.52%) | total_pruned =   38594 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.2.weight       | nonzeros =    1758 /   50000 (  3.52%) | total_pruned =   48242 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# fc.weight            | nonzeros =      10 /     300 (  3.33%) | total_pruned =     290 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 180164, pruned : 4940637, total: 5120801, Compression rate :      28.42x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.4508729134785368 0.8114195478723404
# 1 0.4292840234776761 0.8170711436170213
# 2 0.42036771536507506 0.8188164893617021
# 3 0.421756313043706 0.8218916223404256
# 4 0.4152455242707374 0.8215591755319149
# 5 0.413690392324265 0.823720079787234
# 6 0.41162229757359686 0.823470744680851
# 7 0.4125264781586667 0.8257978723404256
# Early Stopping at 7
# 0.41162229757359686 0.8252388535031847
# embedding.weight     | nonzeros =  140740 / 5000200 (  2.81%) | total_pruned = 4859460 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     844 /   30000 (  2.81%) | total_pruned =   29156 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.1.weight       | nonzeros =    1125 /   40000 (  2.81%) | total_pruned =   38875 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.2.weight       | nonzeros =    1406 /   50000 (  2.81%) | total_pruned =   48594 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# fc.weight            | nonzeros =       8 /     300 (  2.67%) | total_pruned =     292 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 144130, pruned : 4976671, total: 5120801, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.49842250458103543 0.7942985372340425
# 1 0.47515444806281554 0.7999501329787234
# 2 0.46123905606726384 0.7996176861702128
# 3 0.4604034910493709 0.801030585106383
# 4 0.45611500486414486 0.8035239361702128
# 5 0.45155337722377575 0.8069315159574468
# 6 0.44630531855720157 0.8047706117021277
# 7 0.450289507971165 0.8047706117021277
# 8 0.4475723406735887 0.8046875
# Early Stopping at 8
# 0.44630531855720157 0.8094148089171974
# embedding.weight     | nonzeros =  112592 / 5000200 (  2.25%) | total_pruned = 4887608 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     675 /   30000 (  2.25%) | total_pruned =   29325 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     900 /   40000 (  2.25%) | total_pruned =   39100 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1125 /   50000 (  2.25%) | total_pruned =   48875 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       6 /     300 (  2.00%) | total_pruned =     294 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 115302, pruned : 5005499, total: 5120801, Compression rate :      44.41x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.5095178167870704 0.7771775265957447
# 1 0.48779834442316217 0.7836602393617021
# 2 0.4764176615058108 0.7880651595744681
# 3 0.463190810001911 0.780501994680851
# 4 0.4556200431382402 0.8016123670212766
# 5 0.46541568161325253 0.7905585106382979
# 6 0.45869700911831346 0.80078125
# Early Stopping at 6
# 0.4556200431382402 0.7998606687898089
# embedding.weight     | nonzeros =   90073 / 5000200 (  1.80%) | total_pruned = 4910127 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     540 /   30000 (  1.80%) | total_pruned =   29460 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     720 /   40000 (  1.80%) | total_pruned =   39280 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     900 /   50000 (  1.80%) | total_pruned =   49100 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       5 /     300 (  1.67%) | total_pruned =     295 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 92242, pruned : 5028559, total: 5120801, Compression rate :      55.51x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.5309719719151234 0.7675365691489362
# 1 0.50820035519118 0.7712765957446809
# 2 0.48718267171940904 0.7840757978723404
# 3 0.4898674873278496 0.7884807180851063
# 4 0.4884064126204937 0.7838264627659575
# Early Stopping at 4
# 0.48718267171940904 0.790406050955414
# embedding.weight     | nonzeros =   72058 / 5000200 (  1.44%) | total_pruned = 4928142 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     432 /   30000 (  1.44%) | total_pruned =   29568 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     576 /   40000 (  1.44%) | total_pruned =   39424 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     720 /   50000 (  1.44%) | total_pruned =   49280 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       4 /     300 (  1.33%) | total_pruned =     296 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 73794, pruned : 5047007, total: 5120801, Compression rate :      69.39x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.5526552954886822 0.7524933510638298
# 1 0.5299814754027001 0.7689494680851063
# 2 0.5200329754263797 0.7754321808510638
# 3 0.5133160021393857 0.7721908244680851
# 4 0.5072256229976391 0.7740192819148937
# 5 0.4973923703457447 0.7821642287234043
# 6 0.49875928509108564 0.777094414893617
# 7 0.5054004363557125 0.7766788563829787
# Early Stopping at 7
# 0.4973923703457447 0.7856289808917197
# embedding.weight     | nonzeros =   57646 / 5000200 (  1.15%) | total_pruned = 4942554 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     345 /   30000 (  1.15%) | total_pruned =   29655 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     461 /   40000 (  1.15%) | total_pruned =   39539 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     576 /   50000 (  1.15%) | total_pruned =   49424 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       3 /     300 (  1.00%) | total_pruned =     297 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 59035, pruned : 5061766, total: 5120801, Compression rate :      86.74x  ( 98.85% pruned)

# %%
# lr_f
print(performance)
print(valid_losses)

lr_f_performance = performance
lr_f_valid_losses = valid_losses
# Out:
# [87.90804140127389, 87.46019108280255, 87.26114649681529, 87.37062101910828, 87.54976114649682, 86.3953025477707, 86.83320063694268, 86.97253184713377, 86.51472929936305, 86.40525477707006, 86.08678343949045, 85.92754777070064, 85.1015127388535, 84.66361464968153, 83.57882165605095, 83.04140127388536, 82.52388535031847, 80.94148089171973, 79.98606687898089, 79.04060509554141, 78.56289808917197]
# [0.41461936713374675, 0.40466037313354775, 0.38330680508404336, 0.35390813276171684, 0.39517574503700786, 0.3877002265938419, 0.3444429377212803, 0.35906831650657856, 0.3409604744074192, 0.3314934919409929, 0.33766223054299965, 0.3381820966271644, 0.34879168400422056, 0.3579772476186144, 0.37559928047530194, 0.3929621987044811, 0.4125264781586667, 0.4475723406735887, 0.45869700911831346, 0.4884064126204937, 0.5054004363557125]

# %% [markdown]
# ## 4) lt+lr (last epoch)

# %%
reinit = False # random이면 True, lt면 False
mode = 'lr_l'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.BCEWithLogitsLoss()

criterion = criterion.to(device)

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  best_valid_loss = float('inf')
  # early stopping
  count = 0

  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        best_state_dict = copy.deepcopy(model.state_dict())

    else:
        count +=1
        
    if count == 2:
        print(f'Early Stopping at {epoch}')
        break

  model.load_state_dict(best_state_dict)
  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(best_valid_loss, test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  # late rewinding after the last epoch
  if pruning_iter == 0:
     initial_state_dict = copy.deepcopy(model.state_dict())

  print_nonzeros(model)
# Out:
# 0 0.35906656458973885 0.8467420212765957
# 1 0.30482809443740133 0.8738364361702128
# 2 0.30886234339088836 0.8804853723404256
# 3 0.4418924398958049 0.866688829787234
# Early Stopping at 3
# 0.30482809443740133 0.870421974522293
# embedding.weight     | nonzeros = 5000100 / 5000200 (100.00%) | total_pruned =     100 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   30000 /   30000 (100.00%) | total_pruned =       0 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.1.weight       | nonzeros =   40000 /   40000 (100.00%) | total_pruned =       0 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# convs.2.weight       | nonzeros =   50000 /   50000 (100.00%) | total_pruned =       0 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =     100 /     100 (100.00%) | total_pruned =       0 | shape = (100,)
# fc.weight            | nonzeros =     300 /     300 (100.00%) | total_pruned =       0 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 5120701, pruned : 100, total: 5120801, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.3365068239100436 0.8792386968085106
# 1 0.39378077727048955 0.8678523936170213
# 2 0.5061215933095268 0.8715093085106383
# Early Stopping at 2
# 0.3365068239100436 0.8756966560509554
# embedding.weight     | nonzeros = 4000081 / 5000200 ( 80.00%) | total_pruned = 1000119 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   24000 /   30000 ( 80.00%) | total_pruned =    6000 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.1.weight       | nonzeros =   32000 /   40000 ( 80.00%) | total_pruned =    8000 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# convs.2.weight       | nonzeros =   40000 /   50000 ( 80.00%) | total_pruned =   10000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      80 /     100 ( 80.00%) | total_pruned =      20 | shape = (100,)
# fc.weight            | nonzeros =     240 /     300 ( 80.00%) | total_pruned =      60 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 4096562, pruned : 1024239, total: 5120801, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.3210205355698758 0.878407579787234
# 1 0.4275571146306205 0.8740026595744681
# 2 0.4945930915468551 0.8662732712765957
# Early Stopping at 2
# 0.3210205355698758 0.87609474522293
# embedding.weight     | nonzeros = 3200065 / 5000200 ( 64.00%) | total_pruned = 1800135 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   19200 /   30000 ( 64.00%) | total_pruned =   10800 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.1.weight       | nonzeros =   25600 /   40000 ( 64.00%) | total_pruned =   14400 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# convs.2.weight       | nonzeros =   32000 /   50000 ( 64.00%) | total_pruned =   18000 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      64 /     100 ( 64.00%) | total_pruned =      36 | shape = (100,)
# fc.weight            | nonzeros =     192 /     300 ( 64.00%) | total_pruned =     108 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3277250, pruned : 1843551, total: 5120801, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.32767296606238855 0.875748005319149
# 1 0.3863673578709998 0.8707613031914894
# 2 0.46182458407859855 0.8704288563829787
# Early Stopping at 2
# 0.32767296606238855 0.8763933121019108
# embedding.weight     | nonzeros = 2560052 / 5000200 ( 51.20%) | total_pruned = 2440148 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   15360 /   30000 ( 51.20%) | total_pruned =   14640 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.1.weight       | nonzeros =   20480 /   40000 ( 51.20%) | total_pruned =   19520 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# convs.2.weight       | nonzeros =   25600 /   50000 ( 51.20%) | total_pruned =   24400 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      51 /     100 ( 51.00%) | total_pruned =      49 | shape = (100,)
# fc.weight            | nonzeros =     153 /     300 ( 51.00%) | total_pruned =     147 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2621799, pruned : 2499002, total: 5120801, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.3208462042694396 0.8739195478723404
# 1 0.37588814780750174 0.8709275265957447
# 2 0.42066548100890633 0.8675199468085106
# Early Stopping at 2
# 0.3208462042694396 0.8762937898089171
# embedding.weight     | nonzeros = 2048041 / 5000200 ( 40.96%) | total_pruned = 2952159 | shape = (50002, 100)
# convs.0.weight       | nonzeros =   12288 /   30000 ( 40.96%) | total_pruned =   17712 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.1.weight       | nonzeros =   16384 /   40000 ( 40.96%) | total_pruned =   23616 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# convs.2.weight       | nonzeros =   20480 /   50000 ( 40.96%) | total_pruned =   29520 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      41 /     100 ( 41.00%) | total_pruned =      59 | shape = (100,)
# fc.weight            | nonzeros =     122 /     300 ( 40.67%) | total_pruned =     178 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2097439, pruned : 3023362, total: 5120801, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.32185090586860127 0.8704288563829787
# 1 0.3502205083186322 0.8748337765957447
# 2 0.3834000949926199 0.8729222074468085
# Early Stopping at 2
# 0.32185090586860127 0.8725119426751592
# embedding.weight     | nonzeros = 1638433 / 5000200 ( 32.77%) | total_pruned = 3361767 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    9830 /   30000 ( 32.77%) | total_pruned =   20170 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# convs.1.weight       | nonzeros =   13107 /   40000 ( 32.77%) | total_pruned =   26893 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# convs.2.weight       | nonzeros =   16384 /   50000 ( 32.77%) | total_pruned =   33616 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      33 /     100 ( 33.00%) | total_pruned =      67 | shape = (100,)
# fc.weight            | nonzeros =      97 /     300 ( 32.33%) | total_pruned =     203 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1677951, pruned : 3442850, total: 5120801, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.32747076083212456 0.8661901595744681
# 1 0.333611634064545 0.8715093085106383
# 2 0.3519623138486071 0.8734208776595744
# Early Stopping at 2
# 0.32747076083212456 0.8671377388535032
# embedding.weight     | nonzeros = 1310746 / 5000200 ( 26.21%) | total_pruned = 3689454 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    7864 /   30000 ( 26.21%) | total_pruned =   22136 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# convs.1.weight       | nonzeros =   10485 /   40000 ( 26.21%) | total_pruned =   29515 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# convs.2.weight       | nonzeros =   13107 /   50000 ( 26.21%) | total_pruned =   36893 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      26 /     100 ( 26.00%) | total_pruned =      74 | shape = (100,)
# fc.weight            | nonzeros =      77 /     300 ( 25.67%) | total_pruned =     223 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1342358, pruned : 3778443, total: 5120801, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.3179657084748466 0.8655252659574468
# 1 0.3123336917859443 0.8737533244680851
# 2 0.3247630744776193 0.874501329787234
# 3 0.34299057781537795 0.8715093085106383
# Early Stopping at 3
# 0.3123336917859443 0.87390525477707
# embedding.weight     | nonzeros = 1048597 / 5000200 ( 20.97%) | total_pruned = 3951603 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    6291 /   30000 ( 20.97%) | total_pruned =   23709 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# convs.1.weight       | nonzeros =    8388 /   40000 ( 20.97%) | total_pruned =   31612 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# convs.2.weight       | nonzeros =   10485 /   50000 ( 20.97%) | total_pruned =   39515 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      21 /     100 ( 21.00%) | total_pruned =      79 | shape = (100,)
# fc.weight            | nonzeros =      61 /     300 ( 20.33%) | total_pruned =     239 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1073886, pruned : 4046915, total: 5120801, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.3173998543160393 0.8698470744680851
# 1 0.32085559303139116 0.8722573138297872
# 2 0.33588026103345636 0.8677692819148937
# Early Stopping at 2
# 0.3173998543160393 0.8714171974522293
# embedding.weight     | nonzeros =  838877 / 5000200 ( 16.78%) | total_pruned = 4161323 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    5033 /   30000 ( 16.78%) | total_pruned =   24967 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# convs.1.weight       | nonzeros =    6710 /   40000 ( 16.77%) | total_pruned =   33290 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# convs.2.weight       | nonzeros =    8388 /   50000 ( 16.78%) | total_pruned =   41612 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      17 /     100 ( 17.00%) | total_pruned =      83 | shape = (100,)
# fc.weight            | nonzeros =      49 /     300 ( 16.33%) | total_pruned =     251 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 859109, pruned : 4261692, total: 5120801, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.32344988654268547 0.8607878989361702
# 1 0.3181062770333696 0.8657746010638298
# 2 0.31719057079642377 0.8672706117021277
# 3 0.323732501807365 0.8661070478723404
# 4 0.32712331842234793 0.8691821808510638
# Early Stopping at 4
# 0.31719057079642377 0.8710191082802548
# embedding.weight     | nonzeros =  671102 / 5000200 ( 13.42%) | total_pruned = 4329098 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    4026 /   30000 ( 13.42%) | total_pruned =   25974 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# convs.1.weight       | nonzeros =    5368 /   40000 ( 13.42%) | total_pruned =   34632 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# convs.2.weight       | nonzeros =    6710 /   50000 ( 13.42%) | total_pruned =   43290 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      13 /     100 ( 13.00%) | total_pruned =      87 | shape = (100,)
# fc.weight            | nonzeros =      39 /     300 ( 13.00%) | total_pruned =     261 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 687285, pruned : 4433516, total: 5120801, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.32527476493665514 0.8631981382978723
# 1 0.3219370211058475 0.8639461436170213
# 2 0.3226059208366465 0.8681017287234043
# 3 0.325547909720781 0.8671043882978723
# Early Stopping at 3
# 0.3219370211058475 0.8687300955414012
# embedding.weight     | nonzeros =  536882 / 5000200 ( 10.74%) | total_pruned = 4463318 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    3221 /   30000 ( 10.74%) | total_pruned =   26779 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.1.weight       | nonzeros =    4294 /   40000 ( 10.73%) | total_pruned =   35706 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# convs.2.weight       | nonzeros =    5368 /   50000 ( 10.74%) | total_pruned =   44632 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =      10 /     100 ( 10.00%) | total_pruned =      90 | shape = (100,)
# fc.weight            | nonzeros =      31 /     300 ( 10.33%) | total_pruned =     269 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 549827, pruned : 4570974, total: 5120801, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.3476011605655893 0.8515625
# 1 0.3395786241806568 0.8525598404255319
# 2 0.3340176580909719 0.8567154255319149
# 3 0.33538439204084114 0.8599567819148937
# 4 0.3403353736280127 0.8568816489361702
# Early Stopping at 4
# 0.3340176580909719 0.8645501592356688
# embedding.weight     | nonzeros =  429505 / 5000200 (  8.59%) | total_pruned = 4570695 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2577 /   30000 (  8.59%) | total_pruned =   27423 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.1.weight       | nonzeros =    3435 /   40000 (  8.59%) | total_pruned =   36565 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# convs.2.weight       | nonzeros =    4294 /   50000 (  8.59%) | total_pruned =   45706 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       8 /     100 (  8.00%) | total_pruned =      92 | shape = (100,)
# fc.weight            | nonzeros =      25 /     300 (  8.33%) | total_pruned =     275 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 439861, pruned : 4680940, total: 5120801, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.36008815118607057 0.8466589095744681
# 1 0.34145536559059264 0.854720744680851
# 2 0.3454103755982632 0.8517287234042553
# 3 0.3403136695319034 0.8565492021276596
# 4 0.3423454927161653 0.8584607712765957
# Early Stopping at 4
# 0.3403136695319034 0.8600716560509554
# embedding.weight     | nonzeros =  343604 / 5000200 (  6.87%) | total_pruned = 4656596 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    2061 /   30000 (  6.87%) | total_pruned =   27939 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.1.weight       | nonzeros =    2748 /   40000 (  6.87%) | total_pruned =   37252 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# convs.2.weight       | nonzeros =    3435 /   50000 (  6.87%) | total_pruned =   46565 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       6 /     100 (  6.00%) | total_pruned =      94 | shape = (100,)
# fc.weight            | nonzeros =      20 /     300 (  6.67%) | total_pruned =     280 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 351887, pruned : 4768914, total: 5120801, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.36509763108606036 0.8466589095744681
# 1 0.35332656849889044 0.8491522606382979
# 2 0.35281258869044324 0.8483211436170213
# 3 0.354020764853092 0.8490691489361702
# 4 0.35299074554696996 0.8492353723404256
# Early Stopping at 4
# 0.35281258869044324 0.8514132165605095
# embedding.weight     | nonzeros =  274883 / 5000200 (  5.50%) | total_pruned = 4725317 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1649 /   30000 (  5.50%) | total_pruned =   28351 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.1.weight       | nonzeros =    2198 /   40000 (  5.50%) | total_pruned =   37802 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# convs.2.weight       | nonzeros =    2748 /   50000 (  5.50%) | total_pruned =   47252 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       5 /     100 (  5.00%) | total_pruned =      95 | shape = (100,)
# fc.weight            | nonzeros =      16 /     300 (  5.33%) | total_pruned =     284 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 281510, pruned : 4839291, total: 5120801, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.4072501612629028 0.8269614361702128
# 1 0.3853486232618068 0.8289561170212766
# 2 0.37856806656147574 0.8343583776595744
# 3 0.3750857632369437 0.8344414893617021
# 4 0.371977401144327 0.8381815159574468
# 5 0.3745468694003338 0.8365192819148937
# 6 0.37585978384347674 0.8353557180851063
# Early Stopping at 6
# 0.371977401144327 0.8473328025477707
# embedding.weight     | nonzeros =  219906 / 5000200 (  4.40%) | total_pruned = 4780294 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1319 /   30000 (  4.40%) | total_pruned =   28681 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.1.weight       | nonzeros =    1758 /   40000 (  4.39%) | total_pruned =   38242 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# convs.2.weight       | nonzeros =    2198 /   50000 (  4.40%) | total_pruned =   47802 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       4 /     100 (  4.00%) | total_pruned =      96 | shape = (100,)
# fc.weight            | nonzeros =      13 /     300 (  4.33%) | total_pruned =     287 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 225207, pruned : 4895594, total: 5120801, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.41377143419169365 0.8248836436170213
# 1 0.39508113122366845 0.8289561170212766
# 2 0.3947983980178833 0.8259640957446809
# 3 0.39365523879198316 0.8265458776595744
# 4 0.39368335379565017 0.8252992021276596
# 5 0.3897824751886916 0.8287898936170213
# 6 0.39421658534952936 0.827626329787234
# Early Stopping at 6
# 0.3897824751886916 0.8369824840764332
# embedding.weight     | nonzeros =  175925 / 5000200 (  3.52%) | total_pruned = 4824275 | shape = (50002, 100)
# convs.0.weight       | nonzeros =    1055 /   30000 (  3.52%) | total_pruned =   28945 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.1.weight       | nonzeros =    1406 /   40000 (  3.52%) | total_pruned =   38594 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# convs.2.weight       | nonzeros =    1758 /   50000 (  3.52%) | total_pruned =   48242 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       3 /     100 (  3.00%) | total_pruned =      97 | shape = (100,)
# fc.weight            | nonzeros =      10 /     300 (  3.33%) | total_pruned =     290 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 180164, pruned : 4940637, total: 5120801, Compression rate :      28.42x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.4459947262038576 0.8153257978723404
# 1 0.4303771327150629 0.8198969414893617
# 2 0.42283369616625155 0.817154255319149
# 3 0.4112695373119192 0.8207280585106383
# 4 0.4152764487773814 0.8203956117021277
# 5 0.41231320988624653 0.8228889627659575
# Early Stopping at 5
# 0.4112695373119192 0.8245421974522293
# embedding.weight     | nonzeros =  140740 / 5000200 (  2.81%) | total_pruned = 4859460 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     844 /   30000 (  2.81%) | total_pruned =   29156 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.1.weight       | nonzeros =    1125 /   40000 (  2.81%) | total_pruned =   38875 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# convs.2.weight       | nonzeros =    1406 /   50000 (  2.81%) | total_pruned =   48594 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       2 /     100 (  2.00%) | total_pruned =      98 | shape = (100,)
# fc.weight            | nonzeros =       8 /     300 (  2.67%) | total_pruned =     292 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 144130, pruned : 4976671, total: 5120801, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.48940466788220915 0.7942154255319149
# 1 0.4759834646544558 0.7989527925531915
# 2 0.4648990975098407 0.804188829787234
# 3 0.46025555422331427 0.8092586436170213
# 4 0.45390667782184924 0.8064328457446809
# 5 0.45631373309074563 0.8016123670212766
# 6 0.4496330400096609 0.803939494680851
# 7 0.44404786777623156 0.8069315159574468
# 8 0.44850464498109005 0.8045212765957447
# Early Stopping at 8
# 0.44404786777623156 0.8141918789808917
# embedding.weight     | nonzeros =  112592 / 5000200 (  2.25%) | total_pruned = 4887608 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     675 /   30000 (  2.25%) | total_pruned =   29325 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     900 /   40000 (  2.25%) | total_pruned =   39100 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =    1125 /   50000 (  2.25%) | total_pruned =   48875 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       6 /     300 (  2.00%) | total_pruned =     294 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 115302, pruned : 5005499, total: 5120801, Compression rate :      44.41x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.4934784048732291 0.7862367021276596
# 1 0.480903353779874 0.788563829787234
# 2 0.4727968177262773 0.7906416223404256
# 3 0.46693466556199054 0.7923869680851063
# 4 0.46207844259891107 0.7936336436170213
# 5 0.4612464300812559 0.7972905585106383
# 6 0.4583884910383123 0.7989527925531915
# 7 0.4611124922620489 0.79296875
# 8 0.45351329350725134 0.7970412234042553
# 9 0.4506643595213586 0.7987865691489362
# 10 0.45625628943138935 0.7982047872340425
# Early Stopping at 10
# 0.4506643595213586 0.7999601910828026
# embedding.weight     | nonzeros =   90073 / 5000200 (  1.80%) | total_pruned = 4910127 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     540 /   30000 (  1.80%) | total_pruned =   29460 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     720 /   40000 (  1.80%) | total_pruned =   39280 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     900 /   50000 (  1.80%) | total_pruned =   49100 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       5 /     300 (  1.67%) | total_pruned =     295 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 92242, pruned : 5028559, total: 5120801, Compression rate :      55.51x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.5088928112007202 0.7676196808510638
# 1 0.49547541426851394 0.7750166223404256
# 2 0.4856576716646235 0.7789228723404256
# 3 0.47794867719107487 0.7816655585106383
# 4 0.48567199389985266 0.7849900265957447
# 5 0.47706211469274884 0.785405585106383
# 6 0.47879437864460844 0.7836602393617021
# Early Stopping at 6
# 0.47706211469274884 0.7886146496815286
# embedding.weight     | nonzeros =   72058 / 5000200 (  1.44%) | total_pruned = 4928142 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     432 /   30000 (  1.44%) | total_pruned =   29568 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     576 /   40000 (  1.44%) | total_pruned =   39424 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     720 /   50000 (  1.44%) | total_pruned =   49280 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       4 /     300 (  1.33%) | total_pruned =     296 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 73794, pruned : 5047007, total: 5120801, Compression rate :      69.39x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.5430586510833274 0.758061835106383
# 1 0.5181489867415834 0.765126329787234
# 2 0.5076139068349879 0.7682845744680851
# 3 0.5048736991717461 0.7696143617021277
# 4 0.49874101563337003 0.7748503989361702
# 5 0.49626700928870665 0.7795046542553191
# 6 0.49016106398181714 0.7843251329787234
# 7 0.4958096016594704 0.7816655585106383
# 8 0.4895207503057541 0.7784242021276596
# 9 0.4946107585379418 0.785904255319149
# Early Stopping at 9
# 0.4895207503057541 0.7816480891719745
# embedding.weight     | nonzeros =   57646 / 5000200 (  1.15%) | total_pruned = 4942554 | shape = (50002, 100)
# convs.0.weight       | nonzeros =     345 /   30000 (  1.15%) | total_pruned =   29655 | shape = (100, 1, 3, 100)
# convs.0.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.1.weight       | nonzeros =     461 /   40000 (  1.15%) | total_pruned =   39539 | shape = (100, 1, 4, 100)
# convs.1.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# convs.2.weight       | nonzeros =     576 /   50000 (  1.15%) | total_pruned =   49424 | shape = (100, 1, 5, 100)
# convs.2.bias         | nonzeros =       1 /     100 (  1.00%) | total_pruned =      99 | shape = (100,)
# fc.weight            | nonzeros =       3 /     300 (  1.00%) | total_pruned =     297 | shape = (1, 300)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 59035, pruned : 5061766, total: 5120801, Compression rate :      86.74x  ( 98.85% pruned)
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.48915633622636184 0.7785904255319149
# 1 0.49183108879530685 0.7815824468085106
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-7957262be259> in <module>()
#      39   # train
#      40   for epoch in range(N_EPOCH):
# ---> 41     train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
#      42     valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
#      43     print(epoch, valid_loss, valid_acc)
#
# <ipython-input-10-76b05163e3bd> in train(model, iterator, optimizer, criterion)
#       7     model.train()
#       8
# ----> 9     for batch in iterator:
#      10
#      11       text = batch.text[0]
#
# /usr/local/lib/python3.6/dist-packages/torchtext/data/iterator.py in __iter__(self)
#     155                     else:
#     156                         minibatch.sort(key=self.sort_key, reverse=True)
# --> 157                 yield Batch(minibatch, self.dataset, self.device)
#     158             if not self.repeat:
#     159                 return
#
# /usr/local/lib/python3.6/dist-packages/torchtext/data/batch.py in __init__(self, data, dataset, device)
#      32                 if field is not None:
#      33                     batch = [getattr(x, name) for x in data]
# ---> 34                     setattr(self, name, field.process(batch, device=device))
#      35
#      36     @classmethod
#
# /usr/local/lib/python3.6/dist-packages/torchtext/data/field.py in process(self, batch, device)
#     199         """
#     200         padded = self.pad(batch)
# --> 201         tensor = self.numericalize(padded, device=device)
#     202         return tensor
#     203
#
# /usr/local/lib/python3.6/dist-packages/torchtext/data/field.py in numericalize(self, arr, device)
#     321                 arr = self.postprocessing(arr, None)
#     322
# --> 323         var = torch.tensor(arr, dtype=self.dtype, device=device)
#     324
#     325         if self.sequential and not self.batch_first:
#
# KeyboardInterrupt:

# %%
# lr_l
print(performance)
print(valid_losses)

lr_l_performance = performance
lr_l_valid_losses = valid_losses
