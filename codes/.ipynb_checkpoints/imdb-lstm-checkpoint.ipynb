# %% [markdown]
# [reference](https://github.com/bentrevett/pytorch-sentiment-analysis)

# %%
# Importing Libraries
import os
import copy
import time
import torch
import torchtext
from torchtext import data
from torchtext import datasets
from torchtext.vocab import GloVe
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/lt-module'
os.chdir(path)

# %%
# Custom Libraries
import DataLoader
import Model

# %% [markdown]
# ## Define functions - to load dataset & model

# %%
# load dataset
def load_dataset(dataset, architecture, batch_size, device, path):
    if dataset == "imdb":
      if architecture == "cnn":
        data = DataLoader.IMDB_CNN_CUSTOM(batch_size, device, path)
      elif architecture == "lstm":
        data = DataLoader.IMDB_LSTM(batch_size, device, path)

    elif dataset == "agnews":
        data = DataLoader.AGNEWS(batch_size, device, path)

    else:
        raise ValueError(dataset + "is not supported")

    return data

# load model and set hyperparameters
def load_model(architecture, data_choice, batch_size):

    if architecture == "cnn":
      # hyperparameters
      vocab_size = len(dataset.TEXT.vocab)
      embedding_dim = 100
      n_filters = 100
      filter_sizes = [3,4,5]
      dropout = 0.5
      pad_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.pad_token]
      
      if data_choice == "imdb":
        # binary-class
        output_dim = 1
        model = Model.binaryCNN(vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout, pad_idx)
      
      elif data_choice == "agnews":
        # multi-class
        output_dim = 4
        model = Model.multiCNN(vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, dropout, pad_idx)

      unk_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.unk_token]
      model.embedding.weight.data[unk_idx] = torch.zeros(embedding_dim)
      model.embedding.weight.data[pad_idx] = torch.zeros(embedding_dim)

      return model

    elif architecture == "lstm":
      # hyperparameters
      vocab_size = len(dataset.TEXT.vocab)
      embedding_dim = 100
      hidden_dim = 256
      output_dim = 1
      n_layers = 2
      bidirectional = True
      dropout = 0.5
      pad_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.pad_token]
      
      if data_choice == "imdb":
        # binary-class
        output_dim = 1
      
      elif data_choice == "agnews":
        # multi-class
        output_dim = 4
      
      model = Model.LSTM(vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout, pad_idx)

      unk_idx = dataset.TEXT.vocab.stoi[dataset.TEXT.unk_token]
      model.embedding.weight.data[unk_idx] = torch.zeros(embedding_dim)
      model.embedding.weight.data[pad_idx] = torch.zeros(embedding_dim)

      return model

    # temporary
    elif architecture == "bert":
        return None

    else:
        raise ValueError(architecture + "is not supported")

# %% [markdown]
# ## Weight initialization

# %%
# weight initializtion
def initialize_xavier_normal(m):
    
  """
	Function to initialize a layer by picking weights from a xavier normal distribution
	Arguments
	---------
	m : The layer of the neural network
	Returns
	-------
	None
	"""
  
  if type(m) == torch.nn.Conv2d:
    torch.nn.init.xavier_normal_(m.weight.data)
    m.bias.data.fill_(0)

  elif isinstance(m, torch.nn.Linear):
    torch.nn.init.xavier_normal_(m.weight.data)
    m.bias.data.fill_(0)

  elif type(m) in [torch.nn.GRU, torch.nn.LSTM, torch.nn.RNN]:
    for name, param in m.named_parameters():
        if 'weight_ih' in name:
          torch.nn.init.xavier_normal_(param.data)
        elif 'weight_hh' in name:
          torch.nn.init.orthogonal_(param.data)
        elif 'bias' in name:
          param.data.fill_(0)

# %% [markdown]
# ## train and test functions

# %%
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    return acc

# %%
def train(model, iterator, optimizer, criterion):
    # EPS = 1e-6
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for batch in iterator:
      
      optimizer.zero_grad()
      text, text_lengths = batch.text
      target = batch.label
      predictions = model(text, text_lengths).squeeze(1)
      loss = criterion(predictions, target)
      acc = binary_accuracy(predictions, target)
      loss.backward()
      step = 0

      # Freezing Pruned weights by making their gradients Zero
      for name, p in model.named_parameters():
        weight_dev = param.device
        tensor = p.data.cpu().numpy()
        grad_tensor = p.grad.data.cpu().numpy()
        grad_tensor = np.where(mask[step] == 0, 0, grad_tensor)
        p.grad.data = torch.from_numpy(grad_tensor).to(device)
        step += 1
      
      step = 0

      optimizer.step()
        
      epoch_loss += loss.item()
      epoch_acc += acc.item()
      
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
          text, text_lengths = batch.text
          target = batch.label
          
          predictions = model(text, text_lengths).squeeze(1)
            
          loss = criterion(predictions, batch.label)
            
          acc = binary_accuracy(predictions, batch.label)

          epoch_loss += loss.item()
          epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# ## Pruning Functions

# %%
# Prune by Percentile module
def prune_by_percentile(percent):
  global step
  global mask
  global model
  # Calculate percentile value
  step = 0
  for name, param in model.named_parameters():
    # if 'weight' in name:
    tensor = param.data.cpu().numpy()
    nz_count = np.count_nonzero(tensor)

    # bias가 all pruned 되는 경우 발생
    if nz_count == 0:
      step += 1

    else: 
      alive = tensor[np.nonzero(tensor)] # flattened array of nonzero values
      percentile_value = np.percentile(abs(alive), percent)

      # Convert Tensors to numpy and calculate
      weight_dev = param.device
      new_mask = np.where(abs(tensor) < percentile_value, 0, mask[step])
                
      # Apply new weight and mask
      param.data = torch.from_numpy(tensor * new_mask).to(weight_dev)
      mask[step] = new_mask
      step += 1

  step = 0

# %%
# Function to make an empty mask of the same size as the model
def make_mask(model):
  global step
  global mask
  
  step = 0
  for name, param in model.named_parameters(): 
    # if 'weight' in name:
    step += 1
  mask = [None]* step 
  step = 0
  for name, param in model.named_parameters(): 
    # if 'weight' in name:
    tensor = param.data.cpu().numpy()
    mask[step] = np.ones_like(tensor)
    step += 1
  step = 0

# %%
def original_initialization(mask_temp, initial_state_dict):
    global step
    global model
    
    step = 0
    for name, param in model.named_parameters(): 
        # if "weight" in name: 
            weight_dev = param.device
            param.data = torch.from_numpy(mask_temp[step] * initial_state_dict[name].cpu().numpy()).to(weight_dev)
            step = step + 1
        # if "bias" in name:
            # param.data = initial_state_dict[name]
    step = 0

# %%
# ANCHOR Print table of zeros and non-zeros count
def print_nonzeros(model):
    nonzero = total = 0
    for name, p in model.named_parameters():
        tensor = p.data.cpu().numpy()
        nz_count = np.count_nonzero(tensor)
        total_params = np.prod(tensor.shape)
        nonzero += nz_count
        total += total_params
        print(f'{name:20} | nonzeros = {nz_count:7} / {total_params:7} ({100 * nz_count / total_params:6.2f}%) | total_pruned = {total_params - nz_count :7} | shape = {tensor.shape}')
    print(f'alive: {nonzero}, pruned : {total - nonzero}, total: {total}, Compression rate : {total/nonzero:10.2f}x  ({100 * (total-nonzero) / total:6.2f}% pruned)')
    return (round(((total-nonzero)/total)*100,1))

# %% [markdown]
# ## Choose dataset & model

# %%
# colab에서 돌리기 때문에 우선 arg가 아니라 변수로 넘겨주기
data_choice = "imdb" # 데이터셋 선택
arch_choice = "lstm" # 모델 선택
batch_size = 64 # batch size 선택 - 32 or 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using {device} device.')
# Out:
# Using cuda device.

# %% [markdown]
# ### load dataset

# %%
dataset = load_dataset(data_choice, arch_choice, batch_size, device, path)

# %% [markdown]
# ### model setting

# %%
# check the trial number
trial = 9901

# pruning setting
iteration = 20
percent = 20 # 20% prune
N_EPOCH = 10
learning_rate = 5e-3

step = 0

# %% [markdown]
# ## 1) random initialization

# %%
reinit = True # random이면 True, lt면 False
mode = 'random'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# embedding 같은 것 주기 위해
embedding_pretrained_weight = model.embedding.weight

# model initialization and save the model
model.apply(initialize_xavier_normal)
# Out:
# LSTM(
#   (embedding): Embedding(25002, 100, padding_idx=1)
#   (rnn): LSTM(100, 256, num_layers=2, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 4,810,857 trainable parameters

# %%
# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.BCEWithLogitsLoss()

criterion = criterion.to(device)

# %%
for name, param in model.named_parameters():
  print(name, param.size())
# Out:
# embedding.weight torch.Size([25002, 100])
# rnn.weight_ih_l0 torch.Size([1024, 100])
# rnn.weight_hh_l0 torch.Size([1024, 256])
# rnn.bias_ih_l0 torch.Size([1024])
# rnn.bias_hh_l0 torch.Size([1024])
# rnn.weight_ih_l0_reverse torch.Size([1024, 100])
# rnn.weight_hh_l0_reverse torch.Size([1024, 256])
# rnn.bias_ih_l0_reverse torch.Size([1024])
# rnn.bias_hh_l0_reverse torch.Size([1024])
# rnn.weight_ih_l1 torch.Size([1024, 512])
# rnn.weight_hh_l1 torch.Size([1024, 256])
# rnn.bias_ih_l1 torch.Size([1024])
# rnn.bias_hh_l1 torch.Size([1024])
# rnn.weight_ih_l1_reverse torch.Size([1024, 512])
# rnn.weight_hh_l1_reverse torch.Size([1024, 256])
# rnn.bias_ih_l1_reverse torch.Size([1024])
# rnn.bias_hh_l1_reverse torch.Size([1024])
# fc.weight torch.Size([1, 512])
# fc.bias torch.Size([1])

# %%
print(list(model.named_parameters()))
# Out:
# [('embedding.weight', Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.7289, -0.7336,  1.5624,  ..., -0.5592, -0.4480, -0.6476],
#         ...,
#         [ 0.0914,  1.5196,  0.4670,  ...,  0.6393, -0.0332,  0.0185],
#         [-0.6290,  0.4650, -0.7165,  ..., -1.3171,  2.0381, -2.0497],
#         [-1.1222, -0.0240, -1.0878,  ..., -0.4948, -0.3874,  0.0339]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_ih_l0', Parameter containing:
# tensor([[-0.0007, -0.0342, -0.0056,  ...,  0.0398, -0.0260,  0.0581],
#         [-0.0651, -0.0441,  0.0244,  ..., -0.0132, -0.0476, -0.0412],
#         [-0.0146,  0.0274, -0.0125,  ..., -0.0522, -0.0511,  0.0084],
#         ...,
#         [ 0.0020,  0.0523,  0.0376,  ..., -0.1092, -0.0735,  0.0090],
#         [ 0.0571,  0.0342, -0.0489,  ..., -0.0208,  0.0213, -0.0137],
#         [-0.0753,  0.0224,  0.0323,  ...,  0.0165, -0.0369,  0.0058]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_hh_l0', Parameter containing:
# tensor([[ 0.0201, -0.0404, -0.0441,  ...,  0.0048, -0.0254, -0.0095],
#         [-0.0125, -0.0588, -0.0650,  ..., -0.0487,  0.0027, -0.0045],
#         [ 0.0333, -0.0073, -0.0420,  ..., -0.0452,  0.0330, -0.0280],
#         ...,
#         [-0.0058, -0.0746,  0.0238,  ..., -0.0290, -0.0151, -0.0462],
#         [-0.0285,  0.0724, -0.0852,  ...,  0.0143,  0.0315, -0.0247],
#         [-0.0855,  0.0068,  0.0292,  ..., -0.0204,  0.0058, -0.0583]],
#        device='cuda:0', requires_grad=True)), ('rnn.bias_ih_l0', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.bias_hh_l0', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.weight_ih_l0_reverse', Parameter containing:
# tensor([[ 0.0042,  0.0473,  0.0652,  ...,  0.0200, -0.0162, -0.0347],
#         [-0.0417, -0.0152, -0.0215,  ..., -0.0103,  0.0578, -0.0360],
#         [ 0.0765, -0.0155,  0.0170,  ...,  0.0461,  0.0542,  0.0431],
#         ...,
#         [-0.0420, -0.0477,  0.0034,  ...,  0.0471,  0.0605, -0.0011],
#         [ 0.0497, -0.0223, -0.0304,  ...,  0.0326, -0.0132,  0.0689],
#         [-0.0365,  0.0210,  0.0515,  ..., -0.0375,  0.0178,  0.0441]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_hh_l0_reverse', Parameter containing:
# tensor([[-0.0368,  0.0365, -0.0131,  ...,  0.0421, -0.0247,  0.0638],
#         [-0.0086,  0.0458, -0.0233,  ..., -0.0128,  0.0133, -0.0214],
#         [ 0.0185, -0.0195,  0.0041,  ...,  0.0074, -0.0286, -0.0020],
#         ...,
#         [ 0.0829,  0.0129, -0.0247,  ..., -0.0051,  0.0033,  0.0011],
#         [-0.0053,  0.0041,  0.0476,  ...,  0.0213, -0.0187,  0.0021],
#         [-0.0155,  0.0160, -0.0278,  ...,  0.0156,  0.0374, -0.0165]],
#        device='cuda:0', requires_grad=True)), ('rnn.bias_ih_l0_reverse', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.bias_hh_l0_reverse', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.weight_ih_l1', Parameter containing:
# tensor([[ 0.0518, -0.0387,  0.0276,  ...,  0.0066, -0.0385,  0.0249],
#         [ 0.0121,  0.0228,  0.0232,  ...,  0.0248,  0.0814, -0.0472],
#         [ 0.0055, -0.0029,  0.0225,  ...,  0.0557,  0.0133,  0.0327],
#         ...,
#         [-0.0640,  0.0039, -0.0581,  ..., -0.0067, -0.0471, -0.0133],
#         [ 0.0486,  0.0455,  0.0213,  ..., -0.0214,  0.0442, -0.0120],
#         [-0.0017, -0.0006, -0.0188,  ...,  0.0239,  0.0148, -0.0421]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_hh_l1', Parameter containing:
# tensor([[-0.0512,  0.0344,  0.0139,  ...,  0.0349,  0.0453,  0.0036],
#         [ 0.0107, -0.0442, -0.0486,  ...,  0.0354, -0.0195, -0.0340],
#         [ 0.0256,  0.0036,  0.0357,  ..., -0.0494,  0.0073,  0.0069],
#         ...,
#         [ 0.0301,  0.0055,  0.0185,  ..., -0.0778,  0.0104, -0.0111],
#         [-0.0187,  0.0274,  0.0584,  ...,  0.0083, -0.0699, -0.0514],
#         [ 0.0205, -0.0413, -0.0443,  ..., -0.0156,  0.0316, -0.0041]],
#        device='cuda:0', requires_grad=True)), ('rnn.bias_ih_l1', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.bias_hh_l1', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.weight_ih_l1_reverse', Parameter containing:
# tensor([[ 0.0408, -0.0522,  0.0615,  ..., -0.0322, -0.0331, -0.0431],
#         [-0.0178, -0.0477,  0.0047,  ..., -0.0473, -0.0357,  0.0206],
#         [ 0.0221,  0.0272,  0.0044,  ...,  0.0273,  0.0762,  0.0320],
#         ...,
#         [ 0.0075,  0.0033,  0.0092,  ..., -0.0787, -0.0355,  0.0204],
#         [ 0.0423,  0.0313,  0.0628,  ...,  0.0054,  0.0263, -0.0566],
#         [ 0.0027, -0.0243, -0.0478,  ...,  0.0032, -0.0308, -0.0265]],
#        device='cuda:0', requires_grad=True)), ('rnn.weight_hh_l1_reverse', Parameter containing:
# tensor([[ 0.0263, -0.0124,  0.0206,  ..., -0.0001,  0.0158, -0.0283],
#         [-0.0185,  0.0144, -0.0408,  ..., -0.0657, -0.0253,  0.0406],
#         [-0.0347,  0.0039,  0.0046,  ..., -0.0774, -0.0098,  0.0060],
#         ...,
#         [-0.0017,  0.0198,  0.0145,  ..., -0.0230,  0.0009,  0.0395],
#         [ 0.0480,  0.0432,  0.0466,  ...,  0.0383,  0.0262, -0.0235],
#         [-0.0329,  0.0188,  0.0401,  ...,  0.0246, -0.0755, -0.0499]],
#        device='cuda:0', requires_grad=True)), ('rnn.bias_ih_l1_reverse', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('rnn.bias_hh_l1_reverse', Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', requires_grad=True)), ('fc.weight', Parameter containing:
# tensor([[-1.0660e-01,  5.5069e-02,  5.3044e-02,  2.1260e-02,  2.5446e-02,
#          -2.2385e-03, -9.6256e-02,  5.5924e-02, -5.8789e-02, -6.8102e-02,
#          -1.4557e-01,  1.0721e-02, -1.2252e-02,  2.4091e-02, -3.8319e-02,
#          -5.9545e-02,  1.0002e-01, -3.7781e-02,  5.3375e-02, -4.1479e-02,
#          -7.2199e-02, -1.5696e-02, -5.9404e-02, -4.3565e-02, -5.0170e-02,
#           5.7455e-02,  4.7234e-02,  6.9764e-02, -9.8930e-03, -4.9612e-02,
#           6.0908e-02,  6.7616e-02, -6.1710e-02,  2.1265e-02,  3.3567e-02,
#          -4.2914e-03,  5.7062e-02,  5.1603e-02,  8.5969e-02, -6.2883e-02,
#           9.6754e-02,  1.2512e-02, -2.7475e-02,  9.2540e-02, -5.9778e-02,
#           6.5554e-02, -6.8043e-02,  5.6066e-02, -6.0174e-02, -1.2172e-01,
#          -3.7404e-02, -1.2235e-01, -9.8907e-03, -7.0477e-02,  6.3756e-02,
#           7.1752e-03,  3.0146e-03,  1.0048e-01,  3.1122e-02, -8.0469e-02,
#           2.1762e-03,  5.1684e-02, -4.0594e-02, -8.1085e-02, -5.5552e-03,
#          -7.2265e-02,  5.6158e-02, -8.1428e-02, -4.5658e-02,  1.9015e-02,
#          -2.4087e-02,  3.0851e-02, -8.7093e-02,  1.5059e-02, -9.2051e-02,
#           3.5285e-02,  3.6466e-02,  3.2337e-02, -2.5435e-02,  8.2995e-02,
#          -1.2124e-01, -1.2277e-02, -1.9423e-02, -5.4637e-04, -6.8374e-03,
#          -5.3129e-02,  3.7762e-02,  2.8330e-02,  5.6391e-02,  5.4029e-03,
#          -3.9746e-02, -2.8915e-02, -2.7662e-02, -3.0568e-02,  5.9152e-02,
#          -2.1443e-02,  6.0847e-02, -2.4732e-02,  6.3130e-02,  6.0377e-02,
#           5.7974e-02,  4.0310e-02,  1.7738e-02, -9.4321e-03, -1.1283e-01,
#           9.2110e-03,  3.3237e-02, -6.9683e-03, -1.8839e-02, -5.2867e-02,
#           8.8044e-03, -5.0261e-02, -5.0308e-02,  7.4671e-02,  9.4759e-02,
#           6.4647e-03,  2.9315e-02,  4.1992e-03,  6.8835e-02, -4.2918e-02,
#           4.9652e-02, -3.6356e-03, -2.3389e-02, -2.0582e-02, -2.2135e-02,
#           4.3460e-02,  4.8669e-02, -1.3516e-01, -6.4611e-02, -4.9593e-02,
#          -3.2588e-02, -1.0685e-02, -4.1176e-02,  3.4759e-02,  1.7527e-02,
#           9.7702e-02, -4.8754e-03,  1.1693e-02,  1.0417e-01,  4.3916e-02,
#          -2.7876e-02, -1.3508e-01, -4.4520e-03, -1.3800e-01,  8.3541e-02,
#          -1.2275e-01,  1.0756e-01,  3.6341e-02,  5.6887e-03, -6.6738e-03,
#          -4.1664e-02,  1.0850e-01,  2.3688e-02, -3.6872e-02,  5.8645e-02,
#          -4.1907e-02, -2.1394e-02,  2.2417e-02, -8.0829e-02, -2.3884e-03,
#           1.9815e-02, -3.0417e-02,  1.3203e-01,  3.1945e-02,  5.1034e-02,
#          -3.9871e-02,  4.8265e-02, -1.7149e-02, -4.3043e-02, -9.5521e-02,
#           2.3519e-02, -5.1052e-02, -4.0151e-02, -9.3080e-02,  9.8062e-02,
#          -1.5579e-02,  1.1062e-01, -8.5719e-02,  8.4204e-02, -1.8497e-02,
#          -5.4100e-03, -6.7750e-02,  5.2360e-03, -8.5974e-02,  9.0681e-02,
#          -4.8623e-03, -1.1584e-01,  8.1857e-02, -6.7297e-02, -2.8370e-02,
#          -4.1729e-02, -7.9215e-02, -1.3161e-01,  5.7040e-02,  1.3209e-02,
#          -6.7106e-02,  7.8217e-02, -2.3741e-02, -2.2092e-02, -2.8437e-02,
#           2.0969e-02, -1.0646e-02,  1.0685e-02,  1.3612e-01,  1.8642e-03,
#           8.9400e-02, -2.4804e-02, -6.7623e-02,  5.6591e-02,  8.9086e-03,
#           5.4646e-03,  8.3402e-03,  2.8555e-02, -3.9883e-03, -3.8026e-02,
#           5.2441e-02,  1.2645e-01,  5.8233e-02,  3.1854e-02,  8.8522e-02,
#          -1.3413e-02,  1.6270e-01,  1.0594e-01,  5.7393e-02, -3.8492e-02,
#           9.3706e-03,  1.0201e-01,  3.2792e-02, -8.4839e-02, -1.3034e-01,
#           1.3636e-02, -3.1015e-02, -3.5996e-03,  4.6696e-02, -6.9407e-03,
#           3.9389e-03, -4.0589e-02,  7.6249e-04,  3.2914e-02, -7.3082e-02,
#           9.2138e-02, -5.8427e-02,  1.2305e-01, -4.7605e-02, -1.5637e-01,
#          -4.3914e-02,  4.4211e-06, -1.0703e-03, -6.9656e-02, -9.0433e-02,
#           5.2480e-02, -4.1310e-02, -2.8635e-02, -4.2624e-02, -6.1199e-03,
#          -2.0460e-02,  1.1476e-01,  3.3825e-02, -7.9944e-03,  1.2383e-01,
#           2.3404e-02, -3.7662e-02,  7.9731e-02,  1.0430e-01,  1.6607e-02,
#          -3.0801e-03, -1.4845e-01, -1.5769e-01, -8.5514e-03,  3.2043e-02,
#           3.0488e-02,  4.6329e-02, -9.3059e-02, -3.7210e-02,  4.5489e-02,
#          -3.7190e-02, -8.2998e-02,  4.3870e-02,  5.0031e-03,  3.1383e-02,
#           9.4483e-03, -5.6353e-02,  3.2467e-02, -5.3051e-02,  1.0584e-01,
#           1.2846e-01,  6.4285e-02,  3.9882e-02,  8.1094e-02,  4.4686e-02,
#           3.7767e-02, -4.7648e-03,  6.8689e-02, -4.4735e-02,  2.1656e-04,
#          -1.5089e-02, -1.8692e-01, -4.9391e-02, -6.6036e-02, -1.0317e-01,
#           1.3592e-01, -3.0237e-02,  5.5010e-02, -6.0377e-02,  6.0908e-02,
#          -8.5939e-02, -3.4276e-02,  8.5495e-03,  7.0106e-02,  5.0310e-02,
#           3.7724e-02,  6.6209e-02, -3.4311e-02,  4.8853e-02, -1.9574e-02,
#          -4.2070e-03, -1.1768e-01,  2.6416e-03,  3.2129e-02, -3.8927e-02,
#           1.8944e-01, -2.0669e-02,  8.4657e-02,  2.9551e-02,  1.8227e-02,
#           2.1178e-02, -7.2739e-03,  1.2893e-03,  1.1889e-02,  2.7812e-02,
#           1.8740e-02, -3.9110e-02, -1.2814e-02,  1.2552e-01,  1.1679e-01,
#           4.0668e-02, -5.9091e-02,  2.4863e-02,  6.2678e-02, -1.6437e-02,
#          -1.6612e-02, -2.4839e-02,  3.7499e-02, -1.4882e-02, -1.5362e-02,
#          -1.1659e-02,  6.8997e-02, -2.1840e-02, -8.5922e-02,  7.4131e-02,
#           4.7953e-02,  1.7833e-03,  5.3738e-03,  1.5516e-03, -7.0427e-02,
#          -6.5282e-02,  3.9874e-02, -3.7563e-02,  9.4268e-02,  1.1018e-01,
#           5.9341e-02, -1.0073e-01,  8.4286e-02, -1.0579e-01,  3.8340e-03,
#          -8.6318e-03, -6.2241e-02, -2.3219e-02,  6.8652e-02, -8.6870e-02,
#          -1.6852e-02, -2.6657e-02, -1.3760e-01, -7.6831e-02,  3.5552e-04,
#          -1.7902e-02,  7.8213e-02,  3.8143e-03,  6.9451e-02,  3.2334e-02,
#          -4.0800e-02, -6.7755e-02,  3.4543e-03,  1.7135e-02, -3.1702e-02,
#           4.7570e-02, -7.0140e-02, -3.1577e-02,  1.7429e-02, -3.1785e-02,
#          -5.7833e-02,  4.6239e-02,  5.0823e-02,  9.4936e-02, -5.7263e-02,
#          -1.8439e-02, -1.3200e-01, -6.9451e-02, -4.2280e-02, -1.1942e-02,
#           3.1879e-02,  1.9823e-02, -3.3121e-02, -2.8911e-04, -4.6646e-02,
#           8.2896e-02, -1.1526e-01,  2.5849e-02, -2.2153e-02, -2.9628e-03,
#          -7.6446e-02,  7.1438e-02, -5.6121e-02,  4.4138e-03, -5.2788e-03,
#           1.1533e-01,  1.0420e-02,  8.2758e-02, -8.1650e-04,  1.7661e-02,
#          -3.9968e-03, -5.4210e-02,  2.1569e-02, -5.5985e-02, -2.7624e-02,
#          -3.8582e-02, -5.3807e-02,  1.3977e-01,  5.4327e-04,  5.2430e-02,
#           6.0797e-02, -7.7587e-03,  5.1018e-02, -8.3488e-02,  1.1664e-01,
#          -7.4077e-03,  1.0218e-01,  9.7680e-02, -8.2764e-02, -6.4506e-02,
#           1.8195e-02,  4.8996e-02, -8.5700e-03,  5.9543e-02, -1.6779e-01,
#           5.5307e-02,  4.7371e-02, -7.9935e-02,  3.1224e-02,  8.1949e-02,
#           5.3722e-02, -3.0372e-02, -1.0268e-02, -1.3019e-03, -1.0348e-02,
#           4.1831e-02,  2.3417e-02,  1.5380e-02, -8.7950e-03, -1.3972e-01,
#           3.1415e-03,  4.4890e-02,  2.5636e-05,  3.5910e-02, -3.5388e-02,
#          -3.9833e-02,  6.7966e-03,  7.4973e-02, -5.5588e-02, -5.7528e-02,
#           4.0577e-02, -8.0751e-03, -4.4180e-03, -3.3333e-03, -1.2265e-02,
#          -4.1709e-02, -1.6196e-02, -5.6926e-02,  6.5634e-02, -9.0708e-02,
#          -2.4142e-02,  4.9270e-03,  5.1509e-02, -2.3873e-02,  5.2593e-02,
#          -3.2763e-02, -3.3079e-02,  1.0827e-01, -3.7912e-02, -1.3753e-02,
#          -5.4580e-02,  2.4255e-03, -4.6618e-02,  6.2952e-02,  9.5465e-02,
#           1.0669e-01,  2.5576e-02, -3.6121e-02, -7.9189e-02,  9.1461e-02,
#           1.1813e-02, -6.9621e-02, -2.9164e-02, -2.5001e-02,  5.1856e-02,
#          -1.0350e-01,  1.3114e-02, -4.9096e-02,  1.1472e-02,  8.4287e-03,
#           9.8549e-02,  6.1954e-02]], device='cuda:0', requires_grad=True)), ('fc.bias', Parameter containing:
# tensor([0.], device='cuda:0', requires_grad=True))]

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.662527102739253 0.5914228723404256
# 1 0.3716509703626024 0.8367686170212766
# 2 0.30710537533493754 0.87109375
# 3 0.3145540512781194 0.8773271276595744
# 4 0.2643658808888273 0.8996010638297872
# 5 0.36935136752559783 0.866688829787234
# 6 0.2801299524751115 0.8993517287234043
# 7 0.28347136072338897 0.9019281914893617
# 8 0.2799913494233438 0.8994348404255319
# 9 0.28661345952051753 0.9040059840425532
# 0.9014729299363057
# embedding.weight     | nonzeros = 2500100 / 2500200 (100.00%) | total_pruned =     100 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# fc.weight            | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 4810757, pruned : 100, total: 4810857, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.3122954769654477 0.886469414893617
# 1 0.381066400696464 0.8858045212765957
# 2 0.2935015342416281 0.8956117021276596
# 3 0.34057956525778516 0.9012632978723404
# 4 0.33102873855448783 0.9005984042553191
# 5 0.3114757637711281 0.8988530585106383
# 6 0.4557014767952422 0.8871343085106383
# 7 0.4543367566620099 0.8953623670212766
# 8 0.330054912914304 0.897689494680851
# 9 0.41716557053571685 0.8981050531914894
# 0.8937101910828026
# embedding.weight     | nonzeros = 2000080 / 2500200 ( 80.00%) | total_pruned =  500120 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# fc.weight            | nonzeros =     409 /     512 ( 79.88%) | total_pruned =     103 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3848602, pruned : 962255, total: 4810857, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.3528128279016373 0.8597074468085106
# 1 0.5306739919283923 0.8465757978723404
# 2 0.41799076218554315 0.8928690159574468
# 3 0.4524223298785534 0.8887134308510638
# 4 0.4807780624783419 0.8927859042553191
# 5 0.48608014696931584 0.8932845744680851
# 6 0.5533994976431131 0.8938663563829787
# 7 0.5114258104895658 0.893783244680851
# 8 0.6005697219850535 0.8892952127659575
# 9 0.45840316618535115 0.8882147606382979
# 0.8851512738853503
# embedding.weight     | nonzeros = 1600064 / 2500200 ( 64.00%) | total_pruned =  900136 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# fc.weight            | nonzeros =     327 /     512 ( 63.87%) | total_pruned =     185 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3078880, pruned : 1731977, total: 4810857, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.4510168460534608 0.8834773936170213
# 1 0.4241669228538237 0.8882978723404256
# 2 0.5080406272268676 0.8902094414893617
# 3 0.57147791553685 0.8807347074468085
# 4 0.5451205791707369 0.8866356382978723
# 5 0.5676388948006516 0.8873836436170213
# 6 0.5970652238465846 0.8877160904255319
# 7 0.6152136569961588 0.8863031914893617
# 8 0.5447136132799565 0.8850565159574468
# 9 0.7687182424867407 0.8853889627659575
# 0.8876393312101911
# embedding.weight     | nonzeros = 1280051 / 2500200 ( 51.20%) | total_pruned = 1220149 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# fc.weight            | nonzeros =     261 /     512 ( 50.98%) | total_pruned =     251 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2463101, pruned : 2347756, total: 4810857, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.478882585037896 0.8819813829787234
# 1 0.5904920006051977 0.88671875
# 2 0.6389856616114366 0.8852227393617021
# 3 0.7050704517540463 0.8834773936170213
# 4 0.5915456200216679 0.8865525265957447
# 5 0.6409670983223205 0.8844747340425532
# 6 0.7046249352316273 0.8837267287234043
# 7 0.7781265617764377 0.8804022606382979
# 8 0.6225886239888186 0.8829787234042553
# 9 0.6587125841290393 0.8828125
# 0.8834593949044586
# embedding.weight     | nonzeros = 1024041 / 2500200 ( 40.96%) | total_pruned = 1476159 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# fc.weight            | nonzeros =     209 /     512 ( 40.82%) | total_pruned =     303 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1970477, pruned : 2840380, total: 4810857, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.5137153638804213 0.8727559840425532
# 1 0.524094048610076 0.8842253989361702
# 2 0.5965975966066757 0.8848071808510638
# 3 0.7266111297414024 0.8836436170212766
# 4 0.7015454756056375 0.883311170212766
# 5 0.7271069018764699 0.8809009308510638
# 6 0.6034202945438472 0.8853058510638298
# 7 0.7679686492824174 0.8831449468085106
# 8 0.7417830850215669 0.8832280585106383
# 9 0.7442224729568401 0.8799867021276596
# 0.8796775477707006
# embedding.weight     | nonzeros =  819233 / 2500200 ( 32.77%) | total_pruned = 1680967 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# fc.weight            | nonzeros =     167 /     512 ( 32.62%) | total_pruned =     345 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1576377, pruned : 3234480, total: 4810857, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.4802359749186546 0.8795711436170213
# 1 0.5317043306979727 0.8783244680851063
# 2 0.6199427942963357 0.8760804521276596
# 3 0.541558101297693 0.8783244680851063
# 4 0.6705356820070363 0.8816489361702128
# 5 0.6956774335592351 0.8795711436170213
# 6 0.8590383386199779 0.879404920212766
# 7 0.7339437340802335 0.8821476063829787
# 8 0.7254080312683228 0.8805684840425532
# 9 0.7605741213452308 0.8807347074468085
# 0.881468949044586
# embedding.weight     | nonzeros =  655386 / 2500200 ( 26.21%) | total_pruned = 1844814 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# fc.weight            | nonzeros =     133 /     512 ( 25.98%) | total_pruned =     379 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1261098, pruned : 3549759, total: 4810857, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.41579837879126375 0.8504820478723404
# 1 0.505139817424277 0.8771609042553191
# 2 0.5368237227914815 0.8832280585106383
# 3 0.6141507646187823 0.8792386968085106
# 4 0.6262802966038122 0.882313829787234
# 5 0.7463990312783008 0.8764960106382979
# 6 0.7094661507042165 0.8788231382978723
# 7 0.7873009093739884 0.8779920212765957
# 8 0.6655605077902054 0.8805684840425532
# 9 0.7588291754747959 0.8815658244680851
# 0.8812699044585988
# embedding.weight     | nonzeros =  524309 / 2500200 ( 20.97%) | total_pruned = 1975891 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# fc.weight            | nonzeros =     106 /     512 ( 20.70%) | total_pruned =     406 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1008872, pruned : 3801985, total: 4810857, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.4542915444583335 0.8770777925531915
# 1 0.557537131011486 0.6775265957446809
# 2 0.5848103324942132 0.8808178191489362
# 3 0.5930155221610627 0.8810671542553191
# 4 0.6350848078727722 0.8803191489361702
# 5 0.652943473071494 0.8813164893617021
# 6 0.7012782535178864 0.8818151595744681
# 7 0.7435435672548223 0.8780751329787234
# 8 0.7711490996657534 0.8818982712765957
# 9 0.7431053927445666 0.8795711436170213
# 0.8805732484076433
# embedding.weight     | nonzeros =  419447 / 2500200 ( 16.78%) | total_pruned = 2080753 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# fc.weight            | nonzeros =      85 /     512 ( 16.60%) | total_pruned =     427 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 807095, pruned : 4003762, total: 4810857, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.4815478116432403 0.7868184840425532
# 1 0.5541230821387565 0.883311170212766
# 2 0.5910262506692967 0.8788231382978723
# 3 0.5091290757297835 0.8744182180851063
# 4 0.5301688316258344 0.8734208776595744
# 5 0.6314412574977317 0.8810671542553191
# 6 0.768535832141308 0.8722573138297872
# 7 0.6278669212726836 0.8821476063829787
# 8 0.6086896647639731 0.8760804521276596
# 9 0.620290422376166 0.8813164893617021
# 0.8798765923566879
# embedding.weight     | nonzeros =  335557 / 2500200 ( 13.42%) | total_pruned = 2164643 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# fc.weight            | nonzeros =      68 /     512 ( 13.28%) | total_pruned =     444 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 645676, pruned : 4165181, total: 4810857, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.40641686780021546 0.846908244680851
# 1 0.49763191515143884 0.8715093085106383
# 2 0.464577603609638 0.8694315159574468
# 3 0.567480246873295 0.8815658244680851
# 4 0.609358900404991 0.8828956117021277
# 5 0.6017389316111803 0.8763297872340425
# 6 0.6915414191465429 0.8811502659574468
# 7 0.6054258950133907 0.87890625
# 8 0.5587339636651759 0.8628656914893617
# 9 0.6481864425016844 0.8722573138297872
# 0.8691281847133758
# embedding.weight     | nonzeros =  268445 / 2500200 ( 10.74%) | total_pruned = 2231755 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# fc.weight            | nonzeros =      54 /     512 ( 10.55%) | total_pruned =     458 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 516532, pruned : 4294325, total: 4810857, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.42198445743068735 0.866938164893617
# 1 0.44307345920737756 0.8634474734042553
# 2 0.4839603494297951 0.8650265957446809
# 3 0.48799215788219835 0.8774933510638298
# 4 0.5427575419716378 0.8583776595744681
# 5 0.5816831063241401 0.8740026595744681
# 6 0.5394373836510993 0.8689328457446809
# 7 0.5776646215706429 0.8717586436170213
# 8 0.6029352454983807 0.8740026595744681
# 9 0.5886521193575351 0.8743351063829787
# 0.8745023885350318
# embedding.weight     | nonzeros =  214756 / 2500200 (  8.59%) | total_pruned = 2285444 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# fc.weight            | nonzeros =      43 /     512 (  8.40%) | total_pruned =     469 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 413224, pruned : 4397633, total: 4810857, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.4590134408245695 0.8516456117021277
# 1 0.5033930699004138 0.8723404255319149
# 2 0.5180513452183693 0.8780751329787234
# 3 0.5242495229665903 0.8780751329787234
# 4 0.5077232216742444 0.8661901595744681
# 5 0.5192974588259104 0.874501329787234
# 6 0.5234768052208931 0.8715093085106383
# 7 0.520468768802412 0.8761635638297872
# 8 0.5913910912151666 0.8740857712765957
# 9 0.5730034785464089 0.875498670212766
# 0.8754976114649682
# embedding.weight     | nonzeros =  171805 / 2500200 (  6.87%) | total_pruned = 2328395 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# fc.weight            | nonzeros =      34 /     512 (  6.64%) | total_pruned =     478 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 330572, pruned : 4480285, total: 4810857, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.49512346596159834 0.8649434840425532
# 1 0.5896566469777138 0.85546875
# 2 0.5533108807545393 0.8691821808510638
# 3 0.49475562810263735 0.8624501329787234
# 4 0.544759965680064 0.8733377659574468
# 5 0.5781927735723079 0.8755817819148937
# 6 0.5714454952865204 0.875748005319149
# 7 0.6132199409160208 0.8724235372340425
# 8 0.6917665694305237 0.8725066489361702
# 9 0.6326802684430112 0.8728390957446809
# 0.875
# embedding.weight     | nonzeros =  137444 / 2500200 (  5.50%) | total_pruned = 2362756 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# fc.weight            | nonzeros =      27 /     512 (  5.27%) | total_pruned =     485 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 264454, pruned : 4546403, total: 4810857, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.5120631296266901 0.8529753989361702
# 1 0.5327549206608153 0.8534740691489362
# 2 0.5503108092445008 0.8694315159574468
# 3 0.5716245022225888 0.8580452127659575
# 4 0.5389669356828041 0.8569647606382979
# 5 0.5816483150057971 0.870844414893617
# 6 0.6314455706705439 0.8697639627659575
# 7 0.6759540980800669 0.8727559840425532
# 8 0.6148295533308323 0.8751662234042553
# 9 0.6607087347260181 0.8695146276595744
# 0.8675358280254777
# embedding.weight     | nonzeros =  109955 / 2500200 (  4.40%) | total_pruned = 2390245 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# fc.weight            | nonzeros =      21 /     512 (  4.10%) | total_pruned =     491 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 211473, pruned : 4599384, total: 4810857, Compression rate :      22.75x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.5932541644161052 0.854720744680851
# 1 0.5567148717001398 0.8622839095744681
# 2 0.6699526865590126 0.8604554521276596
# 3 0.6361509798530568 0.8680186170212766
# 4 0.6601784186873664 0.8668550531914894
# 5 0.6782584581524134 0.8618683510638298
# 6 0.6259356210047894 0.8687666223404256
# 7 0.6548193563964773 0.862533244680851
# 8 0.677544300702024 0.8613696808510638
# 9 0.7203212646727867 0.8626163563829787
# 0.8622611464968153
# embedding.weight     | nonzeros =   87964 / 2500200 (  3.52%) | total_pruned = 2412236 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# fc.weight            | nonzeros =      17 /     512 (  3.32%) | total_pruned =     495 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 169174, pruned : 4641683, total: 4810857, Compression rate :      28.44x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.5573264880383269 0.8466589095744681
# 1 0.6352037825482957 0.8524767287234043
# 2 0.6729014386680532 0.8507313829787234
# 3 0.7112352338401561 0.8538896276595744
# 4 0.6124849793441752 0.8548869680851063
# 5 0.6175206035692641 0.8626994680851063
# 6 0.7062588405418904 0.8636136968085106
# 7 0.7042322532135121 0.859375
# 8 0.7318163945319804 0.8612034574468085
# 9 0.6760027712171383 0.8582114361702128
# 0.8571855095541401
# embedding.weight     | nonzeros =   70371 / 2500200 (  2.81%) | total_pruned = 2429829 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# fc.weight            | nonzeros =      13 /     512 (  2.54%) | total_pruned =     499 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 135335, pruned : 4675522, total: 4810857, Compression rate :      35.55x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.6172163139315362 0.836186835106383
# 1 0.5663782209950559 0.8324468085106383
# 2 0.6067940247978302 0.8529753989361702
# 3 0.7405478489050206 0.8467420212765957
# 4 0.7788093094813063 0.8526429521276596
# 5 0.727292537847732 0.8518949468085106
# 6 0.7583880235857152 0.8555518617021277
# 7 0.7412846025792842 0.8543051861702128
# 8 0.8144725108558827 0.854720744680851
# 9 0.8521833796291909 0.8567154255319149
# 0.8580812101910829
# embedding.weight     | nonzeros =   56297 / 2500200 (  2.25%) | total_pruned = 2443903 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# fc.weight            | nonzeros =      10 /     512 (  1.95%) | total_pruned =     502 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 108264, pruned : 4702593, total: 4810857, Compression rate :      44.44x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.5241205632052524 0.839095744680851
# 1 0.6220871321064361 0.8382646276595744
# 2 0.6649500922636783 0.8436668882978723
# 3 0.7142598877086285 0.847157579787234
# 4 0.6982474043331248 0.8479886968085106
# 5 0.6908585208052016 0.847157579787234
# 6 0.7214538481958369 0.8491522606382979
# 7 0.823186715866657 0.8491522606382979
# 8 0.7897496745782964 0.8491522606382979
# 9 0.8220768962451752 0.8497340425531915
# 0.8462380573248408
# embedding.weight     | nonzeros =   45037 / 2500200 (  1.80%) | total_pruned = 2455163 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# fc.weight            | nonzeros =       8 /     512 (  1.56%) | total_pruned =     504 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 86608, pruned : 4724249, total: 4810857, Compression rate :      55.55x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.5147318502372884 0.8332779255319149
# 1 0.5823180497168227 0.8335272606382979
# 2 0.6094161242722197 0.8372672872340425
# 3 0.6308760831647731 0.8382646276595744
# 4 0.675562045358597 0.8410904255319149
# 5 0.7053012828085017 0.8407579787234043
# 6 0.7374087446864616 0.839345079787234
# 7 0.7330390354420276 0.8423371010638298
# 8 0.6828751398369353 0.8430851063829787
# 9 0.775856504097898 0.843251329787234
# 0.8415605095541401
# embedding.weight     | nonzeros =   36029 / 2500200 (  1.44%) | total_pruned = 2464171 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# fc.weight            | nonzeros =       6 /     512 (  1.17%) | total_pruned =     506 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 69282, pruned : 4741575, total: 4810857, Compression rate :      69.44x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.5594382001523007 0.8296210106382979
# 1 0.5931325704651944 0.828623670212766
# 2 0.6245101166373872 0.8267121010638298
# 3 0.7335494255765955 0.831781914893617
# 4 0.7122550473568288 0.8342752659574468
# 5 0.7440808659538309 0.8343583776595744
# 6 0.7575481128185353 0.8287067819148937
# 7 0.7575015002425681 0.8300365691489362
# 8 0.7712559759458328 0.8262965425531915
# 9 0.7892035386188233 0.8270445478723404
# 0.8323049363057324
# embedding.weight     | nonzeros =   28823 / 2500200 (  1.15%) | total_pruned = 2471377 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =       0 /    1024 (  0.00%) | total_pruned =    1024 | shape = (1024,)
# fc.weight            | nonzeros =       5 /     512 (  0.98%) | total_pruned =     507 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 55421, pruned : 4755436, total: 4810857, Compression rate :      86.81x  ( 98.85% pruned)

# %%
# random
print(performance)
print(valid_losses)

reinit_performance = performance
reinit_valid_losses = valid_losses
# Out:
# [90.14729299363057, 89.37101910828027, 88.51512738853503, 88.76393312101911, 88.34593949044586, 87.96775477707006, 88.14689490445859, 88.12699044585987, 88.05732484076432, 87.98765923566879, 86.91281847133759, 87.45023885350318, 87.54976114649682, 87.5, 86.75358280254777, 86.22611464968153, 85.718550955414, 85.80812101910828, 84.62380573248409, 84.156050955414, 83.23049363057325]
# [0.28661345952051753, 0.41716557053571685, 0.45840316618535115, 0.7687182424867407, 0.6587125841290393, 0.7442224729568401, 0.7605741213452308, 0.7588291754747959, 0.7431053927445666, 0.620290422376166, 0.6481864425016844, 0.5886521193575351, 0.5730034785464089, 0.6326802684430112, 0.6607087347260181, 0.7203212646727867, 0.6760027712171383, 0.8521833796291909, 0.8220768962451752, 0.775856504097898, 0.7892035386188233]

# %% [markdown]
# ## 2) lt

# %%
reinit = False # random이면 True, lt면 False
mode = 'lt'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)
initial_state_dict = copy.deepcopy(model.state_dict())

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.BCEWithLogitsLoss()

criterion = criterion.to(device)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 4,810,857 trainable parameters

# %%
for name, param in model.named_parameters():
  print(name, param.size())
# Out:
# embedding.weight torch.Size([25002, 100])
# rnn.weight_ih_l0 torch.Size([1024, 100])
# rnn.weight_hh_l0 torch.Size([1024, 256])
# rnn.bias_ih_l0 torch.Size([1024])
# rnn.bias_hh_l0 torch.Size([1024])
# rnn.weight_ih_l0_reverse torch.Size([1024, 100])
# rnn.weight_hh_l0_reverse torch.Size([1024, 256])
# rnn.bias_ih_l0_reverse torch.Size([1024])
# rnn.bias_hh_l0_reverse torch.Size([1024])
# rnn.weight_ih_l1 torch.Size([1024, 512])
# rnn.weight_hh_l1 torch.Size([1024, 256])
# rnn.bias_ih_l1 torch.Size([1024])
# rnn.bias_hh_l1 torch.Size([1024])
# rnn.weight_ih_l1_reverse torch.Size([1024, 512])
# rnn.weight_hh_l1_reverse torch.Size([1024, 256])
# rnn.bias_ih_l1_reverse torch.Size([1024])
# rnn.bias_hh_l1_reverse torch.Size([1024])
# fc.weight torch.Size([1, 512])
# fc.bias torch.Size([1])

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train 
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.6275445514536918 0.6356382978723404
# 1 0.29055116547549026 0.8817320478723404
# 2 0.2515067496198289 0.9027593085106383
# 3 0.2698628051563146 0.9006815159574468
# 4 0.29401789498614506 0.9046708776595744
# 5 0.25580672650261127 0.9069148936170213
# 6 0.2908192324511548 0.9043384308510638
# 7 0.25336884845920066 0.905751329787234
# 8 0.29126042993541096 0.9030086436170213
# 9 0.2709320707920384 0.9074135638297872
# 0.9060509554140127
# embedding.weight     | nonzeros = 2500100 / 2500200 (100.00%) | total_pruned =     100 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# fc.weight            | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 4810757, pruned : 100, total: 4810857, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.4742802050995066 0.7957945478723404
# 1 0.34418673912419917 0.8612865691489362
# 2 0.2836642834021056 0.8920378989361702
# 3 0.2790417662881156 0.8980219414893617
# 4 0.2807657043350504 0.9068317819148937
# 5 0.2802987579414819 0.8956117021276596
# 6 0.3459798380970321 0.8865525265957447
# 7 0.35168183448308327 0.8846409574468085
# 8 0.34199856475312657 0.9005984042553191
# 9 0.3209210311042819 0.8996841755319149
# 0.9006767515923567
# embedding.weight     | nonzeros = 2000080 / 2500200 ( 80.00%) | total_pruned =  500120 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# fc.weight            | nonzeros =     409 /     512 ( 79.88%) | total_pruned =     103 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3848602, pruned : 962255, total: 4810857, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.6230255282939748 0.6704621010638298
# 1 0.3062500781280563 0.8795711436170213
# 2 0.27083856521293204 0.8967752659574468
# 3 0.2784767928434179 0.8924534574468085
# 4 0.28688407209800915 0.8966921542553191
# 5 0.30576834827661514 0.9013464095744681
# 6 0.33730997378997346 0.9030086436170213
# 7 0.2804118959193534 0.9045046542553191
# 8 0.32950216737833427 0.9007646276595744
# 9 0.355762850988577 0.8915392287234043
# 0.8904259554140127
# embedding.weight     | nonzeros = 1600064 / 2500200 ( 64.00%) | total_pruned =  900136 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  167773 /  262144 ( 64.00%) | total_pruned =   94371 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# fc.weight            | nonzeros =     327 /     512 ( 63.87%) | total_pruned =     185 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3078881, pruned : 1731976, total: 4810857, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.27485265352941574 0.8893783244680851
# 1 0.29292408361079847 0.8966090425531915
# 2 0.2747508623894859 0.9025099734042553
# 3 0.2768300234320316 0.8846409574468085
# 4 0.2730788331518465 0.9026761968085106
# 5 0.3495809530958216 0.8967752659574468
# 6 0.3281677771320051 0.9050864361702128
# 7 0.3647464575602653 0.9010970744680851
# 8 0.37863867103736454 0.8983543882978723
# 9 0.37667565362805383 0.9000997340425532
# 0.8965963375796179
# embedding.weight     | nonzeros = 1280051 / 2500200 ( 51.20%) | total_pruned = 1220149 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  134218 /  262144 ( 51.20%) | total_pruned =  127926 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# fc.weight            | nonzeros =     261 /     512 ( 50.98%) | total_pruned =     251 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2463102, pruned : 2347755, total: 4810857, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.40825226776143336 0.8184840425531915
# 1 0.29047967770949323 0.898188164893617
# 2 0.2678263937618504 0.9026761968085106
# 3 0.3001520681254407 0.8992686170212766
# 4 0.3299957310899775 0.9024268617021277
# 5 0.30666186593155914 0.8973570478723404
# 6 0.34466174977058744 0.9001828457446809
# 7 0.3829196932269855 0.9004321808510638
# 8 0.3782163202524819 0.9001828457446809
# 9 0.4281917932899074 0.8982712765957447
# 0.8946058917197452
# embedding.weight     | nonzeros = 1024041 / 2500200 ( 40.96%) | total_pruned = 1476159 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  107374 /  262144 ( 40.96%) | total_pruned =  154770 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# fc.weight            | nonzeros =     209 /     512 ( 40.82%) | total_pruned =     303 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1970478, pruned : 2840379, total: 4810857, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.48971051952623307 0.7995345744680851
# 1 0.33197130132070246 0.8890458776595744
# 2 0.3950215621673046 0.8795711436170213
# 3 0.38249824509183145 0.8822307180851063
# 4 0.33077717689361347 0.8993517287234043
# 5 0.3573006040396843 0.8958610372340425
# 6 0.3222901115907317 0.8984375
# 7 0.46093746591755685 0.8823969414893617
# 8 0.4018585884032097 0.8983543882978723
# 9 0.37324392522110583 0.8998503989361702
# 0.8991839171974523
# embedding.weight     | nonzeros =  819233 / 2500200 ( 32.77%) | total_pruned = 1680967 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   85899 /  262144 ( 32.77%) | total_pruned =  176245 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# fc.weight            | nonzeros =     167 /     512 ( 32.62%) | total_pruned =     345 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1576378, pruned : 3234479, total: 4810857, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.29966355947420953 0.886469414893617
# 1 0.2703023915515935 0.8943650265957447
# 2 0.33128491575096514 0.8963597074468085
# 3 0.3135701035486257 0.8921210106382979
# 4 0.3690380395806216 0.8873005319148937
# 5 0.3497066029763602 0.8996841755319149
# 6 0.337513840737495 0.9004321808510638
# 7 0.3855451006204524 0.8981050531914894
# 8 0.325730150248459 0.8992686170212766
# 9 0.33273945213790906 0.9012632978723404
# 0.9007762738853503
# embedding.weight     | nonzeros =  655386 / 2500200 ( 26.21%) | total_pruned = 1844814 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   68719 /  262144 ( 26.21%) | total_pruned =  193425 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# fc.weight            | nonzeros =     133 /     512 ( 25.98%) | total_pruned =     379 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1261099, pruned : 3549758, total: 4810857, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.36333351162202815 0.8597905585106383
# 1 0.4520796034088794 0.8711768617021277
# 2 0.3244107862974101 0.8907081117021277
# 3 0.33971646376588244 0.8885472074468085
# 4 0.494269090764066 0.878407579787234
# 5 0.5757304773210211 0.8622839095744681
# 6 0.37861772048029496 0.8904587765957447
# 7 0.4194902158243225 0.8927027925531915
# 8 0.4612545638563151 0.8877992021276596
# 9 0.4613666643012077 0.8887965425531915
# 0.8902269108280255
# embedding.weight     | nonzeros =  524309 / 2500200 ( 20.97%) | total_pruned = 1975891 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   54975 /  262144 ( 20.97%) | total_pruned =  207169 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# fc.weight            | nonzeros =     106 /     512 ( 20.70%) | total_pruned =     406 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1008873, pruned : 3801984, total: 4810857, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.7044188678264618 0.5566821808510638
# 1 0.44314858111295297 0.8191489361702128
# 2 0.6950033037586415 0.6391289893617021
# 3 0.4560344496622999 0.7992852393617021
# 4 0.3689995324040981 0.8571309840425532
# 5 0.30528505828152314 0.8688497340425532
# 6 0.36504924935387806 0.8807347074468085
# 7 0.3501576325519288 0.8892952127659575
# 8 0.4991759727411765 0.8638630319148937
# 9 0.34915847057833316 0.8885472074468085
# 0.8880374203821656
# embedding.weight     | nonzeros =  419447 / 2500200 ( 16.78%) | total_pruned = 2080753 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   43980 /  262144 ( 16.78%) | total_pruned =  218164 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# fc.weight            | nonzeros =      85 /     512 ( 16.60%) | total_pruned =     427 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 807096, pruned : 4003761, total: 4810857, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.4398561949901124 0.8085106382978723
# 1 0.49137030779681307 0.769032579787234
# 2 0.517939290784775 0.7965425531914894
# 3 0.33914616676245596 0.8744182180851063
# 4 0.368926318401986 0.8659408244680851
# 5 0.30027009467495247 0.8997672872340425
# 6 0.27063687684688165 0.9041722074468085
# 7 0.28553650270592656 0.9050033244680851
# 8 0.29632574315876403 0.902842420212766
# 9 0.3047537452917784 0.9064162234042553
# 0.9023686305732485
# embedding.weight     | nonzeros =  335557 / 2500200 ( 13.42%) | total_pruned = 2164643 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   35184 /  262144 ( 13.42%) | total_pruned =  226960 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# fc.weight            | nonzeros =      68 /     512 ( 13.28%) | total_pruned =     444 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 645677, pruned : 4165180, total: 4810857, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.4769089987620394 0.8240525265957447
# 1 0.3123403568851187 0.8818151595744681
# 2 0.3179107691617088 0.8814827127659575
# 3 0.32493014043157403 0.89453125
# 4 0.2844399797551809 0.8969414893617021
# 5 0.3093327397995807 0.8956117021276596
# 6 0.2778711806626079 0.902094414893617
# 7 0.29851883150478625 0.9033410904255319
# 8 0.3006186179935615 0.901845079787234
# 9 0.2992147037244223 0.9026761968085106
# 0.897093949044586
# embedding.weight     | nonzeros =  268445 / 2500200 ( 10.74%) | total_pruned = 2231755 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   28147 /  262144 ( 10.74%) | total_pruned =  233997 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# fc.weight            | nonzeros =      54 /     512 ( 10.55%) | total_pruned =     458 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 516533, pruned : 4294324, total: 4810857, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.3334984471030692 0.8725897606382979
# 1 0.3423536087366495 0.8712599734042553
# 2 0.321029773814247 0.8681848404255319
# 3 0.2995750633008937 0.8821476063829787
# 4 0.3179008588194847 0.8745844414893617
# 5 0.33877324285183813 0.8832280585106383
# 6 0.2937568901304869 0.8918716755319149
# 7 0.29965821982539714 0.8985206117021277
# 8 0.29205392259470325 0.9010139627659575
# 9 0.29310907639483824 0.9011801861702128
# 0.899781050955414
# embedding.weight     | nonzeros =  214756 / 2500200 (  8.59%) | total_pruned = 2285444 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# fc.weight            | nonzeros =      43 /     512 (  8.40%) | total_pruned =     469 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 413224, pruned : 4397633, total: 4810857, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.34100002177218175 0.8651928191489362
# 1 0.2914442448936244 0.8870511968085106
# 2 0.2993683872070718 0.8946974734042553
# 3 0.28891093711903754 0.8936170212765957
# 4 0.31082006692490044 0.8961934840425532
# 5 0.3167646083822276 0.8961934840425532
# 6 0.27519556459911326 0.9000166223404256
# 7 0.31455165387547396 0.9005984042553191
# 8 0.30849237589442985 0.9002659574468085
# 9 0.3200863677849795 0.9019281914893617
# 0.8983877388535032
# embedding.weight     | nonzeros =  171805 / 2500200 (  6.87%) | total_pruned = 2328395 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# fc.weight            | nonzeros =      34 /     512 (  6.64%) | total_pruned =     478 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 330572, pruned : 4480285, total: 4810857, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.40818004730217 0.859624335106383
# 1 0.33758666663569337 0.8722573138297872
# 2 0.3596445497204649 0.8542220744680851
# 3 0.34420973783794867 0.8782413563829787
# 4 0.32222693855378853 0.8870511968085106
# 5 0.323407246057499 0.8918716755319149
# 6 0.3133488965636872 0.8955285904255319
# 7 0.3366249588991892 0.895029920212766
# 8 0.3379795899258015 0.8926196808510638
# 9 0.3248282623615988 0.895029920212766
# 0.8932125796178344
# embedding.weight     | nonzeros =  137444 / 2500200 (  5.50%) | total_pruned = 2362756 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# fc.weight            | nonzeros =      27 /     512 (  5.27%) | total_pruned =     485 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 264454, pruned : 4546403, total: 4810857, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.32519463429901196 0.8695977393617021
# 1 0.3289204484763298 0.8792386968085106
# 2 0.3175372654928806 0.863031914893617
# 3 0.31448096290547795 0.882313829787234
# 4 0.2992464030914484 0.8879654255319149
# 5 0.3087919816136994 0.8860538563829787
# 6 0.3235844848479362 0.8848902925531915
# 7 0.30541979370916145 0.8889627659574468
# 8 0.5540404429144048 0.8474900265957447
# 9 0.300750439055264 0.8932014627659575
# 0.8930135350318471
# embedding.weight     | nonzeros =  109955 / 2500200 (  4.40%) | total_pruned = 2390245 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# fc.weight            | nonzeros =      21 /     512 (  4.10%) | total_pruned =     491 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 211561, pruned : 4599296, total: 4810857, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.3416353473241659 0.8722573138297872
# 1 0.3221461927874925 0.8732546542553191
# 2 0.33717286723487555 0.8834773936170213
# 3 0.3103045025008156 0.8870511968085106
# 4 0.3177071275942503 0.8858876329787234
# 5 0.38129302252955893 0.8845578457446809
# 6 0.36818835975483377 0.8838929521276596
# 7 0.34675285053697036 0.886469414893617
# 8 0.8242763420368763 0.749501329787234
# 9 0.3323654755157359 0.8758311170212766
# 0.8773885350318471
# embedding.weight     | nonzeros =   87964 / 2500200 (  3.52%) | total_pruned = 2412236 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# fc.weight            | nonzeros =      17 /     512 (  3.32%) | total_pruned =     495 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 169244, pruned : 4641613, total: 4810857, Compression rate :      28.43x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.33693568729498286 0.8755817819148937
# 1 0.3666065862362689 0.8805684840425532
# 2 0.36852753503208463 0.8690990691489362
# 3 0.364219660930177 0.8797373670212766
# 4 0.31967813101537684 0.883061835106383
# 5 0.3990301470807258 0.8854720744680851
# 6 0.3654441227541959 0.8838929521276596
# 7 0.39159213323542413 0.8858045212765957
# 8 0.3703946587926847 0.8890458776595744
# 9 0.3597956737899717 0.8912067819148937
# 0.888734076433121
# embedding.weight     | nonzeros =   70371 / 2500200 (  2.81%) | total_pruned = 2429829 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# fc.weight            | nonzeros =      13 /     512 (  2.54%) | total_pruned =     499 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 135391, pruned : 4675466, total: 4810857, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.330177930679093 0.8707613031914894
# 1 0.3193570705962942 0.875
# 2 0.33613735552322355 0.8642785904255319
# 3 0.3653682282868218 0.8774933510638298
# 4 0.3797318850584487 0.8527260638297872
# 5 0.38731711873031677 0.8722573138297872
# 6 0.35904933187238713 0.8698470744680851
# 7 0.398911465434952 0.879155585106383
# 8 0.3356651859952414 0.8767453457446809
# 9 0.35731010701745114 0.879155585106383
# 0.8802746815286624
# embedding.weight     | nonzeros =   56297 / 2500200 (  2.25%) | total_pruned = 2443903 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# fc.weight            | nonzeros =      10 /     512 (  1.95%) | total_pruned =     502 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 108308, pruned : 4702549, total: 4810857, Compression rate :      44.42x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.3839053418091003 0.8656914893617021
# 1 0.3528456103770023 0.8686003989361702
# 2 0.38551180599693285 0.8730884308510638
# 3 0.368186095452055 0.8720079787234043
# 4 0.3878385396079814 0.8749168882978723
# 5 0.36738892513862315 0.8730053191489362
# 6 0.39645867184438605 0.8717586436170213
# 7 0.3829168506125186 0.866938164893617
# 8 0.35461368364222506 0.8762466755319149
# 9 0.3436133074078788 0.8697639627659575
# 0.872312898089172
# embedding.weight     | nonzeros =   45037 / 2500200 (  1.80%) | total_pruned = 2455163 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      16 /    1024 (  1.56%) | total_pruned =    1008 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      16 /    1024 (  1.56%) | total_pruned =    1008 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# fc.weight            | nonzeros =       8 /     512 (  1.56%) | total_pruned =     504 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 86640, pruned : 4724217, total: 4810857, Compression rate :      55.53x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.3598878814026396 0.836186835106383
# 1 0.3963670129788683 0.8666057180851063
# 2 0.35752183167224233 0.8672706117021277
# 3 0.3597201609072533 0.8641954787234043
# 4 0.35926360953995523 0.8668550531914894
# 5 0.39456446365790165 0.8577127659574468
# 6 0.3800717164227303 0.8704288563829787
# 7 0.38227257960812844 0.8722573138297872
# 8 0.38206226973140495 0.8721742021276596
# 9 0.3453334332939158 0.867935505319149
# 0.8684315286624203
# embedding.weight     | nonzeros =   36029 / 2500200 (  1.44%) | total_pruned = 2464171 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# fc.weight            | nonzeros =       6 /     512 (  1.17%) | total_pruned =     506 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 69308, pruned : 4741549, total: 4810857, Compression rate :      69.41x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.39620776791521845 0.8346077127659575
# 1 0.3953212668445516 0.8359375
# 2 0.37102380482123254 0.8517287234042553
# 3 0.3744006473571062 0.8565492021276596
# 4 0.3606580591344453 0.8608710106382979
# 5 0.36454441600499 0.8617021276595744
# 6 0.36561559556805073 0.8617021276595744
# 7 0.3882352206459705 0.8651928191489362
# 8 0.3489386787677699 0.8657746010638298
# 9 0.35425657735384525 0.8641123670212766
# 0.8633558917197452
# embedding.weight     | nonzeros =   28823 / 2500200 (  1.15%) | total_pruned = 2471377 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# fc.weight            | nonzeros =       5 /     512 (  0.98%) | total_pruned =     507 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 55441, pruned : 4755416, total: 4810857, Compression rate :      86.77x  ( 98.85% pruned)

# %%
# lt
print(performance)
print(valid_losses)
lt_performance = performance
lt_valid_losses = valid_losses
# Out:
# [90.60509554140127, 90.06767515923568, 89.04259554140127, 89.65963375796179, 89.46058917197452, 89.91839171974523, 90.07762738853503, 89.02269108280255, 88.80374203821655, 90.23686305732484, 89.70939490445859, 89.97810509554141, 89.83877388535032, 89.32125796178345, 89.30135350318471, 87.73885350318471, 88.87340764331209, 88.02746815286623, 87.2312898089172, 86.84315286624204, 86.33558917197452]
# [0.2709320707920384, 0.3209210311042819, 0.355762850988577, 0.37667565362805383, 0.4281917932899074, 0.37324392522110583, 0.33273945213790906, 0.4613666643012077, 0.34915847057833316, 0.3047537452917784, 0.2992147037244223, 0.29310907639483824, 0.3200863677849795, 0.3248282623615988, 0.300750439055264, 0.3323654755157359, 0.3597956737899717, 0.35731010701745114, 0.3436133074078788, 0.3453334332939158, 0.35425657735384525]

# %% [markdown]
# ## 3) lt+lr (last epoch)

# %%
reinit = False # random이면 True, lt면 False
mode = 'lr_l'

# %%
# load model and set hyperparameters
model = load_model(arch_choice, data_choice, batch_size)

# model initialization and save the state
model.apply(initialize_xavier_normal)

# initial state 저장
torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-initial.pt')

# %%
model = model.to(device)
make_mask(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.BCEWithLogitsLoss()

criterion = criterion.to(device)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 4,810,857 trainable parameters

# %%
for name, param in model.named_parameters():
  print(name, param.size())
# Out:
# embedding.weight torch.Size([25002, 100])
# rnn.weight_ih_l0 torch.Size([1024, 100])
# rnn.weight_hh_l0 torch.Size([1024, 256])
# rnn.bias_ih_l0 torch.Size([1024])
# rnn.bias_hh_l0 torch.Size([1024])
# rnn.weight_ih_l0_reverse torch.Size([1024, 100])
# rnn.weight_hh_l0_reverse torch.Size([1024, 256])
# rnn.bias_ih_l0_reverse torch.Size([1024])
# rnn.bias_hh_l0_reverse torch.Size([1024])
# rnn.weight_ih_l1 torch.Size([1024, 512])
# rnn.weight_hh_l1 torch.Size([1024, 256])
# rnn.bias_ih_l1 torch.Size([1024])
# rnn.bias_hh_l1 torch.Size([1024])
# rnn.weight_ih_l1_reverse torch.Size([1024, 512])
# rnn.weight_hh_l1_reverse torch.Size([1024, 256])
# rnn.bias_ih_l1_reverse torch.Size([1024])
# rnn.bias_hh_l1_reverse torch.Size([1024])
# fc.weight torch.Size([1, 512])
# fc.bias torch.Size([1])

# %%
print("Iterative Pruning started")

performance = [] # 결과값을 담을 리스트
valid_losses = []

for pruning_iter in range(0,iteration+1):
  print(f"Running pruning iteration {pruning_iter}/{iteration}")

  # 첫 iter에는 no model compression
  if not pruning_iter == 0:

    # pruning
    prune_by_percentile(percent)

    # random initialization
    if reinit:
      model.apply(initialize_xavier_normal) # random initialization
      model.embedding.weight = embedding_pretrained_weight # embedding은 공통적으로 초기 임베딩으로 초기화
    
      step = 0
      for name, param in model.named_parameters():
      # if 'weight' in name: 
         weight_dev = param.device
         param.data = torch.from_numpy(param.data.cpu().numpy() * mask[step]).to(weight_dev)
         step = step + 1
      step = 0
    
    # lt initialization
    else:
      original_initialization(mask, initial_state_dict)

  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # train  
  for epoch in range(N_EPOCH):
    train_loss, train_acc = train(model, dataset.train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, dataset.valid_iter, criterion)
    print(epoch, valid_loss, valid_acc)

  test_loss, test_acc = evaluate(model, dataset.test_iter, criterion)
  torch.save(model.state_dict(), f'{data_choice}-{arch_choice}-{trial}-{mode}-{pruning_iter}.pt')
  print(test_acc)

  valid_losses.append(valid_loss)
  performance.append(100*test_acc)

  # late rewinding after the last epoch
  if pruning_iter == 0:
     initial_state_dict = copy.deepcopy(model.state_dict())

  print_nonzeros(model)
# Out:
# Iterative Pruning started
# Running pruning iteration 0/20
# 0 0.6665587637652742 0.586685505319149
# 1 0.6272801439812843 0.6527593085106383
# 2 0.3273678425144642 0.863031914893617
# 3 0.28569440496094684 0.882563164893617
# 4 0.34947340483678146 0.8648603723404256
# 5 0.2674269433668319 0.8961103723404256
# 6 0.29116612423132077 0.8877992021276596
# 7 0.25458272473212884 0.9029255319148937
# 8 0.25717981492585323 0.897689494680851
# 9 0.2673580652261351 0.9003490691489362
# 0.8995820063694268
# embedding.weight     | nonzeros = 2500100 / 2500200 (100.00%) | total_pruned =     100 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =  102400 /  102400 (100.00%) | total_pruned =       0 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  524288 /  524288 (100.00%) | total_pruned =       0 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  262144 /  262144 (100.00%) | total_pruned =       0 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =    1024 /    1024 (100.00%) | total_pruned =       0 | shape = (1024,)
# fc.weight            | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 4810757, pruned : 100, total: 4810857, Compression rate :       1.00x  (  0.00% pruned)
# Running pruning iteration 1/20
# 0 0.280421033283656 0.9033410904255319
# 1 0.2885141473342764 0.9049202127659575
# 2 0.25471298035947565 0.9047539893617021
# 3 0.2855335157364607 0.9015126329787234
# 4 0.28481339564190267 0.9015126329787234
# 5 0.31287255225346444 0.90234375
# 6 0.27367532689203605 0.9037566489361702
# 7 0.3110469982741361 0.8972739361702128
# 8 0.30892557698361417 0.8964428191489362
# 9 0.3663525728984399 0.9000997340425532
# 0.8998805732484076
# embedding.weight     | nonzeros = 2000080 / 2500200 ( 80.00%) | total_pruned =  500120 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   81920 /  102400 ( 80.00%) | total_pruned =   20480 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  419430 /  524288 ( 80.00%) | total_pruned =  104858 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  209715 /  262144 ( 80.00%) | total_pruned =   52429 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     819 /    1024 ( 79.98%) | total_pruned =     205 | shape = (1024,)
# fc.weight            | nonzeros =     409 /     512 ( 79.88%) | total_pruned =     103 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3848602, pruned : 962255, total: 4810857, Compression rate :       1.25x  ( 20.00% pruned)
# Running pruning iteration 2/20
# 0 0.26354082463745104 0.901595744680851
# 1 0.32477475354012025 0.9017619680851063
# 2 0.35194159346692105 0.8956117021276596
# 3 0.28644995361645803 0.8997672872340425
# 4 0.2859462652593217 0.9000997340425532
# 5 0.3120649781751823 0.8981050531914894
# 6 0.29808013262029026 0.8963597074468085
# 7 0.33050415395422184 0.8977726063829787
# 8 0.3838037216758474 0.8892121010638298
# 9 0.3904006472848197 0.9005984042553191
# 0.9025676751592356
# embedding.weight     | nonzeros = 1600064 / 2500200 ( 64.00%) | total_pruned =  900136 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   65536 /  102400 ( 64.00%) | total_pruned =   36864 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  335544 /  524288 ( 64.00%) | total_pruned =  188744 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  167772 /  262144 ( 64.00%) | total_pruned =   94372 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     655 /    1024 ( 63.96%) | total_pruned =     369 | shape = (1024,)
# fc.weight            | nonzeros =     327 /     512 ( 63.87%) | total_pruned =     185 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 3078880, pruned : 1731977, total: 4810857, Compression rate :       1.56x  ( 36.00% pruned)
# Running pruning iteration 3/20
# 0 0.29658058848469815 0.8983543882978723
# 1 0.2745101575521713 0.906499335106383
# 2 0.309147378033463 0.897938829787234
# 3 0.3299991050140655 0.9037566489361702
# 4 0.2935649440326589 0.8986037234042553
# 5 0.3125381285245431 0.9011801861702128
# 6 0.34815970974716737 0.8982712765957447
# 7 0.34131892304867506 0.8994348404255319
# 8 0.3397012824945627 0.9001828457446809
# 9 0.3048384489610474 0.8994348404255319
# 0.8977906050955414
# embedding.weight     | nonzeros = 1280051 / 2500200 ( 51.20%) | total_pruned = 1220149 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   52429 /  102400 ( 51.20%) | total_pruned =   49971 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  268435 /  524288 ( 51.20%) | total_pruned =  255853 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  134217 /  262144 ( 51.20%) | total_pruned =  127927 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     524 /    1024 ( 51.17%) | total_pruned =     500 | shape = (1024,)
# fc.weight            | nonzeros =     261 /     512 ( 50.98%) | total_pruned =     251 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 2463101, pruned : 2347756, total: 4810857, Compression rate :       1.95x  ( 48.80% pruned)
# Running pruning iteration 4/20
# 0 0.3079176764301163 0.9044215425531915
# 1 0.39908570332571547 0.8865525265957447
# 2 0.31206843298562664 0.9030086436170213
# 3 0.3180492819346329 0.9039228723404256
# 4 0.31863466454075373 0.8998503989361702
# 5 0.3332419908070501 0.9017619680851063
# 6 0.32491174692961766 0.897938829787234
# 7 0.3331177754803224 0.8981050531914894
# 8 0.3310367422019865 0.9010139627659575
# 9 0.3555393433198333 0.8991023936170213
# 0.9038614649681529
# embedding.weight     | nonzeros = 1024041 / 2500200 ( 40.96%) | total_pruned = 1476159 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   41943 /  102400 ( 40.96%) | total_pruned =   60457 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  214748 /  524288 ( 40.96%) | total_pruned =  309540 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =  107373 /  262144 ( 40.96%) | total_pruned =  154771 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     419 /    1024 ( 40.92%) | total_pruned =     605 | shape = (1024,)
# fc.weight            | nonzeros =     209 /     512 ( 40.82%) | total_pruned =     303 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1970477, pruned : 2840380, total: 4810857, Compression rate :       2.44x  ( 59.04% pruned)
# Running pruning iteration 5/20
# 0 0.33477905676006636 0.9019281914893617
# 1 0.3379122427208944 0.9031748670212766
# 2 0.3472643933714704 0.8927027925531915
# 3 0.29827038618795415 0.9010970744680851
# 4 0.34701286581285457 0.902593085106383
# 5 0.36747746341960863 0.9016788563829787
# 6 0.35223506145337796 0.8892952127659575
# 7 0.3611876337808814 0.8965259308510638
# 8 0.4047767096892633 0.8999335106382979
# 9 0.33361136421878285 0.899185505319149
# 0.8992834394904459
# embedding.weight     | nonzeros =  819233 / 2500200 ( 32.77%) | total_pruned = 1680967 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   33554 /  102400 ( 32.77%) | total_pruned =   68846 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  171798 /  524288 ( 32.77%) | total_pruned =  352490 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   85898 /  262144 ( 32.77%) | total_pruned =  176246 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     335 /    1024 ( 32.71%) | total_pruned =     689 | shape = (1024,)
# fc.weight            | nonzeros =     167 /     512 ( 32.62%) | total_pruned =     345 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1576377, pruned : 3234480, total: 4810857, Compression rate :       3.05x  ( 67.23% pruned)
# Running pruning iteration 6/20
# 0 0.33236874247643544 0.8991023936170213
# 1 0.3375972369883923 0.9008477393617021
# 2 0.3176537089723539 0.9003490691489362
# 3 0.33277512730119074 0.9017619680851063
# 4 0.34917151446434413 0.9033410904255319
# 5 0.38136994977422217 0.8971077127659575
# 6 0.3534754747921165 0.9020113031914894
# 7 0.3972713018351413 0.8999335106382979
# 8 0.37203291240841785 0.9020113031914894
# 9 0.3963029908531524 0.898936170212766
# 0.8974920382165605
# embedding.weight     | nonzeros =  655386 / 2500200 ( 26.21%) | total_pruned = 1844814 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   26843 /  102400 ( 26.21%) | total_pruned =   75557 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  137438 /  524288 ( 26.21%) | total_pruned =  386850 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   68718 /  262144 ( 26.21%) | total_pruned =  193426 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     268 /    1024 ( 26.17%) | total_pruned =     756 | shape = (1024,)
# fc.weight            | nonzeros =     133 /     512 ( 25.98%) | total_pruned =     379 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1261098, pruned : 3549759, total: 4810857, Compression rate :       3.81x  ( 73.79% pruned)
# Running pruning iteration 7/20
# 0 0.3239267894482993 0.8996010638297872
# 1 0.34431626853790687 0.9017619680851063
# 2 0.3593178527390069 0.9000997340425532
# 3 0.3771187022249115 0.8998503989361702
# 4 0.35712734867442164 0.8991023936170213
# 5 0.32217655941209894 0.9024268617021277
# 6 0.331948277758474 0.8998503989361702
# 7 0.340768866280609 0.8980219414893617
# 8 0.3740944456943172 0.8999335106382979
# 9 0.3866792597035144 0.899185505319149
# 0.9007762738853503
# embedding.weight     | nonzeros =  524309 / 2500200 ( 20.97%) | total_pruned = 1975891 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   21474 /  102400 ( 20.97%) | total_pruned =   80926 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =  109950 /  524288 ( 20.97%) | total_pruned =  414338 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   54974 /  262144 ( 20.97%) | total_pruned =  207170 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     214 /    1024 ( 20.90%) | total_pruned =     810 | shape = (1024,)
# fc.weight            | nonzeros =     106 /     512 ( 20.70%) | total_pruned =     406 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 1008872, pruned : 3801985, total: 4810857, Compression rate :       4.77x  ( 79.03% pruned)
# Running pruning iteration 8/20
# 0 0.34035948832380647 0.9012632978723404
# 1 0.3015853700604528 0.9016788563829787
# 2 0.32012125938893 0.8991023936170213
# 3 0.41392851312288104 0.8902094414893617
# 4 0.3251996672454667 0.9000997340425532
# 5 0.37937814867163594 0.898686835106383
# 6 0.35079545896262565 0.8984375
# 7 0.3636039418386335 0.8998503989361702
# 8 0.3689316721494369 0.901595744680851
# 9 0.41103954054415226 0.9008477393617021
# 0.904359076433121
# embedding.weight     | nonzeros =  419447 / 2500200 ( 16.78%) | total_pruned = 2080753 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   17179 /  102400 ( 16.78%) | total_pruned =   85221 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   87960 /  524288 ( 16.78%) | total_pruned =  436328 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   43979 /  262144 ( 16.78%) | total_pruned =  218165 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     171 /    1024 ( 16.70%) | total_pruned =     853 | shape = (1024,)
# fc.weight            | nonzeros =      85 /     512 ( 16.60%) | total_pruned =     427 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 807095, pruned : 4003762, total: 4810857, Compression rate :       5.96x  ( 83.22% pruned)
# Running pruning iteration 9/20
# 0 0.35239127062340364 0.9000166223404256
# 1 0.340640351552754 0.901845079787234
# 2 0.36838139038770756 0.902094414893617
# 3 0.3928753900777628 0.9000997340425532
# 4 0.3764944335723177 0.9006815159574468
# 5 0.3573466488952808 0.8980219414893617
# 6 0.3840315473127238 0.901845079787234
# 7 0.37199211829995854 0.8984375
# 8 0.3998767119891783 0.8966090425531915
# 9 0.37622772929991816 0.8999335106382979
# 0.9048566878980892
# embedding.weight     | nonzeros =  335557 / 2500200 ( 13.42%) | total_pruned = 2164643 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   13743 /  102400 ( 13.42%) | total_pruned =   88657 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   70368 /  524288 ( 13.42%) | total_pruned =  453920 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   35183 /  262144 ( 13.42%) | total_pruned =  226961 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     137 /    1024 ( 13.38%) | total_pruned =     887 | shape = (1024,)
# fc.weight            | nonzeros =      68 /     512 ( 13.28%) | total_pruned =     444 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 645676, pruned : 4165181, total: 4810857, Compression rate :       7.45x  ( 86.58% pruned)
# Running pruning iteration 10/20
# 0 0.3119817869143283 0.8984375
# 1 0.3296967674482693 0.8977726063829787
# 2 0.33061228308113333 0.9000997340425532
# 3 0.38190189955082343 0.8994348404255319
# 4 0.3629396338649887 0.8999335106382979
# 5 0.388800405837754 0.8992686170212766
# 6 0.356676496406819 0.8980219414893617
# 7 0.4104738177810895 0.8985206117021277
# 8 0.34626801769704896 0.8971908244680851
# 9 0.40375970010744766 0.8949468085106383
# 0.897890127388535
# embedding.weight     | nonzeros =  268445 / 2500200 ( 10.74%) | total_pruned = 2231755 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =   10994 /  102400 ( 10.74%) | total_pruned =   91406 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   56294 /  524288 ( 10.74%) | total_pruned =  467994 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   28146 /  262144 ( 10.74%) | total_pruned =  233998 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =     109 /    1024 ( 10.64%) | total_pruned =     915 | shape = (1024,)
# fc.weight            | nonzeros =      54 /     512 ( 10.55%) | total_pruned =     458 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 516532, pruned : 4294325, total: 4810857, Compression rate :       9.31x  ( 89.26% pruned)
# Running pruning iteration 11/20
# 0 0.3655501771321956 0.8970246010638298
# 1 0.46298886821704344 0.8816489361702128
# 2 0.38337401634557766 0.8994348404255319
# 3 0.40550800855766905 0.8988530585106383
# 4 0.3372889299817542 0.898686835106383
# 5 0.41739646818964404 0.8970246010638298
# 6 0.4031657309846041 0.8967752659574468
# 7 0.344712715457253 0.9003490691489362
# 8 0.42461210388214665 0.8974401595744681
# 9 0.40714911014792765 0.8969414893617021
# 0.8984872611464968
# embedding.weight     | nonzeros =  214757 / 2500200 (  8.59%) | total_pruned = 2285443 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    8795 /  102400 (  8.59%) | total_pruned =   93605 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   45035 /  524288 (  8.59%) | total_pruned =  479253 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   22517 /  262144 (  8.59%) | total_pruned =  239627 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      87 /    1024 (  8.50%) | total_pruned =     937 | shape = (1024,)
# fc.weight            | nonzeros =      43 /     512 (  8.40%) | total_pruned =     469 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 413225, pruned : 4397632, total: 4810857, Compression rate :      11.64x  ( 91.41% pruned)
# Running pruning iteration 12/20
# 0 0.3530520389173576 0.8988530585106383
# 1 0.34015087277053835 0.897689494680851
# 2 0.3719157561600367 0.8968583776595744
# 3 0.3950307929016491 0.8922041223404256
# 4 0.3431473184535478 0.898936170212766
# 5 0.36225154157727957 0.8965259308510638
# 6 0.3827581346589834 0.8990192819148937
# 7 0.39822194871908806 0.8966921542553191
# 8 0.39616413661179706 0.8968583776595744
# 9 0.40477936673275333 0.8944481382978723
# 0.8942078025477707
# embedding.weight     | nonzeros =  171805 / 2500200 (  6.87%) | total_pruned = 2328395 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    7036 /  102400 (  6.87%) | total_pruned =   95364 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   36028 /  524288 (  6.87%) | total_pruned =  488260 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   18013 /  262144 (  6.87%) | total_pruned =  244131 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      69 /    1024 (  6.74%) | total_pruned =     955 | shape = (1024,)
# fc.weight            | nonzeros =      34 /     512 (  6.64%) | total_pruned =     478 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 330572, pruned : 4480285, total: 4810857, Compression rate :      14.55x  ( 93.13% pruned)
# Running pruning iteration 13/20
# 0 0.35648662823827026 0.8951961436170213
# 1 0.34703595339855614 0.8991023936170213
# 2 0.35653282838695227 0.898936170212766
# 3 0.3431306774827077 0.9003490691489362
# 4 0.3834015487871589 0.8961934840425532
# 5 0.3844356423323142 0.8993517287234043
# 6 0.34448686654263355 0.8994348404255319
# 7 0.36733418252279465 0.8998503989361702
# 8 0.35867727229847235 0.898188164893617
# 9 0.41857303094435877 0.8938663563829787
# 0.892515923566879
# embedding.weight     | nonzeros =  137444 / 2500200 (  5.50%) | total_pruned = 2362756 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    5629 /  102400 (  5.50%) | total_pruned =   96771 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   28822 /  524288 (  5.50%) | total_pruned =  495466 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   14410 /  262144 (  5.50%) | total_pruned =  247734 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      55 /    1024 (  5.37%) | total_pruned =     969 | shape = (1024,)
# fc.weight            | nonzeros =      27 /     512 (  5.27%) | total_pruned =     485 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 264454, pruned : 4546403, total: 4810857, Compression rate :      18.19x  ( 94.50% pruned)
# Running pruning iteration 14/20
# 0 0.33335701960753256 0.8878823138297872
# 1 0.353545051117606 0.8914561170212766
# 2 0.4430222714993548 0.8808178191489362
# 3 0.41889434529745834 0.8925365691489362
# 4 0.3632772425486845 0.8934507978723404
# 5 0.3812043687447588 0.8929521276595744
# 6 0.3868939084833131 0.8931183510638298
# 7 0.43670860874129735 0.8929521276595744
# 8 0.4199170504914636 0.8897938829787234
# 9 0.3695231836606213 0.8965259308510638
# 0.8985867834394905
# embedding.weight     | nonzeros =  109955 / 2500200 (  4.40%) | total_pruned = 2390245 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    4503 /  102400 (  4.40%) | total_pruned =   97897 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   23057 /  524288 (  4.40%) | total_pruned =  501231 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =   11528 /  262144 (  4.40%) | total_pruned =  250616 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      44 /    1024 (  4.30%) | total_pruned =     980 | shape = (1024,)
# fc.weight            | nonzeros =      21 /     512 (  4.10%) | total_pruned =     491 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 211561, pruned : 4599296, total: 4810857, Compression rate :      22.74x  ( 95.60% pruned)
# Running pruning iteration 15/20
# 0 0.37826760093423917 0.8845578457446809
# 1 0.3865278762705783 0.8701795212765957
# 2 0.349807540826658 0.8918716755319149
# 3 0.38321065557922457 0.8853058510638298
# 4 0.42570253255519463 0.8817320478723404
# 5 0.40223593855316336 0.8740857712765957
# 6 0.4209004870437561 0.8863031914893617
# 7 0.4293166011017054 0.8758311170212766
# 8 0.4040472708404698 0.890874335106383
# 9 0.4643802063024424 0.8789893617021277
# 0.8858479299363057
# embedding.weight     | nonzeros =   87964 / 2500200 (  3.52%) | total_pruned = 2412236 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    3602 /  102400 (  3.52%) | total_pruned =   98798 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   18445 /  524288 (  3.52%) | total_pruned =  505843 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    9222 /  262144 (  3.52%) | total_pruned =  252922 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      35 /    1024 (  3.42%) | total_pruned =     989 | shape = (1024,)
# fc.weight            | nonzeros =      17 /     512 (  3.32%) | total_pruned =     495 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 169244, pruned : 4641613, total: 4810857, Compression rate :      28.43x  ( 96.48% pruned)
# Running pruning iteration 16/20
# 0 0.4028189117683375 0.8788231382978723
# 1 0.4415504499635798 0.866938164893617
# 2 0.4267971502181063 0.8759142287234043
# 3 0.4250230369098643 0.8670212765957447
# 4 0.4426835322792226 0.8852227393617021
# 5 0.4011249739201145 0.8843916223404256
# 6 0.36016569908787593 0.889876994680851
# 7 0.3758078400996771 0.8920378989361702
# 8 0.45239694511636774 0.8831449468085106
# 9 0.40817442465018716 0.8896276595744681
# 0.8955015923566879
# embedding.weight     | nonzeros =   70371 / 2500200 (  2.81%) | total_pruned = 2429829 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2881 /  102400 (  2.81%) | total_pruned =   99519 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   14756 /  524288 (  2.81%) | total_pruned =  509532 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    7377 /  262144 (  2.81%) | total_pruned =  254767 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      28 /    1024 (  2.73%) | total_pruned =     996 | shape = (1024,)
# fc.weight            | nonzeros =      13 /     512 (  2.54%) | total_pruned =     499 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 135391, pruned : 4675466, total: 4810857, Compression rate :      35.53x  ( 97.19% pruned)
# Running pruning iteration 17/20
# 0 0.3709122875427946 0.8768284574468085
# 1 0.38659787487159386 0.8772440159574468
# 2 0.3806426713758327 0.883061835106383
# 3 0.3702615971894974 0.883560505319149
# 4 0.3387919913660339 0.8828125
# 5 0.40628502668535454 0.8840591755319149
# 6 0.3759497711633114 0.882064494680851
# 7 0.43856762785543785 0.8676030585106383
# 8 0.37883279341808024 0.8868849734042553
# 9 0.4097749140272115 0.8802360372340425
# 0.884952229299363
# embedding.weight     | nonzeros =   56297 / 2500200 (  2.25%) | total_pruned = 2443903 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    2305 /  102400 (  2.25%) | total_pruned =  100095 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =   11805 /  524288 (  2.25%) | total_pruned =  512483 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    5901 /  262144 (  2.25%) | total_pruned =  256243 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      22 /    1024 (  2.15%) | total_pruned =    1002 | shape = (1024,)
# fc.weight            | nonzeros =      10 /     512 (  1.95%) | total_pruned =     502 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 108308, pruned : 4702549, total: 4810857, Compression rate :      44.42x  ( 97.75% pruned)
# Running pruning iteration 18/20
# 0 0.3640870062753241 0.8700132978723404
# 1 0.4478215637834782 0.866439494680851
# 2 0.39279805575596527 0.8765791223404256
# 3 0.4864737320136517 0.8603723404255319
# 4 0.40018056455920353 0.8707613031914894
# 5 0.39455928181872724 0.8778257978723404
# 6 0.4574004092669867 0.8723404255319149
# 7 0.4434955361041617 0.8685172872340425
# 8 0.41174390856572923 0.8783244680851063
# 9 0.4255295708934043 0.8734208776595744
# 0.8799761146496815
# embedding.weight     | nonzeros =   45037 / 2500200 (  1.80%) | total_pruned = 2455163 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1844 /  102400 (  1.80%) | total_pruned =  100556 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    9444 /  524288 (  1.80%) | total_pruned =  514844 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    4721 /  262144 (  1.80%) | total_pruned =  257423 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      17 /    1024 (  1.66%) | total_pruned =    1007 | shape = (1024,)
# fc.weight            | nonzeros =       8 /     512 (  1.56%) | total_pruned =     504 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 86642, pruned : 4724215, total: 4810857, Compression rate :      55.53x  ( 98.20% pruned)
# Running pruning iteration 19/20
# 0 0.36059147888358606 0.8611203457446809
# 1 0.4000539876362111 0.8675199468085106
# 2 0.39901344050118265 0.8651928191489362
# 3 0.35671486871990754 0.8736702127659575
# 4 0.43968523293733597 0.8624501329787234
# 5 0.3826274293613561 0.8700964095744681
# 6 0.3853617552667856 0.8697639627659575
# 7 0.38111523629978616 0.870345744680851
# 8 0.42111502223192376 0.8615359042553191
# 9 0.47524133705078286 0.863031914893617
# 0.8683320063694268
# embedding.weight     | nonzeros =   36029 / 2500200 (  1.44%) | total_pruned = 2464171 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1475 /  102400 (  1.44%) | total_pruned =  100925 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    7555 /  524288 (  1.44%) | total_pruned =  516733 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3777 /  262144 (  1.44%) | total_pruned =  258367 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      13 /    1024 (  1.27%) | total_pruned =    1011 | shape = (1024,)
# fc.weight            | nonzeros =       6 /     512 (  1.17%) | total_pruned =     506 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 69308, pruned : 4741549, total: 4810857, Compression rate :      69.41x  ( 98.56% pruned)
# Running pruning iteration 20/20
# 0 0.3395774463548305 0.8599567819148937
# 1 0.3848212042704542 0.8646941489361702
# 2 0.40198651756694975 0.8618683510638298
# 3 0.3976906954925111 0.8651928191489362
# 4 0.39081418264578 0.8695146276595744
# 5 0.41300064206440396 0.8655252659574468
# 6 0.3747484546075476 0.8721742021276596
# 7 0.41966370984594875 0.8698470744680851
# 8 0.36177574549900726 0.8702626329787234
# 9 0.3880528197722866 0.8695146276595744
# 0.872312898089172
# embedding.weight     | nonzeros =   28823 / 2500200 (  1.15%) | total_pruned = 2471377 | shape = (25002, 100)
# rnn.weight_ih_l0     | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l0_reverse | nonzeros =    1180 /  102400 (  1.15%) | total_pruned =  101220 | shape = (1024, 100)
# rnn.weight_hh_l0_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l0_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1     | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1     | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1       | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.weight_ih_l1_reverse | nonzeros =    6044 /  524288 (  1.15%) | total_pruned =  518244 | shape = (1024, 512)
# rnn.weight_hh_l1_reverse | nonzeros =    3021 /  262144 (  1.15%) | total_pruned =  259123 | shape = (1024, 256)
# rnn.bias_ih_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# rnn.bias_hh_l1_reverse | nonzeros =      10 /    1024 (  0.98%) | total_pruned =    1014 | shape = (1024,)
# fc.weight            | nonzeros =       5 /     512 (  0.98%) | total_pruned =     507 | shape = (1, 512)
# fc.bias              | nonzeros =       1 /       1 (100.00%) | total_pruned =       0 | shape = (1,)
# alive: 55441, pruned : 4755416, total: 4810857, Compression rate :      86.77x  ( 98.85% pruned)

# %%
# lr_l
print(performance)
print(valid_losses)

lr_l_performance = performance
lr_l_valid_losses = valid_losses
# Out:
# [89.95820063694268, 89.98805732484077, 90.25676751592357, 89.77906050955414, 90.38614649681529, 89.92834394904459, 89.74920382165605, 90.07762738853503, 90.43590764331209, 90.48566878980891, 89.7890127388535, 89.84872611464968, 89.42078025477707, 89.25159235668791, 89.85867834394905, 88.58479299363057, 89.55015923566879, 88.4952229299363, 87.99761146496814, 86.83320063694268, 87.2312898089172]
# [0.2673580652261351, 0.3663525728984399, 0.3904006472848197, 0.3048384489610474, 0.3555393433198333, 0.33361136421878285, 0.3963029908531524, 0.3866792597035144, 0.41103954054415226, 0.37622772929991816, 0.40375970010744766, 0.40714911014792765, 0.40477936673275333, 0.41857303094435877, 0.3695231836606213, 0.4643802063024424, 0.40817442465018716, 0.4097749140272115, 0.4255295708934043, 0.47524133705078286, 0.3880528197722866]

# %% [markdown]
# # Plot

# %%
print(reinit_performance)
print(lt_performance)
print(lr_l_performance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-e95ce432fa56> in <module>()
# ----> 1 print(reinit_performance)
#       2 print(lt_performance)
#       3 print(lr_l_performance)
#
# NameError: name 'reinit_performance' is not defined
